# %%
#Для расчета прейскуранта бриллиантов
# работает после кода 23-10-24_упрОбработка выгрузки 1С УТ ДК использование коррекцию вставок 1-5 род_корр штрихкод.ipynb
## на входе данные - for_script24-10-2023\выгрузка15-10-2023_все_склады_ДК_24-10-2023_17-57.xlsx
#
#описание - C:\Users\специалист ао\mypandas\work\2023\23-09-ХХ Переоценка ДК магазины выст\ReadMe2023-10-18.docx

# %%
import datetime
datetime.datetime.now().strftime('%d-%m-%Y_%H-%M')
# Out:
# '31-10-2023_09-31'

# %% [markdown]
# # imports

# %%
import numpy as np
import pandas as pd
import re
import os

# %%
folder = '../'
os.listdir(folder)
# Out:
# ['1 Вводные',
#  'del',
#  'for_script17-10-2023',
#  'for_script24-10-2023',
#  'ipynb',
#  'ReadMe2023-10-18.docx',
#  '~$adMe2023-09-19.docx',
#  '~$adMe2023-10-18.docx',
#  'Вставки Родитель1-5 коррекция',
#  'Приложение к readme обнаружены несоответствия по номенклатуре 26-09-2023.xlsx',
#  'Расчет17-10-2023',
#  'Расчет24-10-2023',
#  'Результаты анализа',
#  'шаблон',
#  'штрихкод_24-10-2023_16-33.xlsx']

# %%
folder_res = folder+'for_script24-10-2023/'
folder_res
# Out:
# '../for_script24-10-2023/'

# %%
from rusprice.dictdiamonds import dcol_dia, dcla_dia, dpo_dia, dogr_dia_discount
#import rusprice.func_rpdiamonds_xlsx_v2022_2_CARtoKVG_v2 as func_rpdiamonds_v2
#func_rpdiamonds_xlsx_v2023_1_CARtoKVG.py
import rusprice.func_rpdiamonds_xlsx_v2023_1_CARtoKVG as func_rpdiamonds_v2

# %% [markdown]
# # Входные данные

# %%
files = os.listdir(folder_res)

[x for x in enumerate(files)]
# Out:
# [(0, 'выгрузка15-10-2023_все_склады_ДК_31-10-2023_09-29.xlsx'),
#  (1, 'до исправления вставок после 24-10-2023')]

# %%
filename = files[0]
filename
# Out:
# 'выгрузка15-10-2023_все_склады_ДК_31-10-2023_09-29.xlsx'

# %%
#D:\VKT\TEST_price_diamond\Лот № 1958сертЦО.xls
#df1 = pd.read_excel('D:\VKT\TEST_price_diamond\Лот № 1958сертЦО.xls', dtype={'Code': str})
df0 = pd.read_excel(folder_res+filename)

# %%
#Изначальный файл 1С выгрузки с присоединением штрихкода, Р1-5
df0
# Out:
#        Unnamed: 0          Код Старый код (Справочник "Номенклатура" (Общие))  \
# 0               0  ЦБ-00200503                                            NaN
# 1               1  ЦБ-00002854                                     МС00057368
# 2               2  ЦБ-00019951                                     МС00152100
# 3               3  ЦБ-00019953                                     МС00146311
# 4               4  ЦБ-00111074                                     МС00111422
# ...           ...          ...                                            ...
# 34264       34264  ЦБ-00182016                                     0000032928
# 34265       34265  ЦБ-00182017                                     0000032929
# 34266       34266  ЦБ-00182019                                     0000032934
# 34267       34267  ЦБ-00182020                                     0000032935
# 34268       34268  ЦБ-00182021                                     0000032936
#
#                    Склад Склад.Склад / Магазин  \
# 0           Благовещенск     Розничный магазин
# 1           Благовещенск     Розничный магазин
# 2           Благовещенск     Розничный магазин
#                                   Источник корректировки      Родитель1корр  \
# 0      \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Об...  Ювелирные изделия
# 1      \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Об...  Ювелирные изделия
# 2      \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Об...  Ювелирные изделия
# 3      \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Об...  Ювелирные изделия
# 4      \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Об...  Ювелирные изделия
# ...                                                  ...                ...
# 34264  \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Об...  Ювелирные изделия
# 34265  \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Об...  Ювелирные изделия
# 34266  \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Об...  Ювелирные изделия
# 34267  \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Об...  Ювелирные изделия
# 34268  \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Об...  Ювелирные изделия
#
#                   Родитель2корр                                 Родитель3корр  \
# 0         Саха Минералс Лимитед  Sakha Minerals Limited SM21-01 от 28.09.2021
# 1                     Из Москвы                                      Товар ДК
# 2            ИП "Алексеев В.М."                          10-271 от 21.12.2018
# 3      Драгоценности Якутии ООО                        № 06-329/2 от 12.12.16
# 4      Драгоценности Якутии ООО                        06-341/4 от 26.12.2016
# ...                         ...                                           ...
# 34264    Золото Якутии ОАО АПЮК                                   Из магазина
# 34265    Золото Якутии ОАО АПЮК                                   Из магазина
# 34266    Золото Якутии ОАО АПЮК                                   Из магазина
# 34267    Золото Якутии ОАО АПЮК                                   Из магазина
# 34268    Золото Якутии ОАО АПЮК                                   Из магазина
#
#                            Родитель4корр Родитель5корр
# 0        спецификация №1 от 27.01.2022г.           NaN
# 1                                    NaN           NaN
# 2                                  Броши           NaN
# 3      06-329/2 от 12.12.2016 Задание №4       накл.№5
# 4                                  51 ДК           NaN
# ...                                  ...           ...
# 34264          Акт №1 АК "Золото Якутии"           NaN
# 34265          Акт №1 АК "Золото Якутии"           NaN
# 34266          Акт №1 АК "Золото Якутии"           NaN
# 34267          Акт №1 АК "Золото Якутии"           NaN
# 34268          Акт №1 АК "Золото Якутии"           NaN
#
# [34269 rows x 44 columns]

# %%
df0.columns
# Out:
# Index(['Unnamed: 0', 'Код', 'Старый код (Справочник "Номенклатура" (Общие))',
#        'Склад', 'Склад.Склад / Магазин',
#        'Вставки (Справочник "Номенклатура" (Общие))', 'Вид номенклатуры',
#        'Тип номенклатуры', 'Номенклатура', 'Группа',
#        'Заводской номер (Справочник "Номенклатура" (Общие))',
#        'Проба (Справочник "Номенклатура" (Общие))',
#        'Цвет металла (Справочник "Номенклатура" (Общие))',
#        'Дизайн (Справочник "Номенклатура" (Общие))', 'Артикул ',
#        'Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))',
#        'Цвет Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Чистота Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Размер (Справочник "Номенклатура" (Общие))', 'Наименование для печати',
#        'Единица измерения веса',
#        'Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))',
#        'Кол-во ДК (Справочник "Номенклатура" (Общие))',
#        'Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))', 'Группы',
#        'родитель1_1c', 'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
#        'родитель5_1c', 'Количество конечный остаток', 'Конечный остаток вес',
#        'розничная стоимость', 'закупочная стоимость', 'Штрихкод',
#        'Вставки корректировка', 'дата корректировки вставки',
#        'корректировка вставки была', 'Источник корректировки', 'Родитель1корр',
#        'Родитель2корр', 'Родитель3корр', 'Родитель4корр', 'Родитель5корр'],
#       dtype='object')

# %% [markdown]
# previos
# Index(['Unnamed: 0', 'Код', 'Старый код (Справочник "Номенклатура" (Общие))',
#        'Склад', 'Склад.Склад / Магазин',
#        'Вставки (Справочник "Номенклатура" (Общие))', 'Вид номенклатуры',
#        'Тип номенклатуры', 'Номенклатура', 'Группа',
#        'Заводской номер (Справочник "Номенклатура" (Общие))',
#        'Проба (Справочник "Номенклатура" (Общие))',
#        'Цвет металла (Справочник "Номенклатура" (Общие))',
#        'Дизайн (Справочник "Номенклатура" (Общие))', 'Артикул ',
#        'Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))',
#        'Цвет Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Чистота Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Размер (Справочник "Номенклатура" (Общие))', 'Наименование для печати',
#        'Единица измерения веса',
#        'Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))',
#        'Кол-во ДК (Справочник "Номенклатура" (Общие))',
#        'Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))', 'Группы',
#        'родитель1_1c', 'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
#        'родитель5_1c', 'Количество конечный остаток', 'Конечный остаток вес',
#        'розничная стоимость', 'закупочная стоимость', 'Штрихкод',
#        'Вставки корректировка', 'корректировка вставки была', 'Родитель1корр',
#        'Родитель2корр', 'Родитель3корр', 'Родитель4корр', 'Родитель5корр',
#        'Серия номенклатуры.Характеристика номенклатуры.Полное наименование'],
#       dtype='object')

# %%
len(df0['Код'].unique()),len(df0)
# Out:
# (34269, 34269)

# %% [markdown]
# ## Раздел удален в del тк уже подключены корректированные вствки и штрих код без 223 нераспознанных

# %% [markdown]
# # Расчет прейскуранта вставок ДК

# %% [markdown]
# ## Подготовка файла для прогонки прейскуранта df1 - урезанный файл для прогонки прейскуранта

# %%
df0.columns
#'Код','Артикул ','Номенклатура', 'Вставки'
# Out:
# Index(['Unnamed: 0', 'Код', 'Старый код (Справочник "Номенклатура" (Общие))',
#        'Склад', 'Склад.Склад / Магазин',
#        'Вставки (Справочник "Номенклатура" (Общие))', 'Вид номенклатуры',
#        'Тип номенклатуры', 'Номенклатура', 'Группа',
#        'Заводской номер (Справочник "Номенклатура" (Общие))',
#        'Проба (Справочник "Номенклатура" (Общие))',
#        'Цвет металла (Справочник "Номенклатура" (Общие))',
#        'Дизайн (Справочник "Номенклатура" (Общие))', 'Артикул ',
#        'Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))',
#        'Цвет Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Чистота Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Размер (Справочник "Номенклатура" (Общие))', 'Наименование для печати',
#        'Единица измерения веса',
#        'Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))',
#        'Кол-во ДК (Справочник "Номенклатура" (Общие))',
#        'Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))', 'Группы',
#        'родитель1_1c', 'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
#        'родитель5_1c', 'Количество конечный остаток', 'Конечный остаток вес',
#        'розничная стоимость', 'закупочная стоимость', 'Штрихкод',
#        'Вставки корректировка', 'дата корректировки вставки',
#        'корректировка вставки была', 'Источник корректировки', 'Родитель1корр',
#        'Родитель2корр', 'Родитель3корр', 'Родитель4корр', 'Родитель5корр'],
#       dtype='object')

# %%
len(df0['Штрихкод'].unique()) - len(df0)
# Out:
# 0

# %%
(df0['Штрихкод'].isna()).sum()
# Out:
# 0

# %%
#устарел
#df0.rename(columns={'Серия номенклатуры.Характеристика номенклатуры.Полное наименование':'Вставки из ЮТД'}, inplace=True)

# %% [markdown]
# было
# Index(['Unnamed: 0', 'Код', 'Старый код (Справочник "Номенклатура" (Общие))',
#        'Склад', 'Склад.Склад / Магазин',
#        'Вставки (Справочник "Номенклатура" (Общие))', 'Вид номенклатуры',
#        'Тип номенклатуры', 'Номенклатура', 'Группа',
#        'Заводской номер (Справочник "Номенклатура" (Общие))',
#        'Проба (Справочник "Номенклатура" (Общие))',
#        'Цвет металла (Справочник "Номенклатура" (Общие))',
#        'Дизайн (Справочник "Номенклатура" (Общие))', 'Артикул ',
#        'Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))',
#        'Цвет Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Чистота Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Размер (Справочник "Номенклатура" (Общие))', 'Наименование для печати',
#        'Единица измерения веса',
#        'Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))',
#        'Кол-во ДК (Справочник "Номенклатура" (Общие))',
#        'Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))', 'Группы',
#        'родитель1_1c', 'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
#        'родитель5_1c', 'Количество конечный остаток', 'Конечный остаток вес',
#        'розничная стоимость', 'закупочная стоимость', 'Вставки', 'Штрихкод',
#        'Старый код', 'Родитель1', 'Родитель2', 'Родитель3', 'Родитель4',
#        'Родитель5', 'Вставки корректировка 22-09-2023'],
#       dtype='object')

# %%
#проверка соответствия полей перед подготовкой таблицы для прогонки прейскуранта (df1 df0 - оригинал склада)
cols_df1 =  ['Code','art','name', 'vstavki']
cols_num_df1 = ['Код','Артикул ','Номенклатура', 'Вставки корректировка']
for i,c in enumerate(cols_num_df1):
    print(f'Столбец {c} - {cols_df1[i]} \n',df0[c].unique()[:10],end='\n\n')
# Out:
# Столбец Код - Code
#  ['ЦБ-00200503' 'ЦБ-00002854' 'ЦБ-00019951' 'ЦБ-00019953' 'ЦБ-00111074'
#  'ЦБ-00182982' 'ЦБ-00183328' 'ЦБ-00019967' 'ЦБ-00019969' 'ЦБ-00019974']
#
# Столбец Артикул  - art
#  ['JGN00840HGAWX13CH' 'Exl Ш.Н.' '1БШ0140' '515006' '15515144' '2БШ0168'
#  '2БШ0378' '14005228' '14005230' '14005229']
#
# Столбец Номенклатура - name
#  ['Браслет' 'Брошь' 'брошь' 'Зажим' 'Колье' 'Кольцо' 'кольцо'
#  'Кольцо (Двойное)' 'Подвеска' 'Серьги']
#
# Столбец Вставки корректировка - vstavki
#  ['45КР57-0,520-4/5А'
#  '2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-2/2А 3Кр57-0,095-3/2А'
#  '1Кр57-0,086-4/5А' '3Кр57-0,06-4/5А'
#  '1Кр57-0,050-4/5А 1Кр57-0,031-6/6А 1Кр57-0,014-6/6А 4Кр57-0,027-3/5А 6Кр57-0,017-3/6А'
#  '12КР57-0,117-2/4А' 'Жемчуг*Белый 1КР57-0,051-1/4А 6КР57-0,070-2/2А'
#  '2Кр57-0,09-5/8А' '1Кр57-0,11-7/9А' '2Кр57-0,009-2/4А']

# %%
(df0['Вставки корректировка'].isna()).sum()
# Out:
# 0

# %%
df1 = df0[cols_num_df1].copy()

# %%
df1.columns = cols_df1

# %%
df1
# Out:
#               Code                art         name  \
# 0      ЦБ-00200503  JGN00840HGAWX13CH      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 2      ЦБ-00019951            1БШ0140        Брошь
# 3      ЦБ-00019953             515006        Брошь
# 4      ЦБ-00111074           15515144        Брошь
# ...            ...                ...          ...
# 34264  ЦБ-00182016          121302193  серьги с ДК
# 34265  ЦБ-00182017          121302193  серьги с ДК
# 34266  ЦБ-00182019          121562193  серьги с ДК
# 34267  ЦБ-00182020          121562193  серьги с ДК
# 34268  ЦБ-00182021          121562193  серьги с ДК
#
#                                                  vstavki
# 0                                      45КР57-0,520-4/5А
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 2                                       1Кр57-0,086-4/5А
# 3                                        3Кр57-0,06-4/5А
# 4      1Кр57-0,050-4/5А 1Кр57-0,031-6/6А 1Кр57-0,014-...
# ...                                                  ...
# 34264                           СапфирВ 6КР57-0,080-3/4А
# 34265                           СапфирВ 6КР57-0,080-3/4А
# 34266                          ИзумрудВ 4КР57-0,040-2/3А
# 34267                          ИзумрудВ 4КР57-0,040-2/3А
# 34268                          ИзумрудВ 4КР57-0,040-2/3А
#
# [34269 rows x 4 columns]

# %% [markdown]
# ## Расчет прейскуранта для df1

# %%
patternD = r"""(?ix)(?P<N>\d*)[-_\s]*(?P<Form>[A-яA-z.]+[-\s]?\d*)[\s-]+    # штуки огранка
               (?P<Carat>\d\d?[.,]?\d*)[\s-]+                                 # карат
               (?P<ColQ>\d+[.-]?\d?[ /]+(?:7[aAаА]|\d\d?))[\s-]*           # ц/д
               (?P<PO>[aAаАбБвВгГbB]+)                                     # по"""

# %%
#df1['vs_dict'] = df1.vstavki.apply(lambda x: re.findall(patternD, x) if not pd.isna(x) else np.nan)
df1['vs_dict'] = df1.vstavki.apply(lambda x: re.findall(patternD, x) if not pd.isna(x) else np.nan)

# %%
df1
# Out:
#               Code                art         name  \
# 0      ЦБ-00200503  JGN00840HGAWX13CH      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 2      ЦБ-00019951            1БШ0140        Брошь
# 3      ЦБ-00019953             515006        Брошь
# 4      ЦБ-00111074           15515144        Брошь
# ...            ...                ...          ...
# 34264  ЦБ-00182016          121302193  серьги с ДК
# 34265  ЦБ-00182017          121302193  серьги с ДК
# 34266  ЦБ-00182019          121562193  серьги с ДК
# 34267  ЦБ-00182020          121562193  серьги с ДК
# 34268  ЦБ-00182021          121562193  серьги с ДК
#
#                                                  vstavki  \
# 0                                      45КР57-0,520-4/5А
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 2                                       1Кр57-0,086-4/5А
# 3                                        3Кр57-0,06-4/5А
# 4      1Кр57-0,050-4/5А 1Кр57-0,031-6/6А 1Кр57-0,014-...
# ...                                                  ...
# 34264                           СапфирВ 6КР57-0,080-3/4А
# 34265                           СапфирВ 6КР57-0,080-3/4А
# 34266                          ИзумрудВ 4КР57-0,040-2/3А
# 34267                          ИзумрудВ 4КР57-0,040-2/3А
# 34268                          ИзумрудВ 4КР57-0,040-2/3А
#
#                                                  vs_dict
# 0                            [(45, КР57, 0,520, 4/5, А)]
# 1      [(2, Кр57, 0,083, 2/2, А), (4, Кр57, 0,084, 2/...
# 2                             [(1, Кр57, 0,086, 4/5, А)]
# 3                              [(3, Кр57, 0,06, 4/5, А)]
# 4      [(1, Кр57, 0,050, 4/5, А), (1, Кр57, 0,031, 6/...
# ...                                                  ...
# 34264                         [(6, КР57, 0,080, 3/4, А)]
# 34265                         [(6, КР57, 0,080, 3/4, А)]
# 34266                         [(4, КР57, 0,040, 2/3, А)]
# 34267                         [(4, КР57, 0,040, 2/3, А)]
# 34268                         [(4, КР57, 0,040, 2/3, А)]
#
# [34269 rows x 5 columns]

# %%
df1.loc[(df1['vs_dict'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict]
# Index: []

# %%
df1_exp = df1.explode('vs_dict')

# %%
df1_exp
# Out:
#               Code                art         name  \
# 0      ЦБ-00200503  JGN00840HGAWX13CH      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# ...            ...                ...          ...
# 34264  ЦБ-00182016          121302193  серьги с ДК
# 34265  ЦБ-00182017          121302193  серьги с ДК
# 34266  ЦБ-00182019          121562193  серьги с ДК
# 34267  ЦБ-00182020          121562193  серьги с ДК
# 34268  ЦБ-00182021          121562193  серьги с ДК
#
#                                                  vstavki  \
# 0                                      45КР57-0,520-4/5А
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# ...                                                  ...
# 34264                           СапфирВ 6КР57-0,080-3/4А
# 34265                           СапфирВ 6КР57-0,080-3/4А
# 34266                          ИзумрудВ 4КР57-0,040-2/3А
# 34267                          ИзумрудВ 4КР57-0,040-2/3А
# 34268                          ИзумрудВ 4КР57-0,040-2/3А
#
#                          vs_dict
# 0      (45, КР57, 0,520, 4/5, А)
# 1       (2, Кр57, 0,083, 2/2, А)
# 1       (4, Кр57, 0,084, 2/2, А)
# 1       (6, Кр57, 0,280, 2/2, А)
# 1       (3, Кр57, 0,095, 3/2, А)
# ...                          ...
# 34264   (6, КР57, 0,080, 3/4, А)
# 34265   (6, КР57, 0,080, 3/4, А)
# 34266   (4, КР57, 0,040, 2/3, А)
# 34267   (4, КР57, 0,040, 2/3, А)
# 34268   (4, КР57, 0,040, 2/3, А)
#
# [51264 rows x 5 columns]

# %%
df1_exp_dia = df1_exp[~pd.isnull(df1_exp.vs_dict)].copy()

# %%
df1_exp_dia
# Out:
#               Code                art         name  \
# 0      ЦБ-00200503  JGN00840HGAWX13CH      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# ...            ...                ...          ...
# 34264  ЦБ-00182016          121302193  серьги с ДК
# 34265  ЦБ-00182017          121302193  серьги с ДК
# 34266  ЦБ-00182019          121562193  серьги с ДК
# 34267  ЦБ-00182020          121562193  серьги с ДК
# 34268  ЦБ-00182021          121562193  серьги с ДК
#
#                                                  vstavki  \
# 0                                      45КР57-0,520-4/5А
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# ...                                                  ...
# 34264                           СапфирВ 6КР57-0,080-3/4А
# 34265                           СапфирВ 6КР57-0,080-3/4А
# 34266                          ИзумрудВ 4КР57-0,040-2/3А
# 34267                          ИзумрудВ 4КР57-0,040-2/3А
# 34268                          ИзумрудВ 4КР57-0,040-2/3А
#
#                          vs_dict
# 0      (45, КР57, 0,520, 4/5, А)
# 1       (2, Кр57, 0,083, 2/2, А)
# 1       (4, Кр57, 0,084, 2/2, А)
# 1       (6, Кр57, 0,280, 2/2, А)
# 1       (3, Кр57, 0,095, 3/2, А)
# ...                          ...
# 34264   (6, КР57, 0,080, 3/4, А)
# 34265   (6, КР57, 0,080, 3/4, А)
# 34266   (4, КР57, 0,040, 2/3, А)
# 34267   (4, КР57, 0,040, 2/3, А)
# 34268   (4, КР57, 0,040, 2/3, А)
#
# [51223 rows x 5 columns]

# %%
cols = ["ШТУК","ОГРАНКА","КАРАТ", "ЦД", "ПО"]
for c in range(len(cols)):
    df1_exp_dia[cols[c]] = df1_exp_dia.vs_dict.apply(lambda x: x[c].strip())

# %%
df1_exp_dia['Ц'] = df1_exp_dia['ЦД'].apply(lambda x: x.split('/')[0].strip())
df1_exp_dia['Д'] = df1_exp_dia['ЦД'].apply(lambda x: x.split('/')[1].strip())

# %%
df1_exp_dia
# Out:
#               Code                art         name  \
# 0      ЦБ-00200503  JGN00840HGAWX13CH      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# ...            ...                ...          ...
# 34264  ЦБ-00182016          121302193  серьги с ДК
# 34265  ЦБ-00182017          121302193  серьги с ДК
# 34266  ЦБ-00182019          121562193  серьги с ДК
# 34267  ЦБ-00182020          121562193  серьги с ДК
# 34268  ЦБ-00182021          121562193  серьги с ДК
#
#                                                  vstavki  \
# 0                                      45КР57-0,520-4/5А
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# ...                                                  ...
# 34264                           СапфирВ 6КР57-0,080-3/4А
# 34265                           СапфирВ 6КР57-0,080-3/4А
# 34266                          ИзумрудВ 4КР57-0,040-2/3А
# 34267                          ИзумрудВ 4КР57-0,040-2/3А
# 34268                          ИзумрудВ 4КР57-0,040-2/3А
#
#                          vs_dict ШТУК ОГРАНКА  КАРАТ   ЦД ПО  Ц  Д
# 0      (45, КР57, 0,520, 4/5, А)   45    КР57  0,520  4/5  А  4  5
# 1       (2, Кр57, 0,083, 2/2, А)    2    Кр57  0,083  2/2  А  2  2
# 1       (4, Кр57, 0,084, 2/2, А)    4    Кр57  0,084  2/2  А  2  2
# 1       (6, Кр57, 0,280, 2/2, А)    6    Кр57  0,280  2/2  А  2  2
# 1       (3, Кр57, 0,095, 3/2, А)    3    Кр57  0,095  3/2  А  3  2
# ...                          ...  ...     ...    ...  ... .. .. ..
# 34264   (6, КР57, 0,080, 3/4, А)    6    КР57  0,080  3/4  А  3  4
# 34265   (6, КР57, 0,080, 3/4, А)    6    КР57  0,080  3/4  А  3  4
# 34266   (4, КР57, 0,040, 2/3, А)    4    КР57  0,040  2/3  А  2  3
# 34267   (4, КР57, 0,040, 2/3, А)    4    КР57  0,040  2/3  А  2  3
# 34268   (4, КР57, 0,040, 2/3, А)    4    КР57  0,040  2/3  А  2  3
#
# [51223 rows x 12 columns]

# %%
df1_exp_dia.dtypes
# Out:
# Code       object
# art        object
# name       object
# vstavki    object
# vs_dict    object
# ШТУК       object
# ОГРАНКА    object
# КАРАТ      object
# ЦД         object
# ПО         object
# Ц          object
# Д          object
# dtype: object

# %%
pd.options.display.max_colwidth = 100
#pd.set_option('display.float_format', '{:.2f}'.format)
#pd.options.display.max_columns = 30
#pd.options.display.max_rows = 500

# %% [markdown]
# ### Проверки (если есть, все решения перенесены в раздел DEL - Решения проблем)

# %%
df1_exp_dia.loc[~df1_exp_dia.ОГРАНКА.apply(lambda x: x in dogr_dia_discount),'ОГРАНКА'].unique()
# Out:
# array([], dtype=object)

# %%
df1_exp_dia['ШТУК'].unique()
# Out:
# array(['45', '2', '4', '6', '3', '1', '12', '5', '10', '7', '14', '32',
#        '20', '22', '44', '52', '28', '29', '46', '34', '60', '18', '42',
#        '82', '69', '97', '8', '56', '54', '27', '50', '62', '16', '26',
#        '25', '11', '9', '13', '15', '40', '24', '134', '48', '23', '21',
#        '36', '58', '19', '31', '38', '17', '30', '70', '80', '114', '90',
#        '84', '108', '68', '76', '140', '57', '35', '66', '33', '92',
#        '105', '59', '153', '43', '89', '74', '102', '64', '120', '75',
#        '53', '47', '67', '78', '39', '88', '49', '216', '209', '103',
#        '100', '83', '81', '401', '836', '99', '72', '86', '183', '41',
#        '590', '61', '55', '147', '65', '289', '51', '37', '87', '418',
#        '107', '106', '205', '119', '132', '262', '98', '137', '200',
#        '337', '63', '152', '136', '182', '194', '263', '91', '130', '131',
#        '171', '500', '178', '328', '241', '180', '160', '187', '85',
#        '157', '110', '71', '96', '361', '305', '273', '93', '113', '129',
#        '94', '112', '95', '164', '139', '166', '116', '73', '207', '115',
#        '148', '138', '124', '163', '141', '79', '400', '104', '142',
#        '165', '118', '128', '312', '125', '77', '167', '196', '229',
#        '534', '267', '257', '181', '370', '122', '254', '373', '224',
#        '367', '117', '206', '201', '371', '210', '635', '299', '162',
#        '324', '388', '154', '143', '170', '176', '204', '385', '150',
#        '175', '158', '285', '255', '230', '111', '353', '189', '121',
#        '264', '506', '431', '198', '236', '109', '321'], dtype=object)

# %%
df1_exp_dia[df1_exp_dia['ШТУК'] == '']
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д]
# Index: []

# %%
#Была проблема решена ниже
df1_exp_dia['ШТУК'] = df1_exp_dia['ШТУК'].astype('int')

# %%
#Была проблема решение ниже
df1_exp_dia.loc[~df1_exp_dia.ОГРАНКА.apply(lambda x: x in dogr_dia_discount)]
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д]
# Index: []

# %%
#

# %%
df1_exp_dia['КАРАТ'] = df1_exp_dia['КАРАТ'].str.replace(',','.').astype('float')

# %%
df1_exp_dia['СРКАРАТ'] = df1_exp_dia['КАРАТ']/df1_exp_dia['ШТУК']

# %%
df1_exp_dia.loc[df1_exp_dia['СРКАРАТ'] == 0, 'Code' ].to_list()
# Out:
# []

# %%
df1_exp_dia.sort_values('СРКАРАТ')
# Out:
#               Code                art      name  \
# 3632   ЦБ-00060721          JPF21740H  Подвеска
# 4563   ЦБ-00037398            DR10526    Кольцо
# 4261   ЦБ-00003006          1С011717П    Серьги
# 31057  ЦБ-00160970          Exc380С-и    Серьги
# 18030  ЦБ-00166155   17279BD322CL0725     Колье
# ...            ...                ...       ...
# 11578  ЦБ-00219606  JRZ855910GAWX13Q0    Кольцо
# 11575  ЦБ-00219603  JRZ857010GAWX13Q0    Кольцо
# 11549  ЦБ-00096401            Exc821К    Кольцо
# 11594  ЦБ-00219607  JPS159306GAWX13XX  Подвеска
# 11552  ЦБ-00096404            Exc421К    Кольцо
#
#                                                                                                    vstavki  \
# 3632                                                                                     21кр57-0,007-6/5А
# 4563                                                             ТопазГ 48КР57-0,020-4/5А 24КР57-0,18-4/5А
# 4261                                                                   2кр57-0,670-6/4А 16кр57-0,0070-3/5А
# 31057                                                                                   134КР57-0,064-2/4А
# 18030                                                                                    13Кр57-0,007-3/3А
# ...                                                                                                    ...
# 11578                               1МодИ-8,010-4/7А 44Кр57-0,410-5/5А 52Кр57-0,330-5/5А 24Кр57-0,280-5/5А
# 11575                            1МодРа-8,040-8-5/5А 32Кр57-0,540-5/5А 32Кр57-0,380-5/5А 16Кр57-0,160-5/5А
# 11549  1Овал-9,040-8-4/7А 10КР57-1,110-4/5А 1КР57-0,110-4/5Б 2КР57-0,240-4/5Б 2КР57-0,260-4/5Б 1КР57-0,...
# 11594                                                                 1МодУ-9,140-8-5/4А 22Кр57-0,660-5/5А
# 11552  1КР57-10,090-7/6А 11КР17-0,070-2/4А 4КР17-0,030-3/4А 1КР17-0,010-2/4В 1КР17-0,010-2/5В 2КР57-0,1...
#
#                            vs_dict  ШТУК ОГРАНКА   КАРАТ     ЦД ПО    Ц  Д  \
# 3632     (21, кр57, 0,007, 6/5, А)    21    кр57   0.007    6/5  А    6  5
# 4563     (48, КР57, 0,020, 4/5, А)    48    КР57   0.020    4/5  А    4  5
# 4261    (16, кр57, 0,0070, 3/5, А)    16    кр57   0.007    3/5  А    3  5
# 31057   (134, КР57, 0,064, 2/4, А)   134    КР57   0.064    2/4  А    2  4
# 18030    (13, Кр57, 0,007, 3/3, А)    13    Кр57   0.007    3/3  А    3  3
# ...                            ...   ...     ...     ...    ... ..  ... ..
# 11578     (1, МодИ, 8,010, 4/7, А)     1    МодИ   8.010    4/7  А    4  7
# 11575  (1, МодРа, 8,040, 8-5/5, А)     1   МодРа   8.040  8-5/5  А  8-5  5
# 11549   (1, Овал, 9,040, 8-4/7, А)     1    Овал   9.040  8-4/7  А  8-4  7
# 11594   (1, МодУ, 9,140, 8-5/4, А)     1    МодУ   9.140  8-5/4  А  8-5  4
# 11552    (1, КР57, 10,090, 7/6, А)     1    КР57  10.090    7/6  А    7  6
#
#          СРКАРАТ
# 3632    0.000333
# 4563    0.000417
# 4261    0.000438
# 31057   0.000478
# 18030   0.000538
# ...          ...
# 11578   8.010000
# 11575   8.040000
# 11549   9.040000
# 11594   9.140000
# 11552  10.090000
#
# [51223 rows x 13 columns]

# %%
#ручное решение на основе другого файла и сообщения Жмурова
#df1_exp_dia.loc[4985, ['КАРАТ','Code']]

# %%
#df1_exp_dia.loc[4985, 'КАРАТ'] = 0.5

# %%
#i_corr = _
#i_corr
# Out:
# 25431

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict']]

# %%
#Корректировка 
#df1_exp_dia.loc[i_corr, 'КАРАТ'] = 0.05

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict']]

# %%
df1_exp_dia.dtypes
# Out:
# Code        object
# art         object
# name        object
# vstavki     object
# vs_dict     object
# ШТУК         int32
# ОГРАНКА     object
# КАРАТ      float64
# ЦД          object
# ПО          object
# Ц           object
# Д           object
# СРКАРАТ    float64
# dtype: object

# %%
#проверка по полю вида огранки.
df1_exp_dia.loc[~df1_exp_dia.ОГРАНКА.apply(lambda x: x in dogr_dia_discount)]
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д, СРКАРАТ]
# Index: []

# %% [markdown]
# ### Корректировка c = 'Д',

# %%
c = 'Д'
df1_exp_dia[c].unique()
# Out:
# array(['5', '2', '6', '4', '8', '9', '7', '3', '1', '7а', '7A', '10',
#        '11', '12', '7А'], dtype=object)

# %%
df1_exp_dia[df1_exp_dia[c]=='']
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д, СРКАРАТ]
# Index: []

# %%
#i_corr = _.index
#i_corr

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict',c]]

# %%
#Корректировка
#df1_exp_dia.loc[i_corr, c] = '5'

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict', c]]

# %% [markdown]
# ### Корректировка c = 'ПО', АА

# %%
c = 'ПО'

df1_exp_dia[c].unique()
# Out:
# array(['А', 'Б', 'Г', 'В', 'а', 'б', 'в'], dtype=object)

# %%
df1_exp_dia[df1_exp_dia[c]=='АА']
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д, СРКАРАТ]
# Index: []

# %%
#i_corr = _.index
#i_corr

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict',c]]

# %%
#Корректировка
#df1_exp_dia.loc[i_corr, c] = 'А'

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict', c]]

# %% [markdown]
# ### Корректировка c = 'Ц', 8

# %%
c = 'Ц'
df1_exp_dia[c].unique()
# Out:
# array(['4', '2', '3', '6', '1', '5', '7', '8-2', '8-5', '9-1', '8-1',
#        '9-2', '6-1', '8-3', '9-4', '9-3', '8-4', '8.5'], dtype=object)

# %%
df1_exp_dia[df1_exp_dia[c]=='8']
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д, СРКАРАТ]
# Index: []

# %%
#i_corr = _.index
#i_corr

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict',c]]

# %%
#Корректировка
#df1_exp_dia.loc[i_corr, c] = '8-2'

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict', c]]

# %% [markdown]
# ### Корректировка c = 'ШТУК'

# %%
c = 'ШТУК'
df1_exp_dia[c].unique()
# Out:
# array([ 45,   2,   4,   6,   3,   1,  12,   5,  10,   7,  14,  32,  20,
#         22,  44,  52,  28,  29,  46,  34,  60,  18,  42,  82,  69,  97,
#          8,  56,  54,  27,  50,  62,  16,  26,  25,  11,   9,  13,  15,
#         40,  24, 134,  48,  23,  21,  36,  58,  19,  31,  38,  17,  30,
#         70,  80, 114,  90,  84, 108,  68,  76, 140,  57,  35,  66,  33,
#         92, 105,  59, 153,  43,  89,  74, 102,  64, 120,  75,  53,  47,
#         67,  78,  39,  88,  49, 216, 209, 103, 100,  83,  81, 401, 836,
#         99,  72,  86, 183,  41, 590,  61,  55, 147,  65, 289,  51,  37,
#         87, 418, 107, 106, 205, 119, 132, 262,  98, 137, 200, 337,  63,
#        152, 136, 182, 194, 263,  91, 130, 131, 171, 500, 178, 328, 241,
#        180, 160, 187,  85, 157, 110,  71,  96, 361, 305, 273,  93, 113,
#        129,  94, 112,  95, 164, 139, 166, 116,  73, 207, 115, 148, 138,
#        124, 163, 141,  79, 400, 104, 142, 165, 118, 128, 312, 125,  77,
#        167, 196, 229, 534, 267, 257, 181, 370, 122, 254, 373, 224, 367,
#        117, 206, 201, 371, 210, 635, 299, 162, 324, 388, 154, 143, 170,
#        176, 204, 385, 150, 175, 158, 285, 255, 230, 111, 353, 189, 121,
#        264, 506, 431, 198, 236, 109, 321])

# %%
#df1_exp_dia[df1_exp_dia[c]==5657]

# %%
#i_corr = _.index
#i_corr

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_d
# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict',c]]

# %%
#Корректировка
#df1_exp_dia.loc[i_corr, c] = 56

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict', c]]

# %%
#Была проблема решена ниже
df1_exp_dia['ШТУК'] = df1_exp_dia['ШТУК'].astype('int')

# %%
#Была проблема решение ниже
df1_exp_dia.loc[~df1_exp_dia.ОГРАНКА.apply(lambda x: x in dogr_dia_discount)]
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д, СРКАРАТ]
# Index: []

# %% [markdown]
# # Прогон прейскуранта на урезанном файле результат - diamonds

# %%
diamonds = func_rpdiamonds_v2.rpdiamonds(df1_exp_dia)
# Out:
# []
# []
# []
# []
# 0.0003333333333333333  - 10.09
# не сработал прейскурант на этих строках:
#           ШТУК ОГРАНКА  КАРАТ ПО    Ц  Д  СРКАРАТ  Col  Cla Po  ogrdisc  \
# 19048     1    Овал   9.04  А  8-4  7     9.04  8.4  7.0  А     Овал
# 19058     1    КР57  10.09  А    7  6    10.09  7.0  6.0  А    Кр-57
# 19067     1    КР57   8.01  А  8-4  5     8.01  8.4  5.0  А    Кр-57
# 19075     1    КР57   8.00  А  8-4  7     8.00  8.4  7.0  А    Кр-57
# 19155     1    МодГ   7.28  А    6  8     7.28  6.0  8.0  А     Г-56
# 19167     1   МодРа   8.04  А  8-5  5     8.04  8.5  5.0  А  Радиант
# 19177     1    МодИ   8.01  А    4  7     8.01  4.0  7.0  А     И-57
# 19210     1    Кр57   6.16  А  8-4  6     6.16  8.4  6.0  А    Кр-57
# 19258     1    МодУ   9.14  А  8-5  4     9.14  8.5  4.0  А   Сердце
#
#                Grp  discont_po ogrbasic  Pr2022  ogrdiscount  prpr  prcost
# 19048    9.00-9.24         1.0    Кр-57     NaN          NaN   NaN     NaN
# 19058  10.00-10.24         1.0    Кр-57     NaN          NaN   NaN     NaN
# 19067    8.00-8.24         1.0    Кр-57     NaN          NaN   NaN     NaN
# 19075    8.00-8.24         1.0    Кр-57     NaN          NaN   NaN     NaN
# 19155    7.25-7.49         1.0    Кр-57     NaN          NaN   NaN     NaN
# 19167    8.00-8.24         1.0    Кр-57     NaN          NaN   NaN     NaN
# 19177    8.00-8.24         1.0    Кр-57     NaN          NaN   NaN     NaN
# 19210    6.00-6.24         1.0    Кр-57     NaN          1.0   NaN     NaN
# 19258    9.00-9.24         1.0    Кр-57     NaN          0.6   NaN     NaN

# %% [markdown]
# ## Сохранение результата diamonds - для построчной проверки сработки прейскуранта

# %%
#'/'.join(folder.split('/')[:-2])

# %%
folder_res
# Out:
# '../for_script24-10-2023/'

# %%
filename.split('.')[:-1][0]
# Out:
# 'выгрузка15-10-2023_все_склады_ДК_31-10-2023_09-29'

# %%
_[:-16]
# Out:
# 'выгрузка15-10-2023_все_склады_ДК_'

# %%
filename = _

# %%
filename
# Out:
# 'выгрузка15-10-2023_все_склады_ДК_'

# %%
filename_for_diamonds = filename+'_'+datetime.datetime.now().strftime('%d-%m-%Y_%H-%M')+'_diamonds.xlsx'
filename_for_diamonds
# Out:
# 'выгрузка15-10-2023_все_склады_ДК__31-10-2023_09-38_diamonds.xlsx'

# %%
folder_res+filename_for_diamonds
# Out:
# '../for_script24-10-2023/выгрузка15-10-2023_все_склады_ДК__31-10-2023_09-38_diamonds.xlsx'

# %%
diamonds.to_excel(_)

# %%
#Проверки

# %%
diamonds.loc[(diamonds.prcost.isna())|(diamonds.prpr.isna())]
# Out:
#               Code                art      name  \
# 19048  ЦБ-00096401            Exc821К    Кольцо
# 19058  ЦБ-00096404            Exc421К    Кольцо
# 19067  ЦБ-00096406            Exc321К    Кольцо
# 19075  ЦБ-00096409            Exc221К    Кольцо
# 19155  ЦБ-00219598  JRZ858310GAWX13Q0    Кольцо
# 19167  ЦБ-00219603  JRZ857010GAWX13Q0    Кольцо
# 19177  ЦБ-00219606  JRZ855910GAWX13Q0    Кольцо
# 19210  ЦБ-00219615  JRZ85801EGAWX13Q0    Кольцо
# 19258  ЦБ-00219607  JPS159306GAWX13XX  Подвеска
#
#                                                                                                    vstavki  \
# 19048  1Овал-9,040-8-4/7А 10КР57-1,110-4/5А 1КР57-0,110-4/5Б 2КР57-0,240-4/5Б 2КР57-0,260-4/5Б 1КР57-0,...
# 19058  1КР57-10,090-7/6А 11КР17-0,070-2/4А 4КР17-0,030-3/4А 1КР17-0,010-2/4В 1КР17-0,010-2/5В 2КР57-0,1...
# 19067                                                                 1КР57-8,010-8-4/5А 20КР57-1,170-3/2А
# 19075                                                1КР57-8,000-8-4/7А 21КР17-0,170-3/4А 7КР17-0,050-3/4В
# 19155                                                 1МодГ-7,280-6/8А 34Кр57-0,760-5/5А 12Кр57-0,300-5/5А
# 19167                            1МодРа-8,040-8-5/5А 32Кр57-0,540-5/5А 32Кр57-0,380-5/5А 16Кр57-0,160-5/5А
# 19177                               1МодИ-8,010-4/7А 44Кр57-0,410-5/5А 52Кр57-0,330-5/5А 24Кр57-0,280-5/5А
# 19210  1Кр57-6,160-8-4/6А 1Кр57-0,110-1/4Б 3Кр57-0,380-3/5Б 2Кр57-0,260-3/2А 8Кр57-0,300-5/5А 18Кр57-0,...
# 19258                                                                 1МодУ-9,140-8-5/4А 22Кр57-0,660-5/5А
#
#                            vs_dict  ШТУК ОГРАНКА  КАРАТ     ЦД ПО  ...  Cla  \
# 19048   (1, Овал, 9,040, 8-4/7, А)     1    Овал   9.04  8-4/7  А  ...  7.0
# 19058    (1, КР57, 10,090, 7/6, А)     1    КР57  10.09    7/6  А  ...  6.0
# 19067   (1, КР57, 8,010, 8-4/5, А)     1    КР57   8.01  8-4/5  А  ...  5.0
# 19075   (1, КР57, 8,000, 8-4/7, А)     1    КР57   8.00  8-4/7  А  ...  7.0
# 19155     (1, МодГ, 7,280, 6/8, А)     1    МодГ   7.28    6/8  А  ...  8.0
# 19167  (1, МодРа, 8,040, 8-5/5, А)     1   МодРа   8.04  8-5/5  А  ...  5.0
# 19177     (1, МодИ, 8,010, 4/7, А)     1    МодИ   8.01    4/7  А  ...  7.0
# 19210   (1, Кр57, 6,160, 8-4/6, А)     1    Кр57   6.16  8-4/6  А  ...  6.0
# 19258   (1, МодУ, 9,140, 8-5/4, А)     1    МодУ   9.14  8-5/4  А  ...  4.0
#
#       Po  ogrdisc          Grp  discont_po ogrbasic Pr2022 ogrdiscount  prpr  \
# 19048  А     Овал    9.00-9.24         1.0    Кр-57    NaN         NaN   NaN
# 19058  А    Кр-57  10.00-10.24         1.0    Кр-57    NaN         NaN   NaN
# 19067  А    Кр-57    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19075  А    Кр-57    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19155  А     Г-56    7.25-7.49         1.0    Кр-57    NaN         NaN   NaN
# 19167  А  Радиант    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19177  А     И-57    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19210  А    Кр-57    6.00-6.24         1.0    Кр-57    NaN         1.0   NaN
# 19258  А   Сердце    9.00-9.24         1.0    Кр-57    NaN         0.6   NaN
#
#       prcost
# 19048    NaN
# 19058    NaN
# 19067    NaN
# 19075    NaN
# 19155    NaN
# 19167    NaN
# 19177    NaN
# 19210    NaN
# 19258    NaN
#
# [9 rows x 24 columns]

# %% [markdown]
# ## !Сохранение списка ЦБ где не сработал прейскурант zb_of_pr_is0

# %%
diamonds.loc[(diamonds.prcost.isna())|(diamonds.prpr.isna())]
# Out:
#               Code                art      name  \
# 19048  ЦБ-00096401            Exc821К    Кольцо
# 19058  ЦБ-00096404            Exc421К    Кольцо
# 19067  ЦБ-00096406            Exc321К    Кольцо
# 19075  ЦБ-00096409            Exc221К    Кольцо
# 19155  ЦБ-00219598  JRZ858310GAWX13Q0    Кольцо
# 19167  ЦБ-00219603  JRZ857010GAWX13Q0    Кольцо
# 19177  ЦБ-00219606  JRZ855910GAWX13Q0    Кольцо
# 19210  ЦБ-00219615  JRZ85801EGAWX13Q0    Кольцо
# 19258  ЦБ-00219607  JPS159306GAWX13XX  Подвеска
#
#                                                                                                    vstavki  \
# 19048  1Овал-9,040-8-4/7А 10КР57-1,110-4/5А 1КР57-0,110-4/5Б 2КР57-0,240-4/5Б 2КР57-0,260-4/5Б 1КР57-0,...
# 19058  1КР57-10,090-7/6А 11КР17-0,070-2/4А 4КР17-0,030-3/4А 1КР17-0,010-2/4В 1КР17-0,010-2/5В 2КР57-0,1...
# 19067                                                                 1КР57-8,010-8-4/5А 20КР57-1,170-3/2А
# 19075                                                1КР57-8,000-8-4/7А 21КР17-0,170-3/4А 7КР17-0,050-3/4В
# 19155                                                 1МодГ-7,280-6/8А 34Кр57-0,760-5/5А 12Кр57-0,300-5/5А
# 19167                            1МодРа-8,040-8-5/5А 32Кр57-0,540-5/5А 32Кр57-0,380-5/5А 16Кр57-0,160-5/5А
# 19177                               1МодИ-8,010-4/7А 44Кр57-0,410-5/5А 52Кр57-0,330-5/5А 24Кр57-0,280-5/5А
# 19210  1Кр57-6,160-8-4/6А 1Кр57-0,110-1/4Б 3Кр57-0,380-3/5Б 2Кр57-0,260-3/2А 8Кр57-0,300-5/5А 18Кр57-0,...
# 19258                                                                 1МодУ-9,140-8-5/4А 22Кр57-0,660-5/5А
#
#                            vs_dict  ШТУК ОГРАНКА  КАРАТ     ЦД ПО  ...  Cla  \
# 19048   (1, Овал, 9,040, 8-4/7, А)     1    Овал   9.04  8-4/7  А  ...  7.0
# 19058    (1, КР57, 10,090, 7/6, А)     1    КР57  10.09    7/6  А  ...  6.0
# 19067   (1, КР57, 8,010, 8-4/5, А)     1    КР57   8.01  8-4/5  А  ...  5.0
# 19075   (1, КР57, 8,000, 8-4/7, А)     1    КР57   8.00  8-4/7  А  ...  7.0
# 19155     (1, МодГ, 7,280, 6/8, А)     1    МодГ   7.28    6/8  А  ...  8.0
# 19167  (1, МодРа, 8,040, 8-5/5, А)     1   МодРа   8.04  8-5/5  А  ...  5.0
# 19177     (1, МодИ, 8,010, 4/7, А)     1    МодИ   8.01    4/7  А  ...  7.0
# 19210   (1, Кр57, 6,160, 8-4/6, А)     1    Кр57   6.16  8-4/6  А  ...  6.0
# 19258   (1, МодУ, 9,140, 8-5/4, А)     1    МодУ   9.14  8-5/4  А  ...  4.0
#
#       Po  ogrdisc          Grp  discont_po ogrbasic Pr2022 ogrdiscount  prpr  \
# 19048  А     Овал    9.00-9.24         1.0    Кр-57    NaN         NaN   NaN
# 19058  А    Кр-57  10.00-10.24         1.0    Кр-57    NaN         NaN   NaN
# 19067  А    Кр-57    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19075  А    Кр-57    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19155  А     Г-56    7.25-7.49         1.0    Кр-57    NaN         NaN   NaN
# 19167  А  Радиант    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19177  А     И-57    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19210  А    Кр-57    6.00-6.24         1.0    Кр-57    NaN         1.0   NaN
# 19258  А   Сердце    9.00-9.24         1.0    Кр-57    NaN         0.6   NaN
#
#       prcost
# 19048    NaN
# 19058    NaN
# 19067    NaN
# 19075    NaN
# 19155    NaN
# 19167    NaN
# 19177    NaN
# 19210    NaN
# 19258    NaN
#
# [9 rows x 24 columns]

# %%
index_of_pr_is0 = _.index
index_of_pr_is0
# Out:
# Int64Index([19048, 19058, 19067, 19075, 19155, 19167, 19177, 19210, 19258], dtype='int64')

# %%
#Обнуление прейскуранта других брилл в иделии

# %%
#Код ЦБ для изделий где не сработал прейскурант
zb_of_pr_is0 = set(diamonds.loc[index_of_pr_is0,'Code'])

# %%
#diamonds.loc[diamonds['Code'].isin(zb_of_pr_is0),['prcost', 'prpr']] = 0,0

# %%
# 19067                                                                 1КР57-8,010-8-4/5А 20КР57-1,170-3/2А
# 19075                                                1КР57-8,000-8-4/7А 21КР17-0,170-3/4А 7КР17-0,050-3/4В
# 19155                                                 1МодГ-7,280-6/8А 34Кр57-0,760-5/5А 12Кр57-0,300-5/5А
# 19167                            1МодРа-8,040-8-5/5А 32Кр57-0,540-5/5А 32Кр57-0,380-5/5А 16Кр57-0,160-5/5А
# 19177                               1МодИ-8,010-4/7А 44Кр57-0,410-5/5А 52Кр57-0,330-5/5А 24Кр57-0,280-5/5А
# 19210  1Кр57-6,160-8-4/6А 1Кр57-0,110-1/4Б 3Кр57-0,380-3/5Б 2Кр57-0,260-3/2А 8Кр57-0,300-5/5А 18Кр57-0,...
# 19258                                                                 1МодУ-9,140-8-5/4А 22Кр57-0,660-5/5А
#
#                            vs_dict  ШТУК ОГРАНКА  КАРАТ     ЦД ПО  ...  Cla  \
# 19048   (1, Овал, 9,040, 8-4/7, А)     1    Овал   9.04  8-4/7  А  ...  7.0
# 19058    (1, КР57, 10,090, 7/6, А)     1    КР57  10.09    7/6  А  ...  6.0
# 19067   (1, КР57, 8,010, 8-4/5, А)     1    КР57   8.01  8-4/5  А  ...  5.0
# 19075   (1, КР57, 8,000, 8-4/7, А)     1    КР57   8.00  8-4/7  А  ...  7.0
# 19155     (1, МодГ, 7,280, 6/8, А)     1    МодГ   7.28    6/8  А  ...  8.0
# 19167  (1, МодРа, 8,040, 8-5/5, А)     1   МодРа   8.04  8-5/5  А  ...  5.0
# 19177     (1, МодИ, 8,010, 4/7, А)     1    МодИ   8.01    4/7  А  ...  7.0
# 19210   (1, Кр57, 6,160, 8-4/6, А)     1    Кр57   6.16  8-4/6  А  ...  6.0
# 19258   (1, МодУ, 9,140, 8-5/4, А)     1    МодУ   9.14  8-5/4  А  ...  4.0
#
#       Po  ogrdisc          Grp  discont_po ogrbasic Pr2022 ogrdiscount  prpr  \
# 19048  А     Овал    9.00-9.24         1.0    Кр-57    NaN         NaN   NaN
# 19058  А    Кр-57  10.00-10.24         1.0    Кр-57    NaN         NaN   NaN
# 19067  А    Кр-57    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19075  А    Кр-57    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19155  А     Г-56    7.25-7.49         1.0    Кр-57    NaN         NaN   NaN
# 19167  А  Радиант    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19177  А     И-57    8.00-8.24         1.0    Кр-57    NaN         NaN   NaN
# 19210  А    Кр-57    6.00-6.24         1.0    Кр-57    NaN         1.0   NaN
# 19258  А   Сердце    9.00-9.24         1.0    Кр-57    NaN         0.6   NaN
#
#       prcost
# 19048    NaN
# 19058    NaN
# 19067    NaN
# 19075    NaN
# 19155    NaN
# 19167    NaN
# 19177    NaN
# 19210    NaN
# 19258    NaN
#
# [9 rows x 24 columns]

# %%
#diamonds.loc[(diamonds.prcost.isna())|(diamonds.prpr.isna()),'не сработал прейскурант'] = 'не сработал прейскурант на свыше 6 карат'

# %%
#diamonds.loc[diamonds['не сработал прейскурант']=='не сработал прейскурант на свыше 6 карат']

# %%
#diamonds.loc[(diamonds.prcost < 10)]

# %%
diamonds.columns
# Out:
# Index(['Code', 'art', 'name', 'vstavki', 'vs_dict', 'ШТУК', 'ОГРАНКА', 'КАРАТ',
#        'ЦД', 'ПО', 'Ц', 'Д', 'СРКАРАТ', 'Col', 'Cla', 'Po', 'ogrdisc', 'Grp',
#        'discont_po', 'ogrbasic', 'Pr2022', 'ogrdiscount', 'prpr', 'prcost'],
#       dtype='object')

# %%
diamonds['vs_dict'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## !Сохранение списка ЦБ где не есть камни свыше 1.5 карат для индивидуальной работы с ценами бриллиантов zb_of_1-50ct

# %%
diamonds.loc[(diamonds['СРКАРАТ']>1.5)& ~(diamonds.prcost.isna())|(diamonds.prpr.isna())]
# Out:
#               Code              art    name  \
# 1646   ЦБ-00160591  ЗКР 0915BGu46-7   Колье
# 2799   ЦБ-00021768   YR3717W 1 каст  кольцо
# 2862   ЦБ-00160610       ЗКР WW2685  Кольцо
# 2924   ЦБ-00166062          YR3703P  Кольцо
# 4565   ЦБ-00040276          YR3714W  Кольцо
# ...            ...              ...     ...
# 24353  ЦБ-00163814        213218501  Серьги
# 24354  ЦБ-00163814        213218501  Серьги
# 29886  ЦБ-00105948           007231   Колье
# 35492  ЦБ-00163713        Exl Ф.Мак  Кольцо
# 46952  ЦБ-00161279          YJ7656W  Серьги
#
#                                                                                       vstavki  \
# 1646                                                     1КР57-2,080-8-3/8А 31КР57-0,410-4/5А
# 2799                                                                         1КР57-1,510-5/8А
# 2862                                                     1КР57-1,750-8-3/8А 52КР57-0,530-4/6А
# 2924                                                        1Кр57-1,680-5/9Б 8Кр57-0,790-2/4А
# 4565                      28кр57-0,23-4/6А 1кр57-1,59-7/11Б 65кр57-0,69-4/6А 44кр57-1,02-4/7А
# ...                                                                                       ...
# 24353                            Жемчуг*Белый Жемчуг*Черный 1Кр57-1,750-4/8А 1Кр57-1,750-4/7А
# 24354                            Жемчуг*Белый Жемчуг*Черный 1Кр57-1,750-4/8А 1Кр57-1,750-4/7А
# 29886  1Гр-2,020-7/6А 14Кр57-0,250-2/2А 2Кр57-0,140-3/5А 38Кр57-0,570-3/2А 110Кр57-2,290-3/3А
# 35492                                      1Пр-2,200-8-1/6А 8Кр57-0,125-2/2А 4Кр57-0,035-3/2А
# 46952                                                        92КР57-1,480-3/5А 1ПР-1,600-5/5А
#
#                           vs_dict  ШТУК ОГРАНКА  КАРАТ     ЦД ПО  ...   Cla  \
# 1646   (1, КР57, 2,080, 8-3/8, А)     1    КР57   2.08  8-3/8  А  ...   8.0
# 2799     (1, КР57, 1,510, 5/8, А)     1    КР57   1.51    5/8  А  ...   8.0
# 2862   (1, КР57, 1,750, 8-3/8, А)     1    КР57   1.75  8-3/8  А  ...   8.0
# 2924     (1, Кр57, 1,680, 5/9, Б)     1    Кр57   1.68    5/9  Б  ...   9.0
# 4565     (1, кр57, 1,59, 7/11, Б)     1    кр57   1.59   7/11  Б  ...  11.0
# ...                           ...   ...     ...    ...    ... ..  ...   ...
# 24353    (1, Кр57, 1,750, 4/8, А)     1    Кр57   1.75    4/8  А  ...   8.0
# 24354    (1, Кр57, 1,750, 4/7, А)     1    Кр57   1.75    4/7  А  ...   7.0
# 29886      (1, Гр, 2,020, 7/6, А)     1      Гр   2.02    7/6  А  ...   6.0
# 35492    (1, Пр, 2,200, 8-1/6, А)     1      Пр   2.20  8-1/6  А  ...   6.0
# 46952      (1, ПР, 1,600, 5/5, А)     1      ПР   1.60    5/5  А  ...   5.0
#
#       Po  ogrdisc        Grp  discont_po ogrbasic  Pr2022 ogrdiscount    prpr  \
# 1646   А    Кр-57  2.00-2.24        1.00    Кр-57  2620.0        1.00  2620.0
# 2799   А    Кр-57  1.50-1.74        1.00    Кр-57  4100.0        1.00  4100.0
# 2862   А    Кр-57  1.75-1.99        1.00    Кр-57  2060.0        1.00  2060.0
# 2924   Б    Кр-57  1.50-1.74        0.85    Кр-57  3110.0        1.00  2644.0
# 4565   Б    Кр-57  1.50-1.74        0.85    Кр-57   920.0        1.00   782.0
# ...   ..      ...        ...         ...      ...     ...         ...     ...
# 24353  А    Кр-57  1.75-1.99        1.00    Кр-57  4480.0        1.00  4480.0
# 24354  А    Кр-57  1.75-1.99        1.00    Кр-57  6500.0        1.00  6500.0
# 29886  А     Г-56  2.00-2.24        1.00    Кр-57  5600.0        0.65  3640.0
# 35492  А    Принц  2.00-2.24        1.00    Кр-57  4700.0        0.65  3055.0
# 46952  А    Принц  1.50-1.74        1.00    Кр-57  6350.0        0.65  4128.0
#
#          prcost
# 1646    5449.60
# 2799    6191.00
# 2862    3605.00
# 2924    4441.92
# 4565    1243.38
# ...         ...
# 24353   7840.00
# 24354  11375.00
# 29886   7352.80
# 35492   6721.00
# 46952   6604.80
#
# [70 rows x 24 columns]

# %%
index_of_1_50ct = _.index
index_of_1_50ct
# Out:
# Int64Index([ 1646,  2799,  2862,  2924,  4565,  7321,  7322,  7537,  9101,
#              9102,  9119,  9120,  9122,  9123, 10556, 10558, 12276, 12975,
#             17316, 17551, 19023, 19045, 19048, 19054, 19056, 19058, 19067,
#             19069, 19075, 19078, 19082, 19086, 19092, 19097, 19104, 19113,
#             19123, 19129, 19136, 19142, 19155, 19160, 19163, 19167, 19171,
#             19174, 19177, 19194, 19201, 19205, 19210, 19220, 19227, 19233,
#             19252, 19258, 19263, 19266, 19348, 19350, 19631, 21551, 22623,
#             22624, 22625, 24353, 24354, 29886, 35492, 46952],
#            dtype='int64')

# %%
zb_of_1_50ct = set(diamonds.loc[index_of_1_50ct,'Code'])

# %%
len(zb_of_1_50ct)
# Out:
# 65

# %% [markdown]
# ## Добавление наличия ЦВ ДК

# %%
patternG3 = r'''(?ix)(\d*[-_\s]*[A-яA-z]{3,15}[\s-]+\d[.,]?\d*[\s-]+ \d\d?[ /]+\d\d?
                      | \d*[-_\s]*[A-яA-z]{3,15}[\s-]+\d{0,2}[.,]?\d{0,3}[\s-]+ [\d\w]{0,4}[ /]+[\d\w]{0,4}\s
                      |  \d{0,2}[-_\s]{0,2}[A-яA-z]{3,15}[\s-]?(?:\d{1,2}[.,]+\d{1,3})?)'''

# %%
patternG = r'''(?ix)(?P<Gem>[A-яA-z]{3,15})'''

# %%
df_gem = df0[['Код', 'Вставки корректировка']].copy(deep=True)

# %%
df_gem['gem'] = df_gem['Вставки корректировка'].apply(lambda x: re.findall(patternG
            , x) if not pd.isna(x) else '')

# %%
df_gem_explode = df_gem[df_gem['gem'].map(len)!=0].explode('gem')

# %%
gems = list(df_gem_explode.gem.unique())

# %%
pre_gems = set([x for x in gems if (x.lower().__contains__('сапф') or \
                     x.lower().__contains__('изум') or\
                     x.lower().__contains__('руби')) and\
                     not x.lower().__contains__('в')])

# %%
pre_gem_i = set(['НРОГ',
 'НРОКР',
 'НРОКв',
 'НРОКр',
 'НРООв',
 'НРООо',
 'НРОПр',
 'НРОФ',
 'НРОЧл',
 'НРОкр'])

# %%
set(gems) - pre_gems
# Out:
# {'Агат',
#  'АгатН',
#  'Аквамарин',
#  'Алексит',
#  'АлмазБорт',
#  'Алпанит',
#  'Альмандин',
#  'Аметист',
#  'АметистДруза',
#  'АметистЗ',
#  'АметистК',
#  'АметистН',
#  'АметистО',
#  'АметистФ',
#  'АметистЦветок',
#  'Аметистбриолет',
#  'Аокр',
#  'Багет',
#  'Белый',
#  'БелыйЧерный',
#  'Берилл',
#  'Бесцветный',
#  'Бивень',
#  'БивеньМамонта',
#  'Бирюза',
#  'Виол',
#  'Волосатик',
#  'ГФГ',
#  'Голубой',
#  'ГорныйХрусталь',
#  'Гранат',
#  'ГранатК',
#  'ГранатО',
#  'ГранатП',
#  'Груша',
#  'Дымчатый',
#  'Желтый',
#  'ЖелтыйЗеленый',
#  'Жемчуг',
#  'ЖемчугБ',
#  'ЖемчугК',
#  'ЖемчугР',
#  'ЖемчугС',
#  'ЖемчугТ',
#  'ЖемчугЧ',
#  'Зеленый',
#  'Зелёный',
#  'ИзмурудПМ',
#  'ИзумВ',
#  'ИзумрудВ',
#  'КУШЕН',
#  'Кбовв',
#  'Кварц',
#  'КварцДымчатый',
#  'КварцЗ',
#  'КварцС',
#  'КожаСката',
#  'Коралл',
#  'Коричневый',
#  'Корунд',
#  'КорундС',
#  'Крн',
#  'Кушен',
#  'Кушон',
#  'Лазурит',
#  'Лондон',
#  'ЛондонБлю',
#  'Маркиз',
#  'Мод',
#  'МодБп',
#  'МодГ',
#  'МодИ',
#  'МодМ',
#  'МодОв',
#  'МодП',
#  'МодРа',
#  'МодСе',
#  'МодУ',
#  'НВОРоза',
#  'НРОГ',
#  'НРОКР',
#  'НРОКв',
#  'НРОКр',
#  'НРООв',
#  'НРООо',
#  'НРОПр',
#  'НРОФ',
#  'НРОЧл',
#  'НРОкр',
#  'Овал',
#  'Окрашенный',
#  'Оникс',
#  'ОниксЛисток',
#  'Опал',
#  'Оранжевый',
#  'Падпараджа',
#  'Перидот',
#  'ПеридотЗ',
#  'Перламутр',
#  'Празиолит',
#  'Принцесса',
#  'Радиант',
#  'Раухтопаз',
#  'Родолит',
#  'Розовый',
#  'РубинВ',
#  'Самородок',
#  'СапфирВ',
#  'СафирП',
#  'Сердце',
#  'Серый',
#  'Сибирлит',
#  'Синий',
#  'Топаз',
#  'ТопазГ',
#  'ТопазЛБ',
#  'ТопазЛондон',
#  'ТопазС',
#  'Трилл',
#  'Турмалин',
#  'ТурмалинВ',
#  'ТурмалинГ',
#  'ТурмалинЗ',
#  'ТурмалинМ',
#  'ТурмалинР',
#  'Фантазийный',
#  'Фианит',
#  'Халцедон',
#  'ХриЗОЛИТ',
#  'Хризолит',
#  'Хризопраз',
#  'Хродиопсид',
#  'Хромдиомпсид',
#  'Хромдиопасид',
#  'Хромдиопсид',
#  'Хромдиосид',
#  'Хрусталь',
#  'Цитрин',
#  'Черный',
#  'Шпинель',
#  'ШпинельС',
#  'Эмаль',
#  'Яшма',
#  'аметист',
#  'аметистН',
#  'бриллант',
#  'бриллиант',
#  'гранат',
#  'гранатН',
#  'гранатП',
#  'жадеит',
#  'желтый',
#  'жемугК',
#  'жемчуг',
#  'жемчугБ',
#  'жемчугЧ',
#  'зеленый',
#  'изуирудВ',
#  'изумрудВ',
#  'кКР',
#  'красный',
#  'круг',
#  'мамонта',
#  'моду',
#  'нат',
#  'натГ',
#  'окр',
#  'оливковый',
#  'перидот',
#  'раухтопаз',
#  'родолит',
#  'розовый',
#  'рубинВ',
#  'сапфирВ',
#  'сибирлит',
#  'синий',
#  'топаз',
#  'топазГ',
#  'топазЦв',
#  'турмалин',
#  'турмалинР',
#  'турмалинроз',
#  'хризолит',
#  'хризолитН',
#  'хромдиопсид',
#  'цитрин',
#  'черн',
#  'черный',
#  'шпинель',
#  'шпинельС'}

# %%
pre_gem_i.union(pre_gems)
# Out:
# {'Изум',
#  'Изумруд',
#  'ИзумрудГруша',
#  'ИзумрудН',
#  'ИзумрудПМ',
#  'ИзумрудПН',
#  'ИзумрудПТ',
#  'Изумрудпм',
#  'НРОГ',
#  'НРОКР',
#  'НРОКв',
#  'НРОКр',
#  'НРООв',
#  'НРООо',
#  'НРОПр',
#  'НРОФ',
#  'НРОЧл',
#  'НРОкр',
#  'Рубин',
#  'РубинН',
#  'РубинПН',
#  'РубинПТ',
#  'РубинПФ',
#  'Рубинпн',
#  'Рубинпт',
#  'Сапфир',
#  'СапфирН',
#  'СапфирПМ',
#  'СапфирПН',
#  'СапфирПТ',
#  'СапфирПФ',
#  'Сапфирпт',
#  'изумруд',
#  'изумрудНРОФ',
#  'изумрудПМ',
#  'изумрудПН',
#  'рубинНРОФ',
#  'рубинПН',
#  'рубинПТ',
#  'сапфирПН',
#  'сапфирПТ'}

# %%
set(df_gem_explode.loc[df_gem_explode.gem.isin(pre_gem_i.union(pre_gems)),'Код'])
# Out:
# {'ЦБ-00001991',
#  'ЦБ-00002028',
#  'ЦБ-00002032',
#  'ЦБ-00002033',
#  'ЦБ-00002875',
#  'ЦБ-00003020',
#  'ЦБ-00003190',
#  'ЦБ-00005481',
#  'ЦБ-00005502',
#  'ЦБ-00005503',
#  'ЦБ-00005885',
#  'ЦБ-00005889',
#  'ЦБ-00005890',
#  'ЦБ-00005891',
#  'ЦБ-00005892',
#  'ЦБ-00005895',
#  'ЦБ-00005896',
#  'ЦБ-00005897',
#  'ЦБ-00005898',
#  'ЦБ-00005899',
#  'ЦБ-00005900',
#  'ЦБ-00005901',
#  'ЦБ-00005902',
#  'ЦБ-00005903',
#  'ЦБ-00005904',
#  'ЦБ-00005905',
#  'ЦБ-00005906',
#  'ЦБ-00005907',
#  'ЦБ-00005908',
#  'ЦБ-00005966',
#  'ЦБ-00006196',
#  'ЦБ-00006222',
#  'ЦБ-00006224',
#  'ЦБ-00006228',
#  'ЦБ-00006312',
#  'ЦБ-00007444',
#  'ЦБ-00007452',
#  'ЦБ-00008204',
#  'ЦБ-00008216',
#  'ЦБ-00008277',
#  'ЦБ-00008281',
#  'ЦБ-00008283',
#  'ЦБ-00008285',
#  'ЦБ-00008297',
#  'ЦБ-00008362',
#  'ЦБ-00008370',
#  'ЦБ-00008382',
#  'ЦБ-00008383',
#  'ЦБ-00008384',
#  'ЦБ-00008387',
#  'ЦБ-00008395',
#  'ЦБ-00008402',
#  'ЦБ-00008403',
#  'ЦБ-00008404',
#  'ЦБ-00008406',
#  'ЦБ-00008407',
#  'ЦБ-00008414',
#  'ЦБ-00008447',
#  'ЦБ-00008448',
#  'ЦБ-00008455',
#  'ЦБ-00008456',
#  'ЦБ-00008467',
#  'ЦБ-00008468',
#  'ЦБ-00008482',
#  'ЦБ-00008483',
#  'ЦБ-00008484',
#  'ЦБ-00008485',
#  'ЦБ-00008487',
#  'ЦБ-00008491',
#  'ЦБ-00008542',
#  'ЦБ-00008547',
#  'ЦБ-00009182',
#  'ЦБ-00009183',
#  'ЦБ-00009184',
#  'ЦБ-00009188',
#  'ЦБ-00009194',
#  'ЦБ-00009200',
#  'ЦБ-00009202',
#  'ЦБ-00009203',
#  'ЦБ-00009205',
#  'ЦБ-00009214',
#  'ЦБ-00009215',
#  'ЦБ-00009216',
#  'ЦБ-00014506',
#  'ЦБ-00014539',
#  'ЦБ-00016485',
#  'ЦБ-00016497',
#  'ЦБ-00016504',
#  'ЦБ-00016515',
#  'ЦБ-00016517',
#  'ЦБ-00016520',
#  'ЦБ-00016521',
#  'ЦБ-00016529',
#  'ЦБ-00016541',
#  'ЦБ-00016544',
#  'ЦБ-00016547',
#  'ЦБ-00016554',
#  'ЦБ-00016559',
#  'ЦБ-00017654',
#  'ЦБ-00017685',
#  'ЦБ-00017689',
#  'ЦБ-00017690',
#  'ЦБ-00017693',
#  'ЦБ-00017698',
#  'ЦБ-00017716',
#  'ЦБ-00017717',
#  'ЦБ-00017718',
#  'ЦБ-00017722',
#  'ЦБ-00017723',
#  'ЦБ-00017765',
#  'ЦБ-00017855',
#  'ЦБ-00017876',
#  'ЦБ-00017980',
#  'ЦБ-00019508',
#  'ЦБ-00019785',
#  'ЦБ-00019794',
#  'ЦБ-00019921',
#  'ЦБ-00021881',
#  'ЦБ-00022224',
#  'ЦБ-00022239',
#  'ЦБ-00022248',
#  'ЦБ-00022250',
#  'ЦБ-00022274',
#  'ЦБ-00023197',
#  'ЦБ-00025940',
#  'ЦБ-00027073',
#  'ЦБ-00027802',
#  'ЦБ-00029569',
#  'ЦБ-00029573',
#  'ЦБ-00029574',
#  'ЦБ-00029617',
#  'ЦБ-00029618',
#  'ЦБ-00029619',
#  'ЦБ-00029620',
#  'ЦБ-00029621',
#  'ЦБ-00029622',
#  'ЦБ-00029623',
#  'ЦБ-00029624',
#  'ЦБ-00029625',
#  'ЦБ-00029626',
#  'ЦБ-00029627',
#  'ЦБ-00029628',
#  'ЦБ-00029629',
#  'ЦБ-00029630',
#  'ЦБ-00029631',
#  'ЦБ-00029632',
#  'ЦБ-00029633',
#  'ЦБ-00029636',
#  'ЦБ-00029666',
#  'ЦБ-00029667',
#  'ЦБ-00029668',
#  'ЦБ-00029670',
#  'ЦБ-00029671',
#  'ЦБ-00029672',
#  'ЦБ-00029710',
#  'ЦБ-00029711',
#  'ЦБ-00029712',
#  'ЦБ-00029713',
#  'ЦБ-00029714',
#  'ЦБ-00029715',
#  'ЦБ-00029716',
#  'ЦБ-00030466',
#  'ЦБ-00030467',
#  'ЦБ-00030499',
#  'ЦБ-00030500',
#  'ЦБ-00030501',
#  'ЦБ-00030511',
#  'ЦБ-00031285',
#  'ЦБ-00031310',
#  'ЦБ-00031447',
#  'ЦБ-00031717',
#  'ЦБ-00031722',
#  'ЦБ-00031723',
#  'ЦБ-00031727',
#  'ЦБ-00031789',
#  'ЦБ-00031792',
#  'ЦБ-00031795',
#  'ЦБ-00031796',
#  'ЦБ-00033290',
#  'ЦБ-00033291',
#  'ЦБ-00034422',
#  'ЦБ-00034539',
#  'ЦБ-00034579',
#  'ЦБ-00034615',
#  'ЦБ-00036164',
#  'ЦБ-00036165',
#  'ЦБ-00036439',
#  'ЦБ-00036440',
#  'ЦБ-00036448',
#  'ЦБ-00037006',
#  'ЦБ-00037241',
#  'ЦБ-00037243',
#  'ЦБ-00037244',
#  'ЦБ-00037245',
#  'ЦБ-00037246',
#  'ЦБ-00037248',
#  'ЦБ-00037797',
#  'ЦБ-00037958',
#  'ЦБ-00037962',
#  'ЦБ-00037963',
#  'ЦБ-00038112',
#  'ЦБ-00038850',
#  'ЦБ-00038853',
#  'ЦБ-00038855',
#  'ЦБ-00038856',
#  'ЦБ-00038860',
#  'ЦБ-00038862',
#  'ЦБ-00038867',
#  'ЦБ-00038870',
#  'ЦБ-00038871',
#  'ЦБ-00038904',
#  'ЦБ-00038907',
#  'ЦБ-00038914',
#  'ЦБ-00039015',
#  'ЦБ-00039493',
#  'ЦБ-00039564',
#  'ЦБ-00039565',
#  'ЦБ-00041717',
#  'ЦБ-00041825',
#  'ЦБ-00041855',
#  'ЦБ-00041861',
#  'ЦБ-00041898',
#  'ЦБ-00126695',
#  'ЦБ-00126696',
#  'ЦБ-00126697',
#  'ЦБ-00126698',
#  'ЦБ-00126699',
#  'ЦБ-00126700',
#  'ЦБ-00126701',
#  'ЦБ-00126702',
#  'ЦБ-00126703',
#  'ЦБ-00126711',
#  'ЦБ-00126725',
#  'ЦБ-00126734',
#  'ЦБ-00126737',
#  'ЦБ-00126745',
#  'ЦБ-00126746',
#  'ЦБ-00126762',
#  'ЦБ-00126763',
#  'ЦБ-00126764',
#  'ЦБ-00126765',
#  'ЦБ-00126766',
#  'ЦБ-00126767',
#  'ЦБ-00126768',
#  'ЦБ-00126883',
#  'ЦБ-00126884',
#  'ЦБ-00126885',
#  'ЦБ-00126886',
#  'ЦБ-00126887',
#  'ЦБ-00126888',
#  'ЦБ-00126889',
#  'ЦБ-00126890',
#  'ЦБ-00126891',
#  'ЦБ-00126892',
#  'ЦБ-00126893',
#  'ЦБ-00126894',
#  'ЦБ-00126895',
#  'ЦБ-00126896',
#  'ЦБ-00126897',
#  'ЦБ-00126898',
#  'ЦБ-00126966',
#  'ЦБ-00126967',
#  'ЦБ-00126968',
#  'ЦБ-00126969',
#  'ЦБ-00126970',
#  'ЦБ-00126971',
#  'ЦБ-00126972',
#  'ЦБ-00126976',
#  'ЦБ-00126978',
#  'ЦБ-00126986',
#  'ЦБ-00126990',
#  'ЦБ-00127192',
#  'ЦБ-00127194',
#  'ЦБ-00127196',
#  'ЦБ-00127198',
#  'ЦБ-00127200',
#  'ЦБ-00129546',
#  'ЦБ-00129566',
#  'ЦБ-00130036',
#  'ЦБ-00130044',
#  'ЦБ-00130093',
#  'ЦБ-00130110',
#  'ЦБ-00130113',
#  'ЦБ-00130114',
#  'ЦБ-00130124',
#  'ЦБ-00130127',
#  'ЦБ-00130128',
#  'ЦБ-00130138',
#  'ЦБ-00133305',
#  'ЦБ-00133307',
#  'ЦБ-00133309',
#  'ЦБ-00133311',
#  'ЦБ-00133360',
#  'ЦБ-00133383',
#  'ЦБ-00137852',
#  'ЦБ-00137956',
#  'ЦБ-00141019',
#  'ЦБ-00143428',
#  'ЦБ-00143429',
#  'ЦБ-00143443',
#  'ЦБ-00143444',
#  'ЦБ-00143445',
#  'ЦБ-00143446',
#  'ЦБ-00143447',
#  'ЦБ-00143448',
#  'ЦБ-00143449',
#  'ЦБ-00143450',
#  'ЦБ-00143469',
#  'ЦБ-00143654',
#  'ЦБ-00143656',
#  'ЦБ-00143657',
#  'ЦБ-00143658',
#  'ЦБ-00143659',
#  'ЦБ-00143661',
#  'ЦБ-00143662',
#  'ЦБ-00143663',
#  'ЦБ-00143664',
#  'ЦБ-00143665',
#  'ЦБ-00143722',
#  'ЦБ-00143725',
#  'ЦБ-00143726',
#  'ЦБ-00145002',
#  'ЦБ-00146456',
#  'ЦБ-00146467',
#  'ЦБ-00146538',
#  'ЦБ-00146602',
#  'ЦБ-00146707',
#  'ЦБ-00155200',
#  'ЦБ-00155201',
#  'ЦБ-00155301',
#  'ЦБ-00155302',
#  'ЦБ-00167591',
#  'ЦБ-00167622',
#  'ЦБ-00167636',
#  'ЦБ-00167643',
#  'ЦБ-00167644',
#  'ЦБ-00167674',
#  'ЦБ-00167764',
#  'ЦБ-00169986',
#  'ЦБ-00170083',
#  'ЦБ-00170113',
#  'ЦБ-00170143',
#  'ЦБ-00170145',
#  'ЦБ-00170147',
#  'ЦБ-00170869',
#  'ЦБ-00170930',
#  'ЦБ-00170938',
#  'ЦБ-00170954',
#  'ЦБ-00170968',
#  'ЦБ-00171008',
#  'ЦБ-00171010',
#  'ЦБ-00171013',
#  'ЦБ-00171018',
#  'ЦБ-00171037',
#  'ЦБ-00171046',
#  'ЦБ-00171052',
#  'ЦБ-00171058',
#  'ЦБ-00171062',
#  'ЦБ-00171064',
#  'ЦБ-00171069',
#  'ЦБ-00171070',
#  'ЦБ-00171072',
#  'ЦБ-00171073',
#  'ЦБ-00171075',
#  'ЦБ-00171082',
#  'ЦБ-00171088',
#  'ЦБ-00171089',
#  'ЦБ-00171091',
#  'ЦБ-00171118',
#  'ЦБ-00171127',
#  'ЦБ-00171128',
#  'ЦБ-00171129',
#  'ЦБ-00171179',
#  'ЦБ-00171184',
#  'ЦБ-00171185',
#  'ЦБ-00171186',
#  'ЦБ-00171191',
#  'ЦБ-00171192',
#  'ЦБ-00171193',
#  'ЦБ-00171194',
#  'ЦБ-00171195',
#  'ЦБ-00171196',
#  'ЦБ-00171197',
#  'ЦБ-00171198',
#  'ЦБ-00171199',
#  'ЦБ-00171200',
#  'ЦБ-00171201',
#  'ЦБ-00171203',
#  'ЦБ-00171204',
#  'ЦБ-00171206',
#  'ЦБ-00171207',
#  'ЦБ-00171209',
#  'ЦБ-00171211',
#  'ЦБ-00171212',
#  'ЦБ-00171216',
#  'ЦБ-00171217',
#  'ЦБ-00171218',
#  'ЦБ-00171219',
#  'ЦБ-00171221',
#  'ЦБ-00171222',
#  'ЦБ-00171223',
#  'ЦБ-00171224',
#  'ЦБ-00171225',
#  'ЦБ-00171226',
#  'ЦБ-00171227',
#  'ЦБ-00171228',
#  'ЦБ-00171229',
#  'ЦБ-00171230',
#  'ЦБ-00171233',
#  'ЦБ-00171324',
#  'ЦБ-00171334',
#  'ЦБ-00171340',
#  'ЦБ-00171341',
#  'ЦБ-00171343',
#  'ЦБ-00171360',
#  'ЦБ-00173700',
#  'ЦБ-00173775',
#  'ЦБ-00173776',
#  'ЦБ-00173777',
#  'ЦБ-00173782',
#  'ЦБ-00174084',
#  'ЦБ-00174179',
#  'ЦБ-00174223',
#  'ЦБ-00177018',
#  'ЦБ-00177019',
#  'ЦБ-00177020',
#  'ЦБ-00177021',
#  'ЦБ-00177022',
#  'ЦБ-00177023',
#  'ЦБ-00177024',
#  'ЦБ-00177025',
#  'ЦБ-00177026',
#  'ЦБ-00177027',
#  'ЦБ-00177028',
#  'ЦБ-00177029',
#  'ЦБ-00177030',
#  'ЦБ-00177187',
#  'ЦБ-00177228',
#  'ЦБ-00177359',
#  'ЦБ-00177526',
#  'ЦБ-00182578',
#  'ЦБ-00182583',
#  'ЦБ-00182586',
#  'ЦБ-00182589',
#  'ЦБ-00182591',
#  'ЦБ-00182594',
#  'ЦБ-00182596',
#  'ЦБ-00182597',
#  'ЦБ-00182599',
#  'ЦБ-00182602',
#  'ЦБ-00182606',
#  'ЦБ-00182619',
#  'ЦБ-00182633',
#  'ЦБ-00182880',
#  'ЦБ-00182892',
#  'ЦБ-00182902',
#  'ЦБ-00182923',
#  'ЦБ-00182950',
#  'ЦБ-00182962',
#  'ЦБ-00183028',
#  'ЦБ-00183045',
#  'ЦБ-00183087',
#  'ЦБ-00183088',
#  'ЦБ-00183091',
#  'ЦБ-00183092',
#  'ЦБ-00183102',
#  'ЦБ-00183103',
#  'ЦБ-00183108',
#  'ЦБ-00183137',
#  'ЦБ-00183140',
#  'ЦБ-00183177',
#  'ЦБ-00183444',
#  'ЦБ-00188007',
#  'ЦБ-00188026',
#  'ЦБ-00188027',
#  'ЦБ-00188073',
#  'ЦБ-00188076',
#  'ЦБ-00188484',
#  'ЦБ-00188485',
#  'ЦБ-00188520',
#  'ЦБ-00188543',
#  'ЦБ-00188572',
#  'ЦБ-00188585',
#  'ЦБ-00188647',
#  'ЦБ-00188650',
#  'ЦБ-00188651',
#  'ЦБ-00188652',
#  'ЦБ-00188663',
#  'ЦБ-00188885',
#  'ЦБ-00188958',
#  'ЦБ-00188959',
#  'ЦБ-00188961',
#  'ЦБ-00189695',
#  'ЦБ-00189696',
#  'ЦБ-00189698',
#  'ЦБ-00189699',
#  'ЦБ-00189700',
#  'ЦБ-00189729',
#  'ЦБ-00189787',
#  'ЦБ-00189841',
#  'ЦБ-00189844',
#  'ЦБ-00212061',
#  'ЦБ-00219608'}

# %%
len(_)
# Out:
# 940

# %%
945

# %% [markdown]
# ## !Сохранение списка ЦБ где есть ДК ЦВ камни для индивидуальной работы с ценами бриллиантов zb_of_dkcol

# %%
zb_of_dkcol = set(df_gem_explode.loc[df_gem_explode.gem.isin(pre_gem_i.union(pre_gems)),'Код'])

# %%
len(zb_of_dkcol)
# Out:
# 940

# %% [markdown]
# ## Группировка по изделиям diamondsgrby

# %%
#пром результат группировка
diamondsgrby = diamonds.groupby('Code').agg({'ШТУК':"sum", 
                                             'КАРАТ':"sum",'prcost':"sum"}).reset_index()

# %%
#diamondsgrby.drop(columns=['не сработал прейскурант'], inplace=True)

# %%
diamondsgrby['инф для не сработал прейскурант']='сработал'

# %%
diamondsgrby.columns
# Out:
# Index(['Code', 'ШТУК', 'КАРАТ', 'prcost', 'инф для не сработал прейскурант'], dtype='object')

# %%
diamondsgrby.loc[diamondsgrby['Code'].isin(zb_of_1_50ct)
                 ,['инф для не сработал прейскурант', 'КАРАТ']]
# Out:
#       инф для не сработал прейскурант  КАРАТ
# 1321                         сработал  1.766
# 1501                         сработал  2.250
# 3669                         сработал  1.510
# 5465                         сработал  2.183
# 6075                         сработал  2.213
# ...                               ...    ...
# 34219                        сработал  5.359
# 34220                        сработал  7.380
# 34222                        сработал  4.570
# 34223                        сработал  4.375
# 34224                        сработал  3.040
#
# [65 rows x 2 columns]

# %%
diamondsgrby.loc[diamondsgrby['Code'].isin(zb_of_1_50ct)
                 ,'инф для не сработал прейскурант'] = 'имеется брилл свыше 1.50 требуется индивидуальный подход'

# %%
diamondsgrby.loc[diamondsgrby['Code'].isin(zb_of_pr_is0)
                 ,['инф для не сработал прейскурант', 'КАРАТ']]
# Out:
#                                 инф для не сработал прейскурант  КАРАТ
# 11875  имеется брилл свыше 1.50 требуется индивидуальный подход  10.89
# 11878  имеется брилл свыше 1.50 требуется индивидуальный подход  10.47
# 11880  имеется брилл свыше 1.50 требуется индивидуальный подход   9.18
# 11883  имеется брилл свыше 1.50 требуется индивидуальный подход   8.22
# 34204  имеется брилл свыше 1.50 требуется индивидуальный подход   8.34
# 34208  имеется брилл свыше 1.50 требуется индивидуальный подход   9.12
# 34211  имеется брилл свыше 1.50 требуется индивидуальный подход   9.03
# 34212  имеется брилл свыше 1.50 требуется индивидуальный подход   9.80
# 34220  имеется брилл свыше 1.50 требуется индивидуальный подход   7.38

# %%
diamondsgrby.loc[diamondsgrby['Code'].isin(zb_of_pr_is0)
                 ,'инф для не сработал прейскурант'] = 'не сработал тк свыше 6 карат'

# %%
diamondsgrby.loc[diamondsgrby['Code'].isin(zb_of_dkcol)
                 ,['инф для не сработал прейскурант', 'КАРАТ']]
# Out:
#       инф для не сработал прейскурант  КАРАТ
# 206                          сработал  0.020
# 221                          сработал  0.190
# 223                          сработал  0.370
# 368                          сработал  0.070
# 390                          сработал  0.140
# ...                               ...    ...
# 29354                        сработал  0.139
# 29408                        сработал  0.138
# 29411                        сработал  0.138
# 34167                        сработал  0.069
# 34213                        сработал  1.670
#
# [915 rows x 2 columns]

# %%
'Цветной ДК, ' + diamondsgrby.loc[diamondsgrby['Code'].isin(zb_of_dkcol)
                 ,'инф для не сработал прейскурант']\
        #       .unique()
# Out:
# 206      Цветной ДК, сработал
# 221      Цветной ДК, сработал
# 223      Цветной ДК, сработал
# 368      Цветной ДК, сработал
# 390      Цветной ДК, сработал
#                  ...
# 29354    Цветной ДК, сработал
# 29408    Цветной ДК, сработал
# 29411    Цветной ДК, сработал
# 34167    Цветной ДК, сработал
# 34213    Цветной ДК, сработал
# Name: инф для не сработал прейскурант, Length: 915, dtype: object

# %%
diamondsgrby.loc[diamondsgrby['Code'].isin(zb_of_dkcol)
                 ,'инф для не сработал прейскурант'] = 'Цветной ДК, ' + diamondsgrby.loc[diamondsgrby['Code'].isin(zb_of_dkcol)
                 ,'инф для не сработал прейскурант']

# %% [markdown]
# ## (попутно) Сохранение списка ЦБ где нет бриллиантов zb_of_no_diamond

# %%
diamondsgrby['инф для не сработал прейскурант'].value_counts()
# Out:
# сработал                                                    33248
# Цветной ДК, сработал                                          915
# имеется брилл свыше 1.50 требуется индивидуальный подход       56
# не сработал тк свыше 6 карат                                    9
# Name: инф для не сработал прейскурант, dtype: int64

# %%
#Изделия в которых нет бриллиантов

# %%
len(df1) - len(diamondsgrby)
# Out:
# 41

# %%
#Код ЦБ по ним
zb_of_no_diamond =  set(df1.Code) - set(diamondsgrby.Code)
zb_of_no_diamond
# Out:
# {'ЦБ-00002032',
#  'ЦБ-00002998',
#  'ЦБ-00003097',
#  'ЦБ-00016485',
#  'ЦБ-00016515',
#  'ЦБ-00016517',
#  'ЦБ-00016541',
#  'ЦБ-00016544',
#  'ЦБ-00016547',
#  'ЦБ-00016554',
#  'ЦБ-00017654',
#  'ЦБ-00017838',
#  'ЦБ-00027802',
#  'ЦБ-00029899',
#  'ЦБ-00030466',
#  'ЦБ-00030493',
#  'ЦБ-00030499',
#  'ЦБ-00031727',
#  'ЦБ-00034197',
#  'ЦБ-00034539',
#  'ЦБ-00036054',
#  'ЦБ-00036164',
#  'ЦБ-00059772',
#  'ЦБ-00059773',
#  'ЦБ-00106026',
#  'ЦБ-00160807',
#  'ЦБ-00161021',
#  'ЦБ-00166110',
#  'ЦБ-00171046',
#  'ЦБ-00171068',
#  'ЦБ-00171340',
#  'ЦБ-00174317',
#  'ЦБ-00177228',
#  'ЦБ-00177359',
#  'ЦБ-00182948',
#  'ЦБ-00182949',
#  'ЦБ-00182950',
#  'ЦБ-00188518',
#  'ЦБ-00188647',
#  'ЦБ-00188958',
#  'ЦБ-00188959'}

# %%
#Проверка почему
df1[df1['Code'].isin (set(df1.Code) - set(diamondsgrby.Code))]
# Out:
#               Code              art      name  \
# 1042   ЦБ-00166110        YN6112WBD     Колье
# 3455   ЦБ-00002032            01573    Кольцо
# 3842   ЦБ-00031727          2250072    Серьги
# 4255   ЦБ-00002998          4стс329    Серьги
# 5640   ЦБ-00160807       1А20272-22    серьги
# 5908   ЦБ-00059772          нк11/15     колье
# 5909   ЦБ-00059773          нк11/04     колье
# 10444  ЦБ-00029899          4стк050    Кольцо
# 10463  ЦБ-00030466          НПКО35И    Кольцо
# 10481  ЦБ-00030493         21110016    Кольцо
# 10817  ЦБ-00036164       К039-0769С    Кольцо
# 11078  ЦБ-00036054          4стп152  Подвеска
# 11180  ЦБ-00034197          4стс051    Серьги
# 11239  ЦБ-00034539            02523    Серьги
# 14018  ЦБ-00027802          3250003  Подвеска
# 14657  ЦБ-00017838              Тай   Браслет
# 14709  ЦБ-00016485       К007-147Сж    Кольцо
# 14732  ЦБ-00016515          НПКО07С    Кольцо
# 14734  ЦБ-00016517        38к512011    Кольцо
# 14753  ЦБ-00016541         257/3/48    Кольцо
# 14756  ЦБ-00016544       К039-0715И    Кольцо
# 14758  ЦБ-00016547        38к510801    Кольцо
# 14764  ЦБ-00016554          НПКО25С    Кольцо
# 14843  ЦБ-00017654          НПКО15И    Кольцо
# 18084  ЦБ-00177228  Северное сияние     Колье
# 18096  ЦБ-00182948          Excl ЭВ     Колье
# 18097  ЦБ-00182949              Exl     Колье
# 18200  ЦБ-00030499      К007-0539жС    Кольцо
# 23646  ЦБ-00171046            01367    Кольцо
# 23755  ЦБ-00171340            01131    Кольцо
# 26283  ЦБ-00188518            2Б066    Кольцо
# 3842       []
# 4255       []
# 5640       []
# 5908       []
# 5909       []
# 10444      []
# 10463      []
# 10481      []
# 10817      []
# 11078      []
# 11180      []
# 11239      []
# 14018      []
# 14657      []
# 14709      []
# 14732      []
# 14734      []
# 14753      []
# 14756      []
# 14758      []
# 14764      []
# 14843      []
# 18084      []
# 18096      []
# 18097      []
# 18200      []
# 23646      []
# 23755      []
# 26283      []
# 26291      []
# 26322      []
# 26323      []
# 28351      []
# 28633      []
# 30165      []
# 31063      []
# 31910      []
# 32686      []
# 34217      []

# %%
set(df1.Code) - set(diamondsgrby.Code)
# Out:
# {'ЦБ-00002032',
#  'ЦБ-00002998',
#  'ЦБ-00003097',
#  'ЦБ-00016485',
#  'ЦБ-00016515',
#  'ЦБ-00016517',
#  'ЦБ-00016541',
#  'ЦБ-00016544',
#  'ЦБ-00016547',
#  'ЦБ-00016554',
#  'ЦБ-00017654',
#  'ЦБ-00017838',
#  'ЦБ-00027802',
#  'ЦБ-00029899',
#  'ЦБ-00030466',
#  'ЦБ-00030493',
#  'ЦБ-00030499',
#  'ЦБ-00031727',
#  'ЦБ-00034197',
#  'ЦБ-00034539',
#  'ЦБ-00036054',
#  'ЦБ-00036164',
#  'ЦБ-00059772',
#  'ЦБ-00059773',
#  'ЦБ-00106026',
#  'ЦБ-00160807',
#  'ЦБ-00161021',
#  'ЦБ-00166110',
#  'ЦБ-00171046',
#  'ЦБ-00171068',
#  'ЦБ-00171340',
#  'ЦБ-00174317',
#  'ЦБ-00177228',
#  'ЦБ-00177359',
#  'ЦБ-00182948',
#  'ЦБ-00182949',
#  'ЦБ-00182950',
#  'ЦБ-00188518',
#  'ЦБ-00188647',
#  'ЦБ-00188958',
#  'ЦБ-00188959'}

# %% [markdown]
# ## MERGE

# %%
#Присоединяем 'vs_dict' из df1  
diamondsdf1 = pd.merge(df1, diamondsgrby,
                    how='left',right_on='Code',left_on='Code')

# %%
diamondsdf1
# Out:
#               Code                art         name  \
# 0      ЦБ-00200503  JGN00840HGAWX13CH      Браслет
# 1      ЦБ-00002854           Exl Ш.Н.      Браслет
# 2      ЦБ-00019951            1БШ0140        Брошь
# 3      ЦБ-00019953             515006        Брошь
# 4      ЦБ-00111074           15515144        Брошь
# ...            ...                ...          ...
# 34264  ЦБ-00182016          121302193  серьги с ДК
# 34265  ЦБ-00182017          121302193  серьги с ДК
# 34266  ЦБ-00182019          121562193  серьги с ДК
# 34267  ЦБ-00182020          121562193  серьги с ДК
# 34268  ЦБ-00182021          121562193  серьги с ДК
#
#                                                                                     vstavki  \
# 0                                                                         45КР57-0,520-4/5А
# 1                       2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-2/2А 3Кр57-0,095-3/2А
# 2                                                                          1Кр57-0,086-4/5А
# 3                                                                           3Кр57-0,06-4/5А
# 4      1Кр57-0,050-4/5А 1Кр57-0,031-6/6А 1Кр57-0,014-6/6А 4Кр57-0,027-3/5А 6Кр57-0,017-3/6А
# ...                                                                                     ...
# 34264                                                              СапфирВ 6КР57-0,080-3/4А
# 34265                                                              СапфирВ 6КР57-0,080-3/4А
# 34266                                                             ИзумрудВ 4КР57-0,040-2/3А
# 34267                                                             ИзумрудВ 4КР57-0,040-2/3А
# 34268                                                             ИзумрудВ 4КР57-0,040-2/3А
#
#                                                                                                    vs_dict  \
# 0                                                                              [(45, КР57, 0,520, 4/5, А)]
# 1      [(2, Кр57, 0,083, 2/2, А), (4, Кр57, 0,084, 2/2, А), (6, Кр57, 0,280, 2/2, А), (3, Кр57, 0,095, ...
# 2                                                                               [(1, Кр57, 0,086, 4/5, А)]
# 3                                                                                [(3, Кр57, 0,06, 4/5, А)]
# 4      [(1, Кр57, 0,050, 4/5, А), (1, Кр57, 0,031, 6/6, А), (1, Кр57, 0,014, 6/6, А), (4, Кр57, 0,027, ...
# ...                                                                                                    ...
# 34264                                                                           [(6, КР57, 0,080, 3/4, А)]
# 34265                                                                           [(6, КР57, 0,080, 3/4, А)]
# 34266                                                                           [(4, КР57, 0,040, 2/3, А)]
# 34267                                                                           [(4, КР57, 0,040, 2/3, А)]
# 34268                                                                           [(4, КР57, 0,040, 2/3, А)]
#
#        ШТУК  КАРАТ  prcost инф для не сработал прейскурант
# 0      45.0  0.520  161.20                        сработал
# 1      15.0  0.542  231.53                        сработал
# 2       1.0  0.086   33.11                        сработал
# 3       3.0  0.060   17.40                        сработал
# 4      13.0  0.139   38.95                        сработал
# ...     ...    ...     ...                             ...
# 34264   6.0  0.080   30.40                        сработал
# 34265   6.0  0.080   30.40                        сработал
# 34266   4.0  0.040   17.40                        сработал
# 34267   4.0  0.040   17.40                        сработал
# 34268   4.0  0.040   17.40                        сработал
#
# [34269 rows x 9 columns]

# %% [markdown]
# ## Сбор всех значений в поле 'не сработал прейскурант'

# %%
# Отмечаем Цв ДК в без бриллиантовых
diamondsdf1.loc[(diamondsdf1['Code'].isin(zb_of_dkcol))&(diamondsdf1['инф для не сработал прейскурант'].isna()),
               [ 'инф для не сработал прейскурант', 'vstavki']]
# Out:
#       инф для не сработал прейскурант  \
# 3455                              NaN
# 3842                              NaN
# 5640                              NaN
# 10463                             NaN
# 10817                             NaN
# 11239                             NaN
# 14018                             NaN
# 14709                             NaN
# 14732                             NaN
# 14734                             NaN
# 14753                             NaN
# 14756                             NaN
# 14758                             NaN
# 14764                             NaN
# 14843                             NaN
# 18084                             NaN
# 18200                             NaN
# 23646                             NaN
# 23755                             NaN
# 26291                             NaN
# 26322                             NaN
# 26323                             NaN
# 28633                             NaN
# 30165                             NaN
# 32686                             NaN
#
#                                                                        vstavki
# 3455                                                      1рубинПН-0,23+ОВ+2/2
# 3842                                                     2рубинПН-0,280+КР+2/3
# 5640                                                    2СапфирПТ-0,162-КР+2/2
# 10463                 1изумрудПН-0,0259-НРОКр+3/2Г 2ИзумрудПН-НРОКр-0,016+3/3Г
# 10817                                                   1СапфирПТ-КР-0,093+2/3
# 11239                                                    2сапфирПТ-1,300-С+2/1
# 14018              6СапфирПТ-0,110-КР+2/2*Синий  5СапфирПТ-0,100-КР+2/2*Желтый
# 14709                                            1сапфирПН-0,080-Кр+2/2*Желтый
# 14732                                                   1сапфирПТ-0,125-кр+2/3
# 14734                                                   1сапфирПТ-0,140-кр+2/2
# 14753                                                1изумрудПМ-0,380-кр57+3/3
# 14756                                               1изумрудПМ-0,0553-кр57+4/2
# 14758                                                   1сапфирПТ-0,320-кр+2/3
# 14764                                                   1сапфирПТ-0,305-кр+2/3
# 14843                                                1изумрудПМ-0,088-Кр57+3/3
# 18084  4РубинПТ-2,430-ов+3/3 2РубинПТ-0,370-кр+3/3 Хромдиопсид Гранат Турмалин
# 18200                                             СапфирПТ-0,104-Кр+2/2*Желтый
# 23646                                                   1РубинПТ-0,260-ГР+2/1
# 23755                                             1ИзумрудПМ-0,210-НРОКв+4/Г1
# 26291                                           ТопазГ 56СапфирПТ-0,360-КР+3/3
# 26322                                              1ИзумрудПМ-0,370-НРОКр+3/Г3
# 26323                                              1ИзумрудПМ-0,070-НРОКр+3/Г3
# 28633                                      80РубинПН-8,520-М+3/3 БивеньМамонта
# 30165                                               2ИзумрудПМ-0,600-НРОГ+4/Г2
# 32686  2РубинПТ-1,200-ов+3/3 2РубинПТ-0,370-кр+3/3 Хромдиопсид Гранат Турмалин

# %%
diamondsdf1.loc[(diamondsdf1['Code'].isin(zb_of_dkcol))&(diamondsdf1['инф для не сработал прейскурант'].isna()),
                'инф для не сработал прейскурант'] =  'Цветной ДК, без бриллиантов'

# %%
# Отмечаем для проверки, тк нет ни Цв ДК ни бриллиантов
diamondsdf1.loc[diamondsdf1['инф для не сработал прейскурант'].isna(), \
                 [ 'инф для не сработал прейскурант', 'vstavki']]
# Out:
#       инф для не сработал прейскурант  \
# 1042                              NaN
# 4255                              NaN
# 5908                              NaN
# 5909                              NaN
# 10444                             NaN
# 10481                             NaN
# 11078                             NaN
# 11180                             NaN
# 14657                             NaN
# 18096                             NaN
# 18097                             NaN
# 26283                             NaN
# 28351                             NaN
# 31063                             NaN
# 31910                             NaN
# 34217                             NaN
#
#                                                     vstavki
# 1042                                       АлмазБорт*Черный
# 4255                                        цитрин сибирлит
# 5908                                              Аквамарин
# 5909                                              Аквамарин
# 10444                          топаз 1.5ct гранат 3шт 0.4ct
# 10481                                  хромдиопсид К17-0,07
# 11078                                 ТопазГ 16Цитрин-1,35А
# 11180            топаз 2шт 2.73ct*Голубой гранат 10шт 0.8ct
# 14657                    топаз*Желтый топаз*Голубой шпинель
# 18096  Аметист Хромдиопсид Турмалин Топаз*Голубой Хризолит
# 18097     Топаз*Голубой Турмалин Цитрин Хромдиопсид Аметист
# 26283                                                Цитрин
# 28351                                                Гранат
# 31063                                                Цитрин
# 31910                                             Аквамарин
# 34217                                                Гранат

# %%
diamondsdf1.loc[diamondsdf1['инф для не сработал прейскурант'].isna(),  'инф для не сработал прейскурант'] = "Проверить, тк без ДК и без бриллиантов"

# %%
diamondsdf1['инф для не сработал прейскурант'].value_counts()
# Out:
# сработал                                                    33248
# Цветной ДК, сработал                                          915
# имеется брилл свыше 1.50 требуется индивидуальный подход       56
# Цветной ДК, без бриллиантов                                    25
# Проверить, тк без ДК и без бриллиантов                         16
# не сработал тк свыше 6 карат                                    9
# Name: инф для не сработал прейскурант, dtype: int64

# %%
diamondsdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34269 entries, 0 to 34268
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Code                             34269 non-null  object
#  1   art                              34268 non-null  object
#  2   name                             34269 non-null  object
#  3   vstavki                          34269 non-null  object
#  4   vs_dict                          34269 non-null  object
#  5   ШТУК                             34228 non-null  float64
#  6   КАРАТ                            34228 non-null  float64
#  7   prcost                           34228 non-null  float64
#  8   инф для не сработал прейскурант  34269 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 2.6+ MB

# %%
(diamondsdf1.vstavki == 'Цветной ДК, без бриллиантов').sum()
# Out:
# 0

# %%
#(diamondsdf0[ 'Вставки корректировка 22-09-2023'] == 'Цветной ДК, без бриллиантов').sum()

# %%
#df_finish.to_excel('D:/TNA/2023_07_05_Otsenka_DYA_dog№19_07-2023/Data check/23_07_26_For_Script_DONE_1.xlsx')

# %%
# проверки
#diamondsdf1.loc[(diamondsdf1.prcost == 0)|(diamondsdf1.prcost.isna())]
diamondsdf1.loc[(diamondsdf1.prcost.isna())]
# Out:
#               Code              art      name  \
# 1042   ЦБ-00166110        YN6112WBD     Колье
# 3455   ЦБ-00002032            01573    Кольцо
# 3842   ЦБ-00031727          2250072    Серьги
# 4255   ЦБ-00002998          4стс329    Серьги
# 5640   ЦБ-00160807       1А20272-22    серьги
# 5908   ЦБ-00059772          нк11/15     колье
# 5909   ЦБ-00059773          нк11/04     колье
# 10444  ЦБ-00029899          4стк050    Кольцо
# 10463  ЦБ-00030466          НПКО35И    Кольцо
# 10481  ЦБ-00030493         21110016    Кольцо
# 10817  ЦБ-00036164       К039-0769С    Кольцо
# 11078  ЦБ-00036054          4стп152  Подвеска
# 11180  ЦБ-00034197          4стс051    Серьги
# 11239  ЦБ-00034539            02523    Серьги
# 14018  ЦБ-00027802          3250003  Подвеска
# 14657  ЦБ-00017838              Тай   Браслет
# 14709  ЦБ-00016485       К007-147Сж    Кольцо
# 14732  ЦБ-00016515          НПКО07С    Кольцо
# 14734  ЦБ-00016517        38к512011    Кольцо
# 14753  ЦБ-00016541         257/3/48    Кольцо
# 14756  ЦБ-00016544       К039-0715И    Кольцо
# 14758  ЦБ-00016547        38к510801    Кольцо
# 14764  ЦБ-00016554          НПКО25С    Кольцо
# 14843  ЦБ-00017654          НПКО15И    Кольцо
# 18084  ЦБ-00177228  Северное сияние     Колье
# 18096  ЦБ-00182948          Excl ЭВ     Колье
# 18097  ЦБ-00182949              Exl     Колье
# 18200  ЦБ-00030499      К007-0539жС    Кольцо
# 23646  ЦБ-00171046            01367    Кольцо
# 23755  ЦБ-00171340            01131    Кольцо
# 26283  ЦБ-00188518            2Б066    Кольцо
# 26291  ЦБ-00188647       11016W0607    Кольцо
# 26322  ЦБ-00188958            10213    Кольцо
# 26323  ЦБ-00188959            10217    Кольцо
# 28351  ЦБ-00174317        09/513128  Подвеска
# 28633  ЦБ-00182950           Exl ВЯ  Подвеска
# 30165  ЦБ-00106026            02452    Серьги
   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 5908       []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 5909       []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 10444      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 10463      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 10481      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 10817      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 11078      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 11180      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 11239      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 14018      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 14657      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 14709      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 14732      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 14734      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 14753      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 14756      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 14758      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 14764      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 14843      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 18084      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 18096      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 18097      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 18200      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 23646      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 23755      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 26283      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 26291      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 26322      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 26323      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 28351      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 28633      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 30165      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 31063      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 31910      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов
# 32686      []   NaN    NaN     NaN             Цветной ДК, без бриллиантов
# 34217      []   NaN    NaN     NaN  Проверить, тк без ДК и без бриллиантов

# %%
diamondsdf1.loc[(diamondsdf1.prcost.isna())]['vstavki'].to_list()
# Out:
# ['АлмазБорт*Черный',
#  '1рубинПН-0,23+ОВ+2/2',
#  '2рубинПН-0,280+КР+2/3',
#  'цитрин сибирлит',
#  '2СапфирПТ-0,162-КР+2/2',
#  'Аквамарин',
#  'Аквамарин',
#  'топаз 1.5ct гранат 3шт 0.4ct',
#  '1изумрудПН-0,0259-НРОКр+3/2Г 2ИзумрудПН-НРОКр-0,016+3/3Г',
#  'хромдиопсид К17-0,07',
#  '1СапфирПТ-КР-0,093+2/3',
#  'ТопазГ 16Цитрин-1,35А',
#  'топаз 2шт 2.73ct*Голубой гранат 10шт 0.8ct',
#  '2сапфирПТ-1,300-С+2/1',
#  '6СапфирПТ-0,110-КР+2/2*Синий  5СапфирПТ-0,100-КР+2/2*Желтый',
#  'топаз*Желтый топаз*Голубой шпинель',
#  '1сапфирПН-0,080-Кр+2/2*Желтый',
#  '1сапфирПТ-0,125-кр+2/3',
#  '1сапфирПТ-0,140-кр+2/2',
#  '1изумрудПМ-0,380-кр57+3/3',
#  '1изумрудПМ-0,0553-кр57+4/2',
#  '1сапфирПТ-0,320-кр+2/3',
#  '1сапфирПТ-0,305-кр+2/3',
#  '1изумрудПМ-0,088-Кр57+3/3',
#  '4РубинПТ-2,430-ов+3/3 2РубинПТ-0,370-кр+3/3 Хромдиопсид Гранат Турмалин',
#  'Аметист Хромдиопсид Турмалин Топаз*Голубой Хризолит ',
#  'Топаз*Голубой Турмалин Цитрин Хромдиопсид Аметист',
#  'СапфирПТ-0,104-Кр+2/2*Желтый',
#  '1РубинПТ-0,260-ГР+2/1 ',
#  '1ИзумрудПМ-0,210-НРОКв+4/Г1 ',
#  'Цитрин',
#  'ТопазГ 56СапфирПТ-0,360-КР+3/3',
#  '1ИзумрудПМ-0,370-НРОКр+3/Г3',
#  '1ИзумрудПМ-0,070-НРОКр+3/Г3',
#  'Гранат',
#  '80РубинПН-8,520-М+3/3 БивеньМамонта',
#  '2ИзумрудПМ-0,600-НРОГ+4/Г2',
#  'Цитрин',
#  'Аквамарин',
#  '2РубинПТ-1,200-ов+3/3 2РубинПТ-0,370-кр+3/3 Хромдиопсид Гранат Турмалин',
#  'Гранат']

# %%
diamondsdf1.dtypes
# Out:
# Code                                object
# art                                 object
# name                                object
# vstavki                             object
# vs_dict                             object
# ШТУК                               float64
# КАРАТ                              float64
# prcost                             float64
# инф для не сработал прейскурант     object
# dtype: object

# %% [markdown]
# # Результат на файл склада (присоединяем к df0)

# %%
folder_res
# Out:
# '../for_script24-10-2023/'

# %%
datetime.datetime.now().strftime('%d-%m-%Y_%H-%M')
# Out:
# '31-10-2023_09-43'

# %%
filename
# Out:
# 'выгрузка15-10-2023_все_склады_ДК_'

# %%
filename_res_df0 = filename+'_'+datetime.datetime.now().strftime('%d-%m-%Y_%H-%M')+'_res_pr.xlsx'
filename_res_df0
# Out:
# 'выгрузка15-10-2023_все_склады_ДК__31-10-2023_09-44_res_pr.xlsx'

# %%
#сохраняем на файл
diamondsdf0 = pd.merge(df0,diamondsdf1[['Code','vs_dict','ШТУК', 'КАРАТ','prcost','инф для не сработал прейскурант']]
    ,how='left',left_on='Код', right_on='Code')
diamondsdf0.to_excel(folder_res+filename_res_df0, index=None)

# %%
diamondsdf0['инф для не сработал прейскурант'].value_counts()
# Out:
# сработал                                                    33248
# Цветной ДК, сработал                                          915
# имеется брилл свыше 1.50 требуется индивидуальный подход       56
# Цветной ДК, без бриллиантов                                    25
# Проверить, тк без ДК и без бриллиантов                         16
# не сработал тк свыше 6 карат                                    9
# Name: инф для не сработал прейскурант, dtype: int64

# %%
сработал                                                    33501
Цветной ДК, сработал                                          919
имеется брилл свыше 1.50 требуется индивидуальный подход       57
Цветной ДК, без бриллиантов                                    26
Проверить, тк без ДК и без бриллиантов                         16
не сработал тк свыше 6 карат                                    9
Name: не сработал прейскурант, dtype: int64
# Out:
#   File "<ipython-input-157-82fdb08726fa>", line 1
#     сработал                                                    33501
#                                                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # DEL

# %% [markdown]
# ### ПРОБЛЕМА 1 ШТУКИ ""

# %%
df1_exp_dia['ШТУК'].unique()
# Out:
# array(['45', '2', '4', '6', '3', '1', '12', '5', '10', '7', '14', '32',
#        '20', '22', '44', '52', '28', '29', '46', '34', '60', '18', '42',
#        '82', '69', '97', '8', '56', '54', '27', '50', '62', '16', '26',
#        '25', '11', '9', '13', '15', '40', '24', '134', '48', '23', '21',
#        '36', '58', '19', '31', '38', '17', '30', '70', '80', '114', '90',
#        '84', '108', '68', '76', '140', '57', '35', '66', '33', '92',
#        '105', '59', '153', '43', '89', '74', '102', '64', '120', '72',
#        '75', '53', '47', '67', '78', '39', '88', '49', '216', '209',
#        '103', '100', '83', '81', '401', '836', '99', '86', '183', '41',
#        '590', '61', '55', '147', '65', '289', '51', '37', '87', '418',
#        '107', '106', '205', '119', '132', '262', '98', '137', '200',
#        '337', '63', '152', '136', '182', '194', '263', '91', '130', '131',
#        '171', '500', '178', '328', '241', '180', '160', '187', '85',
#        '157', '110', '71', '96', '361', '305', '273', '93', '113', '129',
#        '94', '112', '95', '164', '139', '166', '116', '73', '207', '115',
#        '148', '138', '124', '163', '141', '79', '400', '104', '142',
#        '165', '118', '128', '312', '125', '77', '167', '196', '229',
#        '534', '267', '257', '181', '370', '122', '254', '373', '224',
#        '367', '117', '206', '201', '371', '210', '635', '299', '162',
#        '324', '388', '154', '143', '170', '176', '204', '385', '150',
#        '175', '158', '285', '255', '230', '111', '353', '189', '121',
#        '264', '506', '431', '198', '236', '109', '321'], dtype=object)

# %%
df1_exp_dia[df1_exp_dia['ШТУК'] == '']
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д]
# Index: []

# %%
#df1_exp_dia.loc[df1_exp_dia['ОГРАНКА'] == 'Зкр57', 'ШТУК'] = 3

# %%
#df1_exp_dia.loc[df1_exp_dia['ОГРАНКА'] == 'Зкр57', 'ОГРАНКА'] = 'кр57'

# %%
#df1_exp_dia.loc[df1_exp_dia['ШТУК'] == '', 'ШТУК'] = 1

# %%
#df0.loc[df0['Артикул '] == 'JRZ855810GAWX13Q0', ['Группы',
#       'родитель1_1c', 'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
#       'родитель5_1c']]

# %%
#df0.loc[df0['Код'] == 'ЦБ-00019890', ['Группы',
#       'родитель1_1c', 'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
#       'родитель5_1c']]

# %% [markdown]
# ### ПРОБЛЕМА 2 нераспознаны огранки

# %%
df1_exp_dia.loc[~df1_exp_dia.ОГРАНКА.apply(lambda x: x in dogr_dia_discount),'ОГРАНКА'].unique()
# Out:
# array([], dtype=object)

# %%
#df1_exp_dia.loc[df1_exp_dia.ОГРАНКА == 'Г2', 'vstavki'].to_list()

# %%
#запросил бирку, видимо бриллиант - сказали это повтор изумруда остался 
# недописана огранка '1ИзумрудПМ-0,426-НРООв+4/Г2-0,426-4/2А 1КР57-0,030-5/3А 2КР57-0,060-5/5А'
#удаляю на месте строку

# %% [markdown]
# ### СТЕРЕТЬ ПО УСЛОВИЮ

# %%
#!!! резет индекса обязателен
df1_exp_dia.reset_index(drop=True, inplace = True)

# %%
# Условие
df1_exp_dia.loc[df1_exp_dia.ОГРАНКА == 'Г2',:]
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д]
# Index: []

# %%
#!Берем индекс и еще раз проверяем
delete_index = _.index
# проверка еще раз
df1_exp_dia.loc[delete_index]
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д]
# Index: []

# %%
# !!! Стираем строку
df1_exp_dia.drop(delete_index,inplace=True)

# %%
#Проверка стирания
df1_exp_dia.loc[df1_exp_dia.ОГРАНКА == 'Г2',:]
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д]
# Index: []

# %% [markdown]
# ### КОНЕЦ СТЕРЕТЬ ПО УСЛОВИЮ

# %%
#pd.set_option('display.float_format', '{:.2f}'.format)
#pd.options.display.max_columns = 30
#pd.options.display.max_rows = 500

# %%
df0.loc[df0['Код'] == 'ЦБ-00182962', ['Склад','Код', 'Номенклатура', 'Группа',
       'Проба (Справочник "Номенклатура" (Общие))',
       'Артикул ',
       'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
       'Конечный остаток вес',
       'розничная стоимость', 'закупочная стоимость', 'Вставки (Справочник "Номенклатура" (Общие))', 'Вставки', 'Штрихкод', ]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-f05c304ea46d> in <module>
# ----> 1 df0.loc[df0['Код'] == 'ЦБ-00182962', ['Склад','Код', 'Номенклатура', 'Группа',
#       2        'Проба (Справочник "Номенклатура" (Общие))',
#       3        'Артикул ',
#       4        'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
#       5        'Конечный остаток вес',
#
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     773                 continue
#     774
# --> 775             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776             # We should never have retval.ndim < self.ndim, as that should
#     777             #  be handled by the _getitem_lowerdim call above.
#
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1051
#    1052         # A collection of keys
# -> 1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
#    1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1319
#    1320             with option_context("display.max_seq_items", 10, "display.width", 80):
# -> 1321                 raise KeyError(
#    1322                     "Passing list-likes to .loc or [] with any missing labels "
#    1323                     "is no longer supported. "
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: Index(['Вставки'], dtype='object'). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"

# %%
# Запрошена инф у Склада
#Временное решение 1шт Кр57
df1_exp_dia.loc[df1_exp_dia.ОГРАНКА == 'Г2', 'ОГРАНКА']
# Out:
# Series([], Name: ОГРАНКА, dtype: object)

# %%
#по 'Кр', 'МодГ', 'МодМ', 'МодРа', 'МодИ', 'МодСе' 
#Проблема с Мод решена расширением словаря
dogr_dia_discount
# Out:
# {'Baguette': 'Бп-25',
#  'Round-33': 'Бп-25',
#  'Triangle': 'Бп-25',
#  'Trilliant': 'Бп-25',
#  'Troida': 'Бп-25',
#  'Багет': 'Бп-25',
#  'Багет37': 'Бп-25',
#  'БагетНТО': 'Бп-25',
#  'Багет-25': 'Бп-25',
#  'Бп-25': 'Бп-25',
#  'Бп': 'Бп-25',
#  'БП25': 'Бп-25',
#  'БТ': 'Бп-25',
#  'БТ25': 'Бп-25',
#  'Бп-33': 'Бп-25',
#  'Брилл': 'Бп-25',
#  'Бт-25': 'Бп-25',
#  'Кайт': 'Бп-25',
#  'Кв-25': 'Бп-25',
#  'Кв-61': 'Бп-25',
#  'Кр33': 'Бп-25',
#  'Кр-33': 'Бп-25',
#  'Мод.Т': 'Бп-25',
#  'Ромб': 'Бп-25',
#  'Т-19': 'Бп-25',
#  'Тр': 'Бп-25',
#  'Тр-40': 'Бп-25',
#  'Тр-47': 'Бп-25',
#  'Тр-48': 'Бп-25',
#  'Тр-52': 'Бп-25',
#  'Трап-27': 'Бп-25',
#  'Трапеция': 'Бп-25',
#  'Треуг.': 'Бп-25',
#  'ТреугНТО': 'Бп-25',
#  'Треугольник': 'Бп-25',
#  'ТриллиантНТО': 'Бп-25',
#  'Триллиант': 'Бп-25',
#  'Тройда': 'Бп-25',
#  'БП': 'Бп-25',
#  'Кв25': 'Бп-25',
#  'КВ25': 'Бп-25',
#  'Бп25': 'Бп-25',
#  'Бт25': 'Бп-25',
#  'Бт': 'Бп-25',
#  'Багет25': 'Бп-25',
#  'Бг25': 'Бп-25',
#  'Бп26': 'Бп-25',
#  'Бп24': 'Бп-25',
#  'Бг': 'Бп-25',
#  'бт25': 'Бп-25',
#  'Трилл': 'Бп-25',
#  'Т19': 'Бп-25',
#  'Т52': 'Бп-25',
#  'Тр17': 'Бп-25',
#  'Тр49': 'Бп-25',
#  'Баг': 'Бп-25',
#  'Мод.Бп': 'Бп-25',
#  'Бг33': 'Бп-25',
#  'МодБп': 'Бп-25',
#  'Pear': 'Г-56',
#  'Г-52': 'Г-56',
#  'Г-53': 'Г-56',
#  'Г-54': 'Г-56',
#  'Г-55': 'Г-56',
#  'Г-56': 'Г-56',
#  'Г56': 'Г-56',
#  'ГрушаНТО': 'Г-56',
#  'Груша': 'Г-56',
#  'Груша-56': 'Г-56',
#  'Гр': 'Г-56',
#  'Г': 'Г-56',
#  'Мод.Г': 'Г-56',
#  'Подсолнух': 'Г-56',
#  'Гр57': 'Г-56',
#  'Гр56': 'Г-56',
#  'Г560': 'Г-56',
#  'Briolete': 'И-57',
#  'Cinnia': 'И-57',
#  'Emerald': 'И-57',
#  'NXG': 'И-57',
#  'PTG': 'И-57',
#  'TRG': 'И-57',
#  'Ашер': 'И-57',
#  'Бриолетт': 'И-57',
#  'Звезда Давида': 'И-57',
#  'И-57': 'И-57',
#  'И57': 'И-57',
#  'И-61': 'И-57',
#  'И-65': 'И-57',
#  'ИзумрудНТО': 'И-57',
#  'Изумруд-65': 'И-57',
#  'Изумруд': 'И-57',
#  'И': 'И-57',
#  'Мод.И': 'И-57',
#  'Циния': 'И-57',
#  'И65': 'И-57',
#  'Из': 'И-57',
#  'К-25': 'Кв-25',
#  'KP 17': 'Кр-17',
#  'KP-17': 'Кр-17',
#  'KP17': 'Кр-17',
#  'Круглая-17': 'Кр-17',
#  'R-17': 'Кр-17',
#  'R17': 'Кр-17',
#  'Round-17': 'Кр-17',
#  'КР 17': 'Кр-17',
#  'КР-17': 'Кр-17',
#  'КР17': 'Кр-17',
#  'Кр 17': 'Кр-17',
#  'Кр-17': 'Кр-17',
#  'Кр17': 'Кр-17',
#  'кр 17': 'Кр-17',
#  'кр-17': 'Кр-17',
#  'кр17': 'Кр-17',
#  'Кр-44': 'Кр-44',
#  'KP 57': 'Кр-57',
#  'KP-57': 'Кр-57',
#  'KP57': 'Кр-57',
#  'Круглая-57': 'Кр-57',
#  'R-57': 'Кр-57',
#  'R57': 'Кр-57',
#  'Round': 'Кр-57',
#  'КР 57': 'Кр-57',
#  'КР-57': 'Кр-57',
#  'КР57': 'Кр-57',
#  'Кр 57': 'Кр-57',
#  'Кр-57': 'Кр-57',
#  'Кр-73а': 'Кр-57',
#  'Кр-87': 'Кр-57',
#  'Кр57': 'Кр-57',
#  'Ш57': 'Кр-57',
#  'кр 57': 'Кр-57',
#  'кр-57': 'Кр-57',
#  'кр57': 'Кр-57',
#  'КР': 'Кр-57',
#  'кР57': 'Кр-57',
#  'к57': 'Кр-57',
#  'К57': 'Кр-57',
#  'Ко57': 'Кр-57',
#  'кКР57': 'Кр-57',
#  'Marquise': 'М-55',
#  'Антик': 'М-55',
#  'М-49': 'М-55',
#  'М-53': 'М-55',
#  'М55': 'М-55',
#  'М-55': 'М-55',
#  'Маркиз': 'М-55',
#  'Маркиз-55': 'М-55',
#  'Мод.М': 'М-55',
#  'Огн. Роза': 'М-55',
#  'Роза': 'М-55',
#  'Цинния': 'М-55',
#  'М': 'М-55',
#  'КрРоза': 'М-55',
#  'М550': 'М-55',
#  'НВОРоза': 'М-55',
#  'Мичил': 'Мичил',
#  'Oval': 'Овал',
#  'Мод.Ов': 'Овал',
#  'Ов-57': 'Овал',
#  'Овал ': 'Овал',
#  'Овал-61': 'Овал',
#  'Овал-57': 'Овал',
#  'Овал': 'Овал',
#  'Ов': 'Овал',
#  'ОвалНТО': 'Овал',
#  'Поллуны': 'Овал',
#  'Ов57': 'Овал',
#  'ОВ': 'Овал',
#  'ОВ57': 'Овал',
#  'Ов17': 'Овал',
#  'МодОв': 'Овал',
#  'Princess': 'Принц',
#  'Мод.П': 'Принц',
#  'П-57': 'Принц',
#  'П-65': 'Принц',
#  'ПР57': 'Принц',
#  'ПР65': 'Принц',
#  'П-73': 'Принц',
#  'Принц': 'Принц',
#  'принц': 'Принц',
#  'Принц.': 'Принц',
#  'ПринцессаНТО': 'Принц',
#  'Принцесса': 'Принц',
#  'Принцесса-57': 'Принц',
#  'Принцесса-49': 'Принц',
#  'Пр': 'Принц',
#  'П65': 'Принц',
#  'Пр75': 'Принц',
#  'П': 'Принц',
#  'ПР75': 'Принц',
#  'ПР': 'Принц',
#  'пр': 'Принц',
#  'Пр65': 'Принц',
#  'П073': 'Принц',
#  'Пр73': 'Принц',
#  'ПР73': 'Принц',
#  'П75': 'Принц',
#  'Пр57': 'Принц',
#  'Пр77': 'Принц',
#  'ПР45': 'Принц',
#  'П650': 'Принц',
#  'ПР77': 'Принц',
#  'МодП': 'Принц',
#  'Radiant': 'Радиант',
#  'Sheld': 'Радиант',
#  'Мод.Ра': 'Радиант',
#  'Ра': 'Радиант',
#  'Рад': 'Радиант',
#  'Радиант-57': 'Радиант',
#  'Радиант': 'Радиант',
#  'Радиант-кв': 'Радиант',
#  'РадиантНТО': 'Радиант',
#  'Щит': 'Радиант',
#  'Фантазия': 'Радиант',
#  'Р': 'Радиант',
#  'Р65': 'Радиант',
#  'Р61': 'Радиант',
#  'Рад65': 'Радиант',
#  'Ра65': 'Радиант',
#  'Heart': 'Сердце',
#  'Кушон': 'Сердце',
#  'кушон': 'Сердце',
#  'КУШЕН': 'Сердце',
#  'Кушен': 'Сердце',
#  'Кушэн': 'Сердце',
#  'Кушон-57': 'Сердце',
#  'Мод.Се': 'Сердце',
#  'Мод.У': 'Сердце',
#  'Подушка': 'Сердце',
#  'У-57': 'Сердце',
#  'У57': 'Сердце',
#  'У': 'Сердце',
#  'Угловатый': 'Сердце',
#  'Сердце-57': 'Сердце',
#  'Сердце': 'Сердце',
#  'моду': 'Сердце',
#  'МодУ57': 'Сердце',
#  'МодУ': 'Сердце',
#  'Тимур': 'Тимур',
#  'Кр-137': 'Тускул',
#  'Кр-41': 'Тускул',
#  'Кр-49': 'Тускул',
#  'Кр-63': 'Тускул',
#  'Кр-65': 'Тускул',
#  'Кр-73': 'Тускул',
#  'Кр-81': 'Тускул',
#  'Кр-89': 'Тускул',
#  'Круглая-89': 'Тускул',
#  'КрМ-65': 'Тускул',
#  'Тускул': 'Тускул',
#  'Кр': 'Кр-57',
#  'МодГ': 'Г-56',
#  'МодМ': 'М-55',
#  'МодРа': 'Радиант',
#  'МодИ': 'И-57',
#  'МодСе': 'Сердце'}

# %%
df1_exp_dia['КАРАТ'] = df1_exp_dia['КАРАТ'].str.replace(',','.').astype('float')

# %%
df1_exp_dia['СРКАРАТ'] = df1_exp_dia['КАРАТ']/df1_exp_dia['ШТУК']

# %%
df1_exp_dia.sort_values('СРКАРАТ')
# Out:
#               Code                art      name  \
# 6132   ЦБ-00060721          JPF21740H  Подвеска
# 7783   ЦБ-00037398            DR10526    Кольцо
# 7195   ЦБ-00003006          1С011717П    Серьги
# 46908  ЦБ-00160970          Exc380С-и    Серьги
# 30107  ЦБ-00166155   17279BD322CL0725     Колье
# ...            ...                ...       ...
# 19132  ЦБ-00096406            Exc321К    Кольцо
# 19232  ЦБ-00219603  JRZ857010GAWX13Q0    Кольцо
# 19113  ЦБ-00096401            Exc821К    Кольцо
# 19323  ЦБ-00219607  JPS159306GAWX13XX  Подвеска
# 19123  ЦБ-00096404            Exc421К    Кольцо
#
#                                                  vstavki  \
# 6132                                   21кр57-0,007-6/5А
# 7783           ТопазГ 48КР57-0,020-4/5А 24КР57-0,18-4/5А
# 7195                 2кр57-0,670-6/4А 16кр57-0,0070-3/5А
# 46908                                 134КР57-0,064-2/4А
# 30107                                  13Кр57-0,007-3/3А
# ...                                                  ...
# 19132               1КР57-8,010-8-4/5А 20КР57-1,170-3/2А
# 19232  1МодРа-8,040-8-5/5А 32Кр57-0,540-5/5А 32Кр57-0...
# 19113  1Овал-9,040-8-4/7А 10КР57-1,110-4/5А 1КР57-0,1...
# 19323               1МодУ-9,140-8-5/4А 22Кр57-0,660-5/5А
# 19123  1КР57-10,090-7/6А 11КР17-0,070-2/4А 4КР17-0,03...
#
#                            vs_dict  ШТУК ОГРАНКА   КАРАТ     ЦД ПО    Ц  Д  \
# 6132     (21, кр57, 0,007, 6/5, А)    21    кр57   0.007    6/5  А    6  5
# 7783     (48, КР57, 0,020, 4/5, А)    48    КР57   0.020    4/5  А    4  5
# 7195    (16, кр57, 0,0070, 3/5, А)    16    кр57   0.007    3/5  А    3  5
# 46908   (134, КР57, 0,064, 2/4, А)   134    КР57   0.064    2/4  А    2  4
# 30107    (13, Кр57, 0,007, 3/3, А)    13    Кр57   0.007    3/3  А    3  3
# ...                            ...   ...     ...     ...    ... ..  ... ..
# 19132   (1, КР57, 8,010, 8-4/5, А)     1    КР57   8.010  8-4/5  А  8-4  5
# 19232  (1, МодРа, 8,040, 8-5/5, А)     1   МодРа   8.040  8-5/5  А  8-5  5
# 19113   (1, Овал, 9,040, 8-4/7, А)     1    Овал   9.040  8-4/7  А  8-4  7
# 19323   (1, МодУ, 9,140, 8-5/4, А)     1    МодУ   9.140  8-5/4  А  8-5  4
# 19123    (1, КР57, 10,090, 7/6, А)     1    КР57  10.090    7/6  А    7  6
#
#          СРКАРАТ
# 6132    0.000333
# 7783    0.000417
# 7195    0.000438
# 46908   0.000478
# 30107   0.000538
# ...          ...
# 19132   8.010000
# 19232   8.040000
# 19113   9.040000
# 19323   9.140000
# 19123  10.090000
#
# [51429 rows x 13 columns]

# %%
#ручное решение на основе другого файла и сообщения Жмурова
#df1_exp_dia.loc[4985, ['КАРАТ','Code']]

# %%
#df1_exp_dia.loc[4985, 'КАРАТ'] = 0.5

# %%
25431
# Out:
# 25431

# %%
i_corr = _
i_corr
# Out:
# 25431

# %%
df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict']]
# Out:
# КАРАТ                          0.15
# vstavki            1КР57-0,150-3/4А
# vs_dict    (1, КР57, 0,150, 3/4, А)
# Name: 25431, dtype: object

# %%
#Корректировка 
#df1_exp_dia.loc[i_corr, 'КАРАТ'] = 0.05

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict']]

# %%
df1_exp_dia.dtypes
# Out:
# Code        object
# art         object
# name        object
# vstavki     object
# vs_dict     object
# ШТУК         int32
# ОГРАНКА     object
# КАРАТ      float64
# ЦД          object
# ПО          object
# Ц           object
# Д           object
# СРКАРАТ    float64
# dtype: object

# %%
#проверка по полю вида огранки.
df1_exp_dia.loc[~df1_exp_dia.ОГРАНКА.apply(lambda x: x in dogr_dia_discount)]
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д, СРКАРАТ]
# Index: []

# %% [markdown]
# ### Корректировка c = 'Д',

# %%
c = 'Д'
df1_exp_dia[c].unique()
# Out:
# array(['5', '2', '6', '4', '8', '9', '7', '3', '1', '7а', '7A', '10',
#        '11', '12', '7А'], dtype=object)

# %%
df1_exp_dia[df1_exp_dia[c]=='']
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д, СРКАРАТ]
# Index: []

# %%
#i_corr = _.index
#i_corr

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict',c]]

# %%
#Корректировка
#df1_exp_dia.loc[i_corr, c] = '5'

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict', c]]

# %% [markdown]
# ### Корректировка c = 'ПО', АА

# %%
c = 'ПО'

df1_exp_dia[c].unique()
# Out:
# array(['А', 'Б', 'Г', 'В', 'а', 'б', 'в'], dtype=object)

# %%
df1_exp_dia[df1_exp_dia[c]=='АА']
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д, СРКАРАТ]
# Index: []

# %%
#i_corr = _.index
#i_corr

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict',c]]

# %%
#Корректировка
#df1_exp_dia.loc[i_corr, c] = 'А'

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict', c]]

# %% [markdown]
# ### Корректировка c = 'Ц', 8

# %%
c = 'Ц'
df1_exp_dia[c].unique()
# Out:
# array(['4', '2', '3', '6', '1', '5', '7', '8-2', '8-5', '9-1', '8-1',
#        '9-2', '6-1', '8-3', '9-4', '9-3', '8-4', '8.5'], dtype=object)

# %%
df1_exp_dia[df1_exp_dia[c]=='8']
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д, СРКАРАТ]
# Index: []

# %%
#i_corr = _.index
#i_corr

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict',c]]

# %%
#Корректировка
#df1_exp_dia.loc[i_corr, c] = '8-2'

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict', c]]

# %%
5657
# Out:
# 5657

# %% [markdown]
# ### Корректировка c = 'ШТУК'

# %%
c = 'ШТУК'
df1_exp_dia[c].unique()
# Out:
# array([ 45,   2,   4,   6,   3,   1,  12,   5,  10,   7,  14,  32,  20,
#         22,  44,  52,  28,  29,  46,  34,  60,  18,  42,  82,  69,  97,
#          8,  56,  54,  27,  50,  62,  16,  26,  25,  11,   9,  13,  15,
#         40,  24, 134,  48,  23,  21,  36,  58,  19,  31,  38,  17,  30,
#         70,  80, 114,  90,  84, 108,  68,  76, 140,  57,  35,  66,  33,
#         92, 105,  59, 153,  43,  89,  74, 102,  64, 120,  72,  75,  53,
#         47,  67,  78,  39,  88,  49, 216, 209, 103, 100,  83,  81, 401,
#        836,  99,  86, 183,  41, 590,  61,  55, 147,  65, 289,  51,  37,
#         87, 418, 107, 106, 205, 119, 132, 262,  98, 137, 200, 337,  63,
#        152, 136, 182, 194, 263,  91, 130, 131, 171, 500, 178, 328, 241,
#        180, 160, 187,  85, 157, 110,  71,  96, 361, 305, 273,  93, 113,
#        129,  94, 112,  95, 164, 139, 166, 116,  73, 207, 115, 148, 138,
#        124, 163, 141,  79, 400, 104, 142, 165, 118, 128, 312, 125,  77,
#        167, 196, 229, 534, 267, 257, 181, 370, 122, 254, 373, 224, 367,
#        117, 206, 201, 371, 210, 635, 299, 162, 324, 388, 154, 143, 170,
#        176, 204, 385, 150, 175, 158, 285, 255, 230, 111, 353, 189, 121,
#        264, 506, 431, 198, 236, 109, 321])

# %%
df1_exp_dia[df1_exp_dia[c]==5657]
# Out:
# Empty DataFrame
# Columns: [Code, art, name, vstavki, vs_dict, ШТУК, ОГРАНКА, КАРАТ, ЦД, ПО, Ц, Д, СРКАРАТ]
# Index: []

# %%
#i_corr = _.index
#i_corr

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict',c]]

# %%
#Корректировка
#df1_exp_dia.loc[i_corr, c] = 56

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict', c]]

# %%
#проверка по полю вида огранки.
df1_exp_dia.loc[~df1_exp_dia.ОГРАНКА.apply(lambda x: x in dogr_dia_discount), 'ОГРАНКА']
# Out:
# Series([], Name: ОГРАНКА, dtype: object)

# %% [markdown]
# ### Корректировка c = 'КАРАТ'

# %%
c = 'КАРАТ'
df1_exp_dia[c].unique()
# Out:
# array([5.200e-01, 8.300e-02, 8.400e-02, 2.800e-01, 9.500e-02, 8.600e-02,
#        6.000e-02, 5.000e-02, 3.100e-02, 1.400e-02, 2.700e-02, 1.700e-02,
#        1.170e-01, 5.100e-02, 7.000e-02, 9.000e-02, 1.100e-01, 9.000e-03,
#        8.000e-02, 1.400e-01, 3.000e-02, 1.000e-01, 2.000e-02, 1.800e-01,
#        1.200e-01, 4.000e-02, 2.800e-02, 5.000e-03, 1.300e-01, 2.110e-01,
#        2.350e-01, 3.200e-01, 1.830e-01, 1.230e-01, 2.100e-01, 1.250e-01,
#        2.200e-01, 2.600e-01, 1.000e-02, 1.900e-01, 3.400e-01, 3.100e-01,
#        4.000e-01, 1.380e-01, 1.600e-01, 2.700e-01, 3.300e-01, 1.180e-01,
#        1.500e-01, 2.500e-01, 3.500e-01, 5.400e-01, 5.700e-01, 5.800e-01,
#        4.300e-01, 2.300e-01, 4.800e-01, 3.840e-01, 2.470e-01, 8.700e-02,
#        5.600e-02, 7.940e-01, 8.500e-02, 5.700e-02, 2.900e-01, 2.000e-01,
#        2.760e-01, 2.930e-01, 1.390e-01, 3.150e-01, 3.900e-02, 5.300e-01,
#        1.700e-01, 1.950e-01, 4.200e-01, 3.020e-01, 4.350e-01, 3.900e-01,
#        2.790e-01, 4.710e-01, 1.330e-01, 1.790e-01, 2.270e-01, 4.500e-02,
#        4.300e-02, 1.190e-01, 2.280e-01, 5.050e-01, 1.460e-01, 1.050e-01,
#        2.150e-01, 2.400e-01, 5.800e-02, 6.600e-01, 3.770e-01, 3.000e-01,
#        2.250e-01, 4.200e-02, 1.430e-01, 5.460e-01, 1.580e-01, 3.720e-01,
#        7.500e-02, 3.270e-01, 2.100e-02, 3.220e-01, 1.500e-02, 5.000e-01,
#        3.310e-01, 5.500e-02, 3.810e-01, 2.130e-01, 1.320e-01, 1.130e-01,
#        2.360e-01, 2.180e-01, 6.100e-02, 4.900e-02, 3.800e-02, 2.550e-01,
# 19119   5.13               1Кушон-5,130-8-5/6Б 6КР57-0,320-2/2А     5.13     1
# 19088   5.13  1Груша-5,130-8-5/7аА 3КР57-0,100-3/5А 1КР57-0,...     5.13     1
# 19110   5.13  1Радиант-5,130-6/8А 1КР57-0,220-3/5А 1КР57-0,2...     5.13     1
# 19147   5.14  1КР57-5,140-8-5/7А 4КР57-0,040-3/3Б 120КР57-1,...     5.14     1
# 19331   5.53  1КР57-5,590-8-1/7А 36КР57-1,950-2/2А 26КР57-1,...     5.53     1
# 19328   5.59  1КР57-5,590-8-1/7А 36КР57-1,950-2/2А 26КР57-1,...     5.59     1
# 19275   6.16  1Кр57-6,160-8-4/6А 1Кр57-0,110-1/4Б 3Кр57-0,38...     6.16     1
# 19220   7.28  1МодГ-7,280-6/8А 34Кр57-0,760-5/5А 12Кр57-0,30...     7.28     1
# 19140   8.00  1КР57-8,000-8-4/7А 21КР17-0,170-3/4А 7КР17-0,0...     8.00     1
# 19242   8.01  1МодИ-8,010-4/7А 44Кр57-0,410-5/5А 52Кр57-0,33...     8.01     1
# 19132   8.01               1КР57-8,010-8-4/5А 20КР57-1,170-3/2А     8.01     1
# 19232   8.04  1МодРа-8,040-8-5/5А 32Кр57-0,540-5/5А 32Кр57-0...     8.04     1
# 19113   9.04  1Овал-9,040-8-4/7А 10КР57-1,110-4/5А 1КР57-0,1...     9.04     1
# 19323   9.14               1МодУ-9,140-8-5/4А 22Кр57-0,660-5/5А     9.14     1
# 19123  10.09  1КР57-10,090-7/6А 11КР17-0,070-2/4А 4КР17-0,03...    10.09     1

# %%
#df1_exp_dia[df1_exp_dia[c]=='']

# %%
#i_corr = _.index
#i_corr

# %%
#del i_corr

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict',c]]

# %%
#Корректировка
#df1_exp_dia.loc[i_corr, c] = 56

# %%
#df1_exp_dia.loc[i_corr, ['КАРАТ','vstavki', 'vs_dict', c]]

# %% [markdown]
# ### ПРОБЛЕМА 3 нулевые массы

# %%
df1_exp_dia.loc[df1_exp_dia['СРКАРАТ'] == 0, 'Code' ].to_list()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'СРКАРАТ'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-01f0303244ac> in <module>
# ----> 1 df1_exp_dia.loc[df1_exp_dia['СРКАРАТ'] == 0, 'Code' ].to_list()
#
# C:\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'СРКАРАТ'

# %%
df0.loc[df0['Код'].isin(df1_exp_dia.loc[df1_exp_dia['СРКАРАТ'] == 0, 'Code' ].to_list()),[ 'Код','Вставки (Справочник "Номенклатура" (Общие))', 'Вставки'] ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'СРКАРАТ'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-75b0094cea9f> in <module>
# ----> 1 df0.loc[df0['Код'].isin(df1_exp_dia.loc[df1_exp_dia['СРКАРАТ'] == 0, 'Code' ].to_list()),[ 'Код','Вставки (Справочник "Номенклатура" (Общие))', 'Вставки'] ]
#
# C:\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'СРКАРАТ'

# %%
df0.loc[df0['Код'].isin(df1_exp_dia.loc[df1_exp_dia['СРКАРАТ'] == 0, 'Code' ].to_list()),
        'Вставки (Справочник "Номенклатура" (Общие))'].to_list()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'СРКАРАТ'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-8a5e190a4f79> in <module>
# ----> 1 df0.loc[df0['Код'].isin(df1_exp_dia.loc[df1_exp_dia['СРКАРАТ'] == 0, 'Code' ].to_list()),
#       2         'Вставки (Справочник "Номенклатура" (Общие))'].to_list()
#
# C:\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'СРКАРАТ'

# %%
df0.loc[df0['Код'].isin(df1_exp_dia.loc[df1_exp_dia['СРКАРАТ'] == 0, 'Code' ].to_list()),
        'Вставки'].to_list()
# Out:
# ['1Г56-1,15-5/4Б 1Ов57-0,51-8-5/7а 1Ов57-0,-8.5/4А 10кр57-0,14-3/5А 36кр57-0,35-3/5А 147кр57-0,83-3/5А',
#  '2Кр57-0,01-6/5А 36Кр57-0,23-6/5А 1Кр57-0,01-6/5А 1Кр57-0-6/5А 1Кр57-0-6/5А',
#  'жемчугБ 4кр17-0,0-2/4А 5кр17-0,0-3/3А']

# %%
df0.loc[df0['Код'].isin(df1_exp_dia.loc[df1_exp_dia['СРКАРАТ'] == 0, 'Code' ].to_list()),
        ['Склад','Код', 'Номенклатура', 'Группа',
       'Проба (Справочник "Номенклатура" (Общие))',
       'Артикул ',
       'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
       'Конечный остаток вес',
       'розничная стоимость', 'закупочная стоимость', 'Вставки (Справочник "Номенклатура" (Общие))', 'Вставки', 'Штрихкод', ]]
# Out:
#            Склад          Код Номенклатура                       Группа  \
# 2933     Иркутск  ЦБ-00040270       Кольцо                      № 37 дк
# 11370     Мирный  ЦБ-00041091     Подвеска     SM19-01 от 27.09.2019 ДК
# 15135  Хабаровск  ЦБ-00017807       Кольцо  т.н. 229 от 02.06.2011г. ДК
#
#        Проба (Справочник "Номенклатура" (Общие))    Артикул   \
# 2933                                         750     YR3579W
# 11370                                        585   JAP00140Q
# 15135                                        750  2201350410
#
#                родитель2_1c           родитель3_1c  \
# 2933      Невский Бриллиант    №10-159 от 30.06.14
# 11370     Ювелирные изделия  Саха Минералс Лимитед
# 15135  Туймаада Даймонд ОАО   10-265 от 01.06.2011
#
#                       родитель4_1c  Конечный остаток вес  розничная стоимость  \
# 2933                       № 37 дк                 10.53            1596028.0
# 11370     SM19-01 от 27.09.2019 ДК                  0.99              48538.0
# 15135  т.н. 229 от 02.06.2011г. ДК                  2.79              20388.0
#
#        закупочная стоимость  \
# 2933              454644.07
# 11370              16179.38
# 15135               7259.49
#
#              Вставки (Справочник "Номенклатура" (Общие))  \
# 2933                                                 NaN
# 11370  2Кр57-0,01-6/5А 36Кр57-0,23-6/5А 1Кр57-0,01-6/...
# 15135                                                NaN
#
#                                                  Вставки      Штрихкод
# 2933   1Г56-1,15-5/4Б 1Ов57-0,51-8-5/7а 1Ов57-0,-8.5/...  2.000000e+12
# 11370  2Кр57-0,01-6/5А 36Кр57-0,23-6/5А 1Кр57-0,01-6/...  2.000000e+12
# 15135              жемчугБ 4кр17-0,0-2/4А 5кр17-0,0-3/3А  2.000000e+12

# %% [markdown]
# ### КОНЕЦ ПРОБЛЕМ 1 - 2 - 3
