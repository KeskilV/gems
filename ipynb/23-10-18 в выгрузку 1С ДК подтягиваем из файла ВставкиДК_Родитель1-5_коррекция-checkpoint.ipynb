# %% [markdown]
# см readme
# C:\Users\специалист ао\mypandas\work\2023\23-09-ХХ Переоценка ДК магазины выст\ReadMe2023-10-18.docx
#
# Код
#
# - подтягивания поля вставки из файла ВставкиДК_Родитель1-5_коррекция

# %% [markdown]
# # imports

# %%
import numpy as np
import pandas as pd
import re
import os

# %%
from rusprice.dictdiamonds import dcol_dia, dcla_dia, dpo_dia, dogr_dia_discount
#import rusprice.func_rpdiamonds_xlsx_v2022_2_CARtoKVG_v2 as func_rpdiamonds_v2
#func_rpdiamonds_xlsx_v2023_1_CARtoKVG.py
import rusprice.func_rpdiamonds_xlsx_v2023_1_CARtoKVG as func_rpdiamonds_v2

# %%
folder = '../'
#cm readme

folder_res = folder+'for_script/'
folder_res
# Out:
# '../for_script/'

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Входные данные

# %% [markdown]
# ## из 1С

# %%
#1. Вводные/

# %%
os.listdir(folder+'1 Вводные/')
# Out:
# ['выгрузка УТ 2023-08-10',
#  'Выгрузка УТ 2023-09-19',
#  'выгрузка УТ 2023-10-12',
#  'выгрузка УТ 2023-10-15',
#  'Выгрузки ЮТД 2023-10-13',
#  'Номенклатура код ЦБ по УТ из регистра сведений.xlsx']

# %%
files = os.listdir(folder+'1 Вводные/выгрузка УТ 2023-10-15')
files
# Out:
# ['Остатки1СУТ__все_склады_ДК_2023-10-15_закупочные.xlsx',
#  'Остатки1СУТ__все_склады_ДК_2023-10-15_розница.xlsx']

# %%
list(enumerate(files))
# Out:
# [(0, 'Остатки1СУТ__все_склады_ДК_2023-10-15_закупочные.xlsx'),
#  (1, 'Остатки1СУТ__все_склады_ДК_2023-10-15_розница.xlsx')]

# %%
filename_z = files[0]
filename_r= files[1]
filename_z, filename_r
# Out:
# ('Остатки1СУТ__все_склады_ДК_2023-10-15_закупочные.xlsx',
#  'Остатки1СУТ__все_склады_ДК_2023-10-15_розница.xlsx')

# %%
df_z = pd.read_excel(folder+'1 Вводные/выгрузка УТ 2023-10-15/'+filename_z,header=9)#, dtype={5: str}

# %%
#Вывести итог таблицы
df_z.iloc[len(df_z)-1][[ 'Количество конечный остаток', 'Конечный остаток вес',
       'Оценка (конечный остаток)']]
# Out:
# Количество конечный остаток        34269.0
# Конечный остаток вес             122668.35
# Оценка (конечный остаток)      880921254.3
# Name: 34286, dtype: object

# %% [markdown]
# на 09-15-2023 ут
#
# Количество конечный остаток        34,269.00
# Конечный остаток вес              122,668.35
# Оценка (конечный остаток)     880,921,254.30
# Name: 34286, dtype: object
# на 09-10-2023 ут
# Количество конечный остаток         34334.0
# Конечный остаток вес              122885.73
# Оценка (конечный остаток)      883196152.97
# Name: 34350, dtype: object
#
# на 19-09-2023 ут?
# Количество конечный остаток         34528.0
# Конечный остаток вес              123441.14
# Оценка (конечный остаток)      888714246.96
# Name: 34544, dtype: object

# %%
df_z.dropna(subset=['Код'], inplace=True)

# %%
#Вывести сумм таблицы
df_z[[ 'Количество конечный остаток', 'Конечный остаток вес',
       'Оценка (конечный остаток)']].sum()
# Out:
# Количество конечный остаток        34,269.00
# Конечный остаток вес              122,668.35
# Оценка (конечный остаток)     880,921,254.30
# dtype: float64

# %% [markdown]
# на 13-10-2023 ут?
# Количество конечный остаток    3.433400e+04
# Конечный остаток вес           1.228857e+05
# Оценка (конечный остаток)      8.831962e+08
# dtype: float64
# на 19-09-2023 ут?
# Количество конечный остаток    3.452800e+04
# Конечный остаток вес           1.234411e+05
# Оценка (конечный остаток)      8.887142e+08
# dtype: float64

# %%
# Загрузка файла с розничными ценами

# %%
df_r = pd.read_excel(folder+'1 Вводные/выгрузка УТ 2023-10-15/'+filename_r,header=9)#, dtype={5: str}

# %%
#Вывести итог таблицы
df_r.iloc[len(df_r)-1][[ 'Количество конечный остаток', 'Конечный остаток вес',
       'Оценка (конечный остаток)']]
# Out:
# Количество конечный остаток          34,269.00
# Конечный остаток вес                122,668.35
# Оценка (конечный остаток)     2,908,177,532.89
# Name: 34286, dtype: object

# %% [markdown]
# на 13-10-2023
# Количество конечный остаток          34334.0
# Конечный остаток вес               122885.73
# Оценка (конечный остаток)      2915863314.89
# Name: 34350, dtype: object

# %%
на 19-09-2023 ут?
Количество конечный остаток          34528.0
Конечный остаток вес               123441.14
Оценка (конечный остаток)      2935241509.89
Name: 34544, dtype: object

# %%
df_r.dropna(subset=['Код'], inplace=True)

# %%
#Вывести сумм таблицы
df_r[[ 'Количество конечный остаток', 'Конечный остаток вес',
       'Оценка (конечный остаток)']].sum()
# Out:
# Количество конечный остаток          34,269.00
# Конечный остаток вес                122,668.35
# Оценка (конечный остаток)     2,908,177,532.89
# dtype: float64

# %% [markdown]
# Количество конечный остаток    3.433400e+04
# Конечный остаток вес           1.228857e+05
# Оценка (конечный остаток)      2.915863e+09
# dtype: float64

# %% [markdown]
# на 19-09-2023 ут?
# Количество конечный остаток    3.452800e+04
# Конечный остаток вес           1.234411e+05
# Оценка (конечный остаток)      2.935242e+09
# dtype: float64

# %%
df_r.rename(columns={'Оценка (конечный остаток)':'розничная стоимость'}, inplace=True)

# %%
df_z.rename(columns={'Оценка (конечный остаток)':'закупочная стоимость'}, inplace=True)

# %%
#проверка соответствия кодов
len(df_r['Код'].unique()) ,len(df_r)
# Out:
# (34269, 34269)

# %%
len(df_z['Код'].unique()) ,len(df_z)
# Out:
# (34269, 34269)

# %%
set(df_z['Код'].unique()) == set(df_r['Код'].unique())
# Out:
# True

# %%
#Присоединяем к стоимости df_1c
df_1c = pd.merge(df_r,df_z[['Код', 'закупочная стоимость']]
                           ,how='left',right_on='Код',left_on='Код')

# %%
df_1c[['закупочная стоимость','розничная стоимость']].sum()
# Out:
# закупочная стоимость     880,921,254.30
# розничная стоимость    2,908,177,532.89
# dtype: float64

# %%
df_1c.columns
# Out:
# Index(['Склад', 'Unnamed: 1', 'Unnamed: 2', 'Код', 'Unnamed: 4',
#        'Старый код (Справочник "Номенклатура" (Общие))', 'Склад.1',
#        'Склад.Склад / Магазин', 'Unnamed: 8',
#        'Вставки (Справочник "Номенклатура" (Общие))', 'Вид номенклатуры',
#        'Тип номенклатуры', 'Номенклатура', 'Группа',
#        'Заводской номер (Справочник "Номенклатура" (Общие))',
#        'Проба (Справочник "Номенклатура" (Общие))',
#        'Цвет металла (Справочник "Номенклатура" (Общие))',
#        'Дизайн (Справочник "Номенклатура" (Общие))', 'Артикул ',
#        'Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))',
#        'Цвет Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Чистота Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Размер (Справочник "Номенклатура" (Общие))', 'Наименование для печати',
#        'Единица измерения веса',
#        'Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))',
#        'Кол-во ДК (Справочник "Номенклатура" (Общие))',
#        'Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))', 'Группы',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Количество конечный остаток', 'Конечный остаток вес',
#        'розничная стоимость', 'закупочная стоимость'],
#       dtype='object')

# %%
for x in ['Склад', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4','Unnamed: 8','Склад.1','Unnamed: 33',  'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31','Unnamed: 32']:
    print(x, df_1c[x].unique()[:13])
# Out:
# Склад [nan]
# Unnamed: 1 [nan]
# Unnamed: 2 [nan]
# Unnamed: 4 [nan]
# Unnamed: 8 [nan]
# Склад.1 ['Благовещенск' 'Выставочный' 'Интернет-магазин' 'Иркутск' 'Кружало'
#  'Ленина, 28' 'Ленина23' 'Ленск' 'Мирный' 'Московское представительство'
#  'Новосибирск' 'Пассаж' 'Склад "В пути"']
# Unnamed: 33 [nan 'Сахаювелир ООО']
# Unnamed: 29 ['Ювелирные изделия' nan 'Драгоценности Якутии ООО' 'МИЗО'
#  'Сахаювелир ООО' 'Кристалл 2001  ООО' 'СУВЕНИРЫ' 'Золото Якутии ОАО АПЮК'
#  'Разные поставщики' '0']
# Unnamed: 30 ['Саха Минералс Лимитед' 'Ювелирные изделия' 'ИП "Алексеев В.М."'
#  '№ 06-329/2 от 12.12.16' 'Драгоценности Якутии ООО' 'Сахаювелир ООО'
#  '№03/10-212 от 05.11.07' '№6/2-08-КП от 14.01.2008г.' 'Невский Бриллиант'
#  'Золото Якутии ОАО АПЮК' 'Сапфир М ООО' '№11/08-КП от 21.01.2008г.'
#  'Покровский гранильный завод ООО']
# Unnamed: 31 ['Sakha Minerals Limited SM21-01 от 28.09.2021' 'Из Москвы'
#  '10-271 от 21.12.2018' '06-329/2 от 12.12.2016 Задание №4'
#  '06-341/4 от 26.12.2016' '03/10-95 от 15.05.08' '89/1/06 от 20.04.06'
#  'ДЯ 03/10-212 от 05.11.07 (18 партия)' '3 партия'
#  '06-329/2 от 12.12.16 задание 6' 'SM10-04 от 11.10.2011 доп2'
#  '№10-159 от 30.06.14' '06-13 от 24.01.2011г.']
# Unnamed: 32 ['спецификация №1 от 27.01.2022г.' 'Товар ДК' 'Броши' 'накл.№5' '51 ДК'
#  '64/08 от 15.05.08 дк' 'Тн №1067/06 от 31.10.06 (ДК и ПДК)585+750'
#  'Рнк-1335 от 09.11.07 дк 18п' '1679 от 14.01.08 ДК 3п'
#  'Рнк-1332 от 09.11.07 дк 18п' 'Рнк-1291 от 09.11.07 дк 18п'
#  'Рнк-1324 от 09.11.07 дк 18п' 'Кольца ДК']

# %%
df_1c.drop(['Склад', 'Unnamed: 1', 'Unnamed: 2','Unnamed: 4','Unnamed: 8'], axis=1, inplace=True)

# %%
df_1c.rename(columns={'Склад.1':'Склад','Unnamed: 29':'родитель1_1c', 'Unnamed: 30':'родитель2_1c',
                      'Unnamed: 31':'родитель3_1c', 'Unnamed: 32':'родитель4_1c', 'Unnamed: 33':'родитель5_1c'},
            inplace=True)

# %%
df_1c
# Out:
#                Код Старый код (Справочник "Номенклатура" (Общие))  \
# 0      ЦБ-00200503                                            NaN
# 1      ЦБ-00002854                                     МС00057368
# 2      ЦБ-00019951                                     МС00152100
# 3      ЦБ-00019953                                     МС00146311
# 4      ЦБ-00111074                                     МС00111422
# ...            ...                                            ...
# 34264  ЦБ-00182016                                     0000032928
# 34265  ЦБ-00182017                                     0000032929
# 34266  ЦБ-00182019                                     0000032934
# 34267  ЦБ-00182020                                     0000032935
# 34268  ЦБ-00182021                                     0000032936
#
#                    Склад Склад.Склад / Магазин  \
# 0           Благовещенск     Розничный магазин
# 1           Благовещенск     Розничный магазин
# 2           Благовещенск     Розничный магазин
# 3           Благовещенск     Розничный магазин
# 4           Благовещенск     Розничный магазин
# ...                  ...                   ...
# 34264  Ювелирные изделия         Оптовый склад
# 34265  Ювелирные изделия         Оптовый склад
# 34266  Ювелирные изделия         Оптовый склад
# 34267  Ювелирные изделия         Оптовый склад
# 34268  Ювелирные изделия         Оптовый склад
#
#              Вставки (Справочник "Номенклатура" (Общие)) Вид номенклатуры  \
# 0                                      45КР57-0,520-4/5А     Т ДМ Юи с ДК
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...     Т ДМ Юи с ДК
# 2                                       1Кр57-0,086-4/5А     П ДМ Юи с ДК
# 3                                        3Кр57-0,06-4/5А     П ДМ Юи с ДК
# 4      1Кр57-0,050-4/5А 1Кр57-0,031-6/6А 1Кр57-0,014-...     Т ДМ Юи с ДК
# ...                                                  ...              ...
# 34264                                                NaN     Т ДМ Юи с ДК
# 34265                                                NaN     Т ДМ Юи с ДК
# 34266                                                NaN     Т ДМ Юи с ДК
# 34267                                                NaN     Т ДМ Юи с ДК
# 34268                                                NaN     Т ДМ Юи с ДК
#
#       Тип номенклатуры Номенклатура                           Группа  \
# 0                Товар      Браслет  спецификация №1 от 27.01.2022г.
# 1                Товар      Браслет                         Товар ДК
# 2                Товар        Брошь                            Броши
# 3                Товар        Брошь                          накл.№5
# 4                Товар        Брошь                            51 ДК
# ...                ...          ...                              ...
# 34264            Товар  серьги с ДК        Акт №1 АК "Золото Якутии"
# 34265            Товар  серьги с ДК        Акт №1 АК "Золото Якутии"
# 34266            Товар  серьги с ДК        Акт №1 АК "Золото Якутии"
# 34267            Товар  серьги с ДК        Акт №1 АК "Золото Якутии"
# 34268            Товар  серьги с ДК        Акт №1 АК "Золото Якутии"
#
#       Заводской номер (Справочник "Номенклатура" (Общие))  ...  \
# 0                                                    512   ...
# 1                                               30575,51   ...
# 2                                                1191890   ...
# 3                                                   1094   ...
# 4                                                    422   ...
# ...                                                  ...   ...
# 34264                                           01-12308   ...
# 34265                                           01-12309   ...
# 34266                                           01-14045   ...
# 34267                                           01-14046   ...
# 34268                                           01-14047   ...
#
#                   Группы              родитель1_1c              родитель2_1c  \
# 0                    NaN         Ювелирные изделия     Саха Минералс Лимитед
# 1                    NaN                       NaN         Ювелирные изделия
# 2                    NaN         Ювелирные изделия        ИП "Алексеев В.М."
# 3      Ювелирные изделия  Драгоценности Якутии ООО    № 06-329/2 от 12.12.16
# 4                    NaN         Ювелирные изделия  Драгоценности Якутии ООО
# ...                  ...                       ...                       ...
# 34264                NaN         Ювелирные изделия    Золото Якутии ОАО АПЮК
# 34265                NaN         Ювелирные изделия    Золото Якутии ОАО АПЮК
# 34266                NaN         Ювелирные изделия    Золото Якутии ОАО АПЮК
# 34267                NaN         Ювелирные изделия    Золото Якутии ОАО АПЮК
# 34268                NaN         Ювелирные изделия    Золото Якутии ОАО АПЮК
#
#                                        родитель3_1c  \
# 0      Sakha Minerals Limited SM21-01 от 28.09.2021
# 1                                         Из Москвы
# 2                              10-271 от 21.12.2018
# 3                 06-329/2 от 12.12.2016 Задание №4
# 4                            06-341/4 от 26.12.2016
# ...                                             ...
# 34264                                   Из магазина
# 34265                                   Из магазина
# 34266                                   Из магазина
# 34267                                   Из магазина
# 34268                                   Из магазина
#
#                           родитель4_1c родитель5_1c  \
# 0      спецификация №1 от 27.01.2022г.          NaN
# 1                             Товар ДК          NaN
# 2                                Броши          NaN
# 3                              накл.№5          NaN
# 4                                51 ДК          NaN
# ...                                ...          ...
# 34264        Акт №1 АК "Золото Якутии"          NaN
# 34265        Акт №1 АК "Золото Якутии"          NaN
# 34266        Акт №1 АК "Золото Якутии"          NaN
# 34267        Акт №1 АК "Золото Якутии"          NaN
# 34268        Акт №1 АК "Золото Якутии"          NaN
#
#       Количество конечный остаток Конечный остаток вес розничная стоимость  \
# 0                            1.00                 7.89          185,375.00
# 1                            1.00                13.10          333,693.00
# 2                            1.00                 3.92           29,041.00
# 3                            1.00                 5.32           33,789.00
# 4                            1.00                 2.72           52,866.00
# ...                           ...                  ...                 ...
# 34264                        1.00                 3.71                 NaN
# 34265                        1.00                 3.71                 NaN
# 34266                        1.00                 3.67                 NaN
# 34267                        1.00                 3.66                 NaN
# 34268                        1.00                 3.57                 NaN
#
#       закупочная стоимость
# 0                61,791.55
# 1                83,173.87
# 2                 9,680.06
# 3                14,078.47
# 4                21,693.89
# ...                    ...
# 34264             5,446.00
# 34265             5,446.00
# 34266             3,850.00
# 34267             3,850.00
# 34268             3,850.00
#
# [34269 rows x 33 columns]

# %%
#Если без самородков, пропуск 3
df_1c_res = df_1c

# %% [markdown]
# # Подтянуть массу самородков

# %% [markdown]
# ## подтянуть масса самородков из '3.1. Самородки Сводка.xlsx',

# %%
files = os.listdir(folder+'1. Вводные/Веса самородков/')
files
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-06d09a2f1515> in <module>
# ----> 1 files = os.listdir(folder+'1. Вводные/Веса самородков/')
#       2 files
#
# FileNotFoundError: [WinError 3] Системе не удается найти указанный путь: '//UR-JVV/Users/DAS/Desktop/GM TMP/Analytics/Проекты в работе/23-09-ХХ Переоценка ДК магазины выст/1. Вводные/Веса самородков/'

# %%
[x for x in enumerate(files)]

# %%
df_sm1 = pd.read_excel(folder+'1. Вводные/Веса самородков/'+files[1])#,header=9)#, dtype={5: str}

# %%
df_sm1.dropna(subset=['№ столбца'], inplace=True)

# %%
 df_sm1[['Код', 'Артикул', 'Вес изделия','Вес самородка (общий суммированный)']]

# %%
#проверка кода
len(df_sm1['Код'].unique()), len(df_sm1)

# %%
#Присоединяем к df_1c
df_1c = pd.merge(df_1c ,df_sm1[['Код', 'Вес самородка (общий суммированный)']]
                           ,how='left',right_on='Код',left_on='Код')

# %%
#присоеденил массу самородка к df_1c, проверяем сколько не получило массу 
df_1c['Вес самородка (общий суммированный)'].isna().sum()

# %%
#Кто без цены
df_1c[df_1c['Вес самородка (общий суммированный)'].isna()]

# %%
#df_1c['Проба самородка'].unique() -> array([894.,  nan, 885., 932., 889., 810., 890., 820., 875.])

# %% [markdown]
# ## подтянуть масса самородков из '22-09-23 ДК и самородки На утверждение.xlsm'

# %% [markdown]
# ### считываем файл срезаем самородки

# %%
files = os.listdir(folder+'1. Вводные/Веса самородков/')
files

# %%
[x for x in enumerate(files)]

# %%
df_sm2 = pd.read_excel(folder+'1. Вводные/Веса самородков/'+files[0])#,header=9)#, dtype={5: str}

# %%
df_sm2.columns

# %%
df_sm2[['Наименование изделия', 'Артикул', 'Проба','Вес, грамм', 'Учётная стоимость','Вес золотого самородка (общий суммированный)']]

# %%
df_sm2.dropna(subset=['Вес золотого самородка (общий суммированный)'], inplace=True)

# %% [markdown]
# ### Создаем ключи и присоединяем массу самородка

# %%
#проблема в том что данный файл без ключа, поэтому подтягиваем по совокупному совпадению - 
#- 'Номенклатура','Артикул ', 'Конечный остаток вес'

# %%
#проверка уникальности ключа
len((df_sm2['Наименование изделия']+df_sm2['Артикул'].astype('str')+df_sm2['Вес, грамм'].astype('str')).unique())

# %%
len(df_sm2)#.dropna(subset=['Вес, грамм']))

# %%
df_1c_33 = df_1c[df_1c['Вес самородка (общий суммированный)'].isna()].copy()

# %%
df_1c_33['key'] = df_1c_33[['Номенклатура','Артикул ',
  'Конечный остаток вес']].apply(lambda x: x['Номенклатура']+str(x['Артикул '])+str(x['Конечный остаток вес']),
                                 axis=1)

# %%
df_sm2['key'] = df_sm2[['Наименование изделия', 'Артикул',
        'Вес, грамм']].apply(lambda x: x['Наименование изделия']+str(x['Артикул'])+str(x['Вес, грамм']),
                                 axis=1)

# %%
len(set(df_sm2['key'])),len(df_sm2['key'])

# %%
len(set(df_1c_33['key'])),len(df_1c_33['key'])

# %%
#Этих из наличия нет в 27 утвержденных 9 шт из них  "Самородок Севера" понятно, тк это имитация  
set(df_1c_33['key']) - set(df_sm2['key'])

# %%
#Эти есть в утверждении но нет в наличии - видимо проданы 
set(df_sm2['key'])-set(df_1c_33['key'])

# %%
#set(df_1c_33['key']).intersection(set(df_sm2['key']))

# %%
#Присоединяем к df_1c
df_1c_33 = pd.merge(df_1c_33,
         df_sm2[['Вес золотого самородка (общий суммированный)','key']],
         how='left',
         right_on=['key'],
         left_on=['key']
         )

# %%
#Список без массы самородка
df_1c_33[df_1c_33['Вес золотого самородка (общий суммированный)'].isna()]

# %%
df_1c_454 = df_1c[~df_1c['Вес самородка (общий суммированный)'].isna()].copy()

# %%
folder_res

# %%
#запись промрезультата для проверки на excel
pd.concat([df_1c_454,df_1c_33]).to_excel(folder_res+'df_1c_ms.xlsx')

# %% [markdown]
# ## Сборка файла результата сборки весов самородков

# %%
df_1c_454.columns

# %%
df_1c_33.columns

# %%
df_1c_33['вес самородка'] = df_1c_33['Вес золотого самородка (общий суммированный)']
df_1c_454['вес самородка'] = df_1c_454['Вес самородка (общий суммированный)']

# %%
df_1c_res = pd.concat([df_1c_454,df_1c_33])

# %%
df_1c_res['вес самородка'].isna().sum()

# %%
#Вывести сумм таблицы
df_1c_res[[ 'Количество конечный остаток', 'Конечный остаток вес',
           'розничная стоимость', 'закупочная стоимость', 'вес самородка'
          ]].sum()

# %% [markdown]
# должно быть
# Количество конечный остаток         487.00
# Конечный остаток вес               3537.87
# Оценка (конечный остаток)      12375195.96
# dtype: float64

# %%
df_1c_res['источник веса самородка'] = np.nan

# %%
df_1c_res.loc[(~df_1c_res['Вес золотого самородка (общий суммированный)'].isna()),
              'источник веса самородка'] =  '22-09-23 ДК и самородки На утверждение.xlsm'

# %%
df_1c_res.loc[(~df_1c_res['Вес самородка (общий суммированный)'].isna()),'источник веса самородка'] = '3.1. Самородки Сводка.xlsx'

# %%
df_1c_res.columns

# %%
df_1c_res = df_1c_res[['Код', 'Старый код (Справочник "Номенклатура" (Общие))', 'Склад',
       'Склад.Склад / Магазин', 'Вставки (Справочник "Номенклатура" (Общие))',
       'Вид номенклатуры', 'Тип номенклатуры', 'Номенклатура', 'Группа',
       'Заводской номер (Справочник "Номенклатура" (Общие))',
       'Проба (Справочник "Номенклатура" (Общие))',
       'Цвет металла (Справочник "Номенклатура" (Общие))',
       'Дизайн (Справочник "Номенклатура" (Общие))', 'Артикул ',
       'Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))',
       'Цвет Центрального Камня (Справочник "Номенклатура" (Общие))',
       'Чистота Центрального Камня (Справочник "Номенклатура" (Общие))',
       'Размер (Справочник "Номенклатура" (Общие))', 'Наименование для печати',
       'Единица измерения веса',
       'Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))',
       'Кол-во ДК (Справочник "Номенклатура" (Общие))',
       'Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))', 'Группы',
       'родитель1', 'родитель2', 'родитель3', 'родитель4',
       'Количество конечный остаток', 'Конечный остаток вес',
       'розничная стоимость', 'закупочная стоимость',
       'вес самородка',
       'источник веса самородка']]

# %% [markdown]
# # Подтянуть вставки  ШК, родитель 1 -5 из файла ВставкиДК_Родитель1-5_коррекцияНазовем их Вставки_корр

# %% [markdown]
# Для корректировки вставок и р1-5 Берем из файла - C:\Users\специалист ао\mypandas\work\2023\23-09-ХХ Переоценка ДК магазины выст\Вставки Родитель1-5 коррекция\ВставкиДК_Родитель1-5_коррекция_18-10-2023_10-00.xlsx
# Взамен этого файла Данные по вставкам надежнее чем с 1с (на 1 янв 2023г) \\UR-JVV\Users\DAS\Desktop\GM TMP\Analytics\Проекты в работе\23-09-XX Переоценка Самородки\1. Вводные\Данные по вставкам\23-01-01 Сводка ЮИ.xlsx

# %%
#'C:/Users/специалист ао/mypandas/work/2023/23-09-ХХ Переоценка ДК магазины выст/Вставки Родитель1-5 коррекция/ВставкиДК_Родитель1-5_коррекция_18-10-2023_10-00.xlsx'
files = os.listdir('C:/Users/специалист ао/mypandas/work/2023/23-09-ХХ Переоценка ДК магазины выст/Вставки Родитель1-5 коррекция/')
files
# Out:
# ['архив', 'ВставкиДК_Родитель1-5_коррекция_18-10-2023_10-00.xlsx', 'Материалы']

# %%
list(enumerate(files))
# Out:
# [(0, 'архив'),
#  (1, 'ВставкиДК_Родитель1-5_коррекция_18-10-2023_10-00.xlsx'),
#  (2, 'Материалы')]

# %%
fn = files[1]
fn
# Out:
# 'ВставкиДК_Родитель1-5_коррекция_18-10-2023_10-00.xlsx'

# %%
df_vst = pd.read_excel('C:/Users/специалист ао/mypandas/work/2023/23-09-ХХ Переоценка ДК магазины выст/Вставки Родитель1-5 коррекция/'\
                       +fn)#,header=9)#, dtype={5: str}

# %%
df_vst.columns
# Out:
# Index(['Unnamed: 0', 'Код', 'Штрихкод', 'Вставки 1С', 'Вставки 01-01-2023',
#        'Вставки корректировка', 'дата корректировки вставки',
#        'корректировка вставки была', 'Источник корректировки', 'Родитель1корр',
#        'Родитель2корр', 'Родитель3корр', 'Родитель4корр', 'Родитель5корр',
#        'Склад', 'Вид номенклатуры', 'Тип номенклатуры', 'Номенклатура',
#        'Группа', 'Заводской номер (Справочник "Номенклатура" (Общие))',
#        'Проба (Справочник "Номенклатура" (Общие))',
#        'Цвет металла (Справочник "Номенклатура" (Общие))',
#        'Дизайн (Справочник "Номенклатура" (Общие))', 'Артикул ',
#        'Размер (Справочник "Номенклатура" (Общие))', 'Наименование для печати',
#        'Единица измерения веса',
#        'Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))',
#        'Кол-во ДК (Справочник "Номенклатура" (Общие))',
#        'Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))', 'Группы',
#        'родитель1_1c', 'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
#        'родитель5_1c', 'Количество конечный остаток', 'Конечный остаток вес',
#        'розничная стоимость', 'закупочная стоимость', 'Старый код',
#        'vs_dict_0', 'ШТУК_0', 'КАРАТ_0', 'prcost_0',
#        'не сработал прейскурант_0'],
#       dtype='object')

# %%
len(df_vst['Код'].unique()), len(df_vst)
# Out:
# (34528, 34528)

# %%
len(df_1c_res['Код'].unique()), len(df_1c_res)
# Out:
# (34269, 34269)

# %%
#Присоединяем к df_1c
df_1c_res = pd.merge(df_1c_res,
         df_vst[['Код', 'Штрихкод','Вставки корректировка', 'корректировка вставки была', 
                 'Родитель1корр', 'Родитель2корр', 'Родитель3корр', 'Родитель4корр', 'Родитель5корр']],
         how='left',
         right_on=['Код'],
         left_on=['Код']
         )

# %%
#223 пустых строк это по 3 договорам новые Валив и ДЯ
df_1c_res['Штрихкод'].isna().sum()
# Out:
# 223

# %%
#df_1c_res.rename(columns={'Вставки':'Вставки010123'}, inplace=True)

# %% [markdown]
# # Востановление штрихкода у 223 строки

# %% [markdown]
# # Запись результата в файл (не используется)

# %%
folder_res
# Out:
# '../for_script/'

# %%
#запись промрезультата для проверки на excel
#df_1c_res.to_excel(folder_res+'Остатки1С__ДК_2023-10-15_корр_вставки_р1-5.xlsx')
#dododo

# %% [markdown]
# # Анализ 0

# %%
df_1c_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34269 entries, 0 to 34268
# Data columns (total 41 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Код                                                                      34269 non-null  object
#  1   Старый код (Справочник "Номенклатура" (Общие))                           28239 non-null  object
#  2   Склад                                                                    34269 non-null  object
#  3   Склад.Склад / Магазин                                                    34269 non-null  object
#  4   Вставки (Справочник "Номенклатура" (Общие))                              24298 non-null  object
#  5   Вид номенклатуры                                                         34269 non-null  object
#  6   Тип номенклатуры                                                         34269 non-null  object
#  7   Номенклатура                                                             34269 non-null  object
#  8   Группа                                                                   34269 non-null  object
#  9   Заводской номер (Справочник "Номенклатура" (Общие))                      33068 non-null  object
#  10  Проба (Справочник "Номенклатура" (Общие))                                34269 non-null  float64
#  11  Цвет металла (Справочник "Номенклатура" (Общие))                         34183 non-null  object
#  12  Дизайн (Справочник "Номенклатура" (Общие))                               34269 non-null  object
#  13  Артикул                                                                  34268 non-null  object
#  14  Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))  34269 non-null  object
#  15  Цвет Центрального Камня (Справочник "Номенклатура" (Общие))              34269 non-null  object
#  16  Чистота Центрального Камня (Справочник "Номенклатура" (Общие))           34269 non-null  object
#  17  Размер (Справочник "Номенклатура" (Общие))                               34182 non-null  object
#  18  Наименование для печати                                                  34269 non-null  object
#  19  Единица измерения веса                                                   34269 non-null  object
#  20  Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))              6041 non-null   float64
#  21  Кол-во ДК (Справочник "Номенклатура" (Общие))                            29116 non-null  float64
#  22  Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))               29113 non-null  float64
#  23  Группы                                                                   9480 non-null   object
#  24  родитель1_1c                                                             30388 non-null  object
#  25  родитель2_1c                                                             34262 non-null  object
#  26  родитель3_1c                                                             34269 non-null  object
#  27  родитель4_1c                                                             34269 non-null  object
#  28  родитель5_1c                                                             1 non-null      object
#  29  Количество конечный остаток                                              34269 non-null  float64
#  30  Конечный остаток вес                                                     34269 non-null  float64
#  31  розничная стоимость                                                      20480 non-null  float64
#  32  закупочная стоимость                                                     34269 non-null  float64
#  33  Штрихкод                                                                 34046 non-null  float64
#  34  Вставки корректировка                                                    34268 non-null  object
#  35  корректировка вставки была                                               34268 non-null  object
#  36  Родитель1корр                                                            34268 non-null  object
#  37  Родитель2корр                                                            34268 non-null  object
#  38  Родитель3корр                                                            34261 non-null  object
#  39  Родитель4корр                                                            30388 non-null  object
#  40  Родитель5корр                                                            9480 non-null   object
# dtypes: float64(9), object(32)
# memory usage: 11.0+ MB

# %%
df_1c_res.columns
# Out:
# Index(['Код', 'Старый код (Справочник "Номенклатура" (Общие))', 'Склад',
#        'Склад.Склад / Магазин', 'Вставки (Справочник "Номенклатура" (Общие))',
#        'Вид номенклатуры', 'Тип номенклатуры', 'Номенклатура', 'Группа',
#        'Заводской номер (Справочник "Номенклатура" (Общие))',
#        'Проба (Справочник "Номенклатура" (Общие))',
#        'Цвет металла (Справочник "Номенклатура" (Общие))',
#        'Дизайн (Справочник "Номенклатура" (Общие))', 'Артикул ',
#        'Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))',
#        'Цвет Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Чистота Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Размер (Справочник "Номенклатура" (Общие))', 'Наименование для печати',
#        'Единица измерения веса',
#        'Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))',
#        'Кол-во ДК (Справочник "Номенклатура" (Общие))',
#        'Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))', 'Группы',
#        'родитель1_1c', 'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
#        'родитель5_1c', 'Количество конечный остаток', 'Конечный остаток вес',
#        'розничная стоимость', 'закупочная стоимость', 'Штрихкод',
#        'Вставки корректировка', 'корректировка вставки была', 'Родитель1корр',
#        'Родитель2корр', 'Родитель3корр', 'Родитель4корр', 'Родитель5корр'],
#       dtype='object')

# %%
for c in ['Родитель1корр', 'Родитель2корр', 'Родитель3корр', 'Родитель4корр', 'Родитель5корр']:
    print(c, '-->', df_1c_res.sample(10)[c])
# Out:
# Родитель1корр --> 14279    Ювелирные изделия
# 5439     Ювелирные изделия
# 33201    Ювелирные изделия
# 26442    Ювелирные изделия
# 141      Ювелирные изделия
# 29108    Ювелирные изделия
# 1643     Ювелирные изделия
# 6245     Ювелирные изделия
# 4320     Ювелирные изделия
# 26652    Ювелирные изделия
# Name: Родитель1корр, dtype: object
# Родитель2корр --> 10987       Саха Минералс Лимитед
# 15250                   Из Москвы
# 8654     Драгоценности Якутии ООО
# 25175    Драгоценности Якутии ООО
# 26141        Туймаада Даймонд ОАО
# 20098    Драгоценности Якутии ООО
# 8374        Саха Минералс Лимитед
# 24539    Драгоценности Якутии ООО
# 25869              Сахаювелир ООО
# 26647       Саха Минералс Лимитед
# Name: Родитель2корр, dtype: object
# Родитель3корр --> 21260          06-338/1 от 19.12.2016
# 12552    №10-121 от 29.03.12г. Доп. 3
# 15475            SM10/01 от 07.10.10г
# 25862     11дм-06-01 от 30.11.2001 г.
# 402          07/10-587-09 от 11.12.09
# 21351        № 10-398 от 28.09.2011г.
# 17936          №03/10-212 от 05.11.07
# 12700                              ДЯ
# 10424          №03/10-212 от 05.11.07
# 4620                               ДЯ
# Name: Родитель3корр, dtype: object
# Родитель4корр --> 9316                                  2 партия
# 2046                                        ДК
# 22517              т.н. 202 от 02.06.2011г. ДК
# 18874                                 3 партия
# 7896                                    Кольца
# 29342                Рнк №176 от 30.03.10г. ДК
# 6937                                       NaN
# 4579                                       NaN
# 6049                                 Кольца ДК
# 28116    ДЯ 03/10-212 от 05.11.07  (11 партия)
# Name: Родитель4корр, dtype: object
# Родитель5корр --> 5026                                    NaN
# 11466                                   NaN
# 21557                                   NaN
# 15439                                   NaN
# 8781     №Рнк-1-24 от 12.04.05 (140п) ДК750
# 21598                                   NaN
# 18964                1680 от 14.01.08 ДК 3п
# 11249                                   NaN
# 4763                                    NaN
# 30017                1789 от 21.01.08 ДК 2п
# Name: Родитель5корр, dtype: object

# %%
#for c in ['родитель1_1c', 'родитель2_1c', 'родитель3_1c', 'родитель4_1c', 'родитель5_1c']:
#    print(c, '-->\n', df_1c_res.sample(10)[c])

# %%
df_1c_res.value_counts('Склад')
# Out:
# Склад
# Ювелирные изделия               16506
# Центральный                      1770
# Иркутск                          1760
# Ленина23                         1725
# Пассаж                           1630
# Кружало                          1583
# Ленина, 28                       1551
# Новосибирск                      1402
# Хабаровск                        1336
# Ленск                            1246
# Мирный                           1140
# Благовещенск                     1034
# Интернет-магазин                  861
# Выставочный                       647
# Московское представительство       50
# Склад "В пути"                     28
# dtype: int64

# %% [markdown]
# На 15-10-2023
# Склад
# Ювелирные изделия               16506
# Центральный                      1770
# Иркутск                          1760
# Ленина23                         1725
# Пассаж                           1630
# Кружало                          1583
# Ленина, 28                       1551
# Новосибирск                      1402
# Хабаровск                        1336
# Ленск                            1246
# Мирный                           1140
# Благовещенск                     1034
# Интернет-магазин                  861
# Выставочный                       647
# Московское представительство       50
# Склад "В пути"                     28
# dtype: int64

# %% [markdown]
# на 19-09-2023 ут?
# Склад
# Ювелирные изделия               16505
# Центральный                      1793
# Иркутск                          1772
# Ленина23                         1750
# Пассаж                           1619
# Ленина, 28                       1584
# Кружало                          1564
# Новосибирск                      1413
# Хабаровск                        1343
# Ленск                            1253
# Мирный                           1156
# Благовещенск                     1046
# Интернет-магазин                  861
# Выставочный                       818
# Московское представительство       51
# dtype: int64

# %%
#Где находятся 223 с не подключенным штрихкодом
df_1c_res[df_1c_res['Штрихкод'].isna()].value_counts('Склад')
# Out:
# Склад
# Ювелирные изделия               172
# Московское представительство     42
# Кружало                           3
# Центральный                       3
# Ленина, 28                        2
# Пассаж                            1
# dtype: int64

# %%
#Где находятся 214 с не подключенным Сводка Вставки
df_1c_res[df_1c_res['Вставки'].isna()].value_counts('Склад')
# Out:
# Склад
# Ювелирные изделия               171
# Московское представительство     32
# Кружало                           3
# Центральный                       3
# Ленина, 28                        2
# Пассаж                            1
# dtype: int64

# %%
#Где находятся 1 с не подключенным полем вставки
df_1c_res[df_1c_res['Вставки корректировка'].isna()].value_counts('Склад')
# Out:
# Склад
# Ювелирные изделия    1
# dtype: int64

# %%
df_1c_res[df_1c_res['Вставки корректировка'].isna()]
# Out:
#                Код Старый код (Справочник "Номенклатура" (Общие))  \
# 17792  ЦБ-00011837                                     МС00196301
#
#                    Склад Склад.Склад / Магазин  \
# 17792  Ювелирные изделия         Оптовый склад
#
#             Вставки (Справочник "Номенклатура" (Общие)) Вид номенклатуры  \
# 17792  21Кр57-0,84-6/5А 4Кр57-0,13-6/5А 6Кр57-0,12-6/5А     Т ДМ Юи с ДК
#
#       Тип номенклатуры Номенклатура                    Группа  \
# 17792            Товар      Браслет  SM19-01 от 27.09.2019 ДК
#
#       Заводской номер (Справочник "Номенклатура" (Общие))  ...  \
# 17792                                              279/1   ...
#
#        розничная стоимость закупочная стоимость Штрихкод  \
# 17792           230,943.00            76,981.14      NaN
#
#       Вставки корректировка корректировка вставки была Родитель1корр  \
# 17792                   NaN                        NaN           NaN
#
#       Родитель2корр Родитель3корр Родитель4корр Родитель5корр
# 17792           NaN           NaN           NaN           NaN
#
# [1 rows x 41 columns]

# %% [markdown]
# ## Обнаружено что изделие ЦБ-00011837 отсутствовало в выгрузке от 19 сент и 8 октября, но появилось в выгрузке от 15 октября

# %%
# надо чинить вставки и р1-5

# %%
df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837',[ 'Вставки корректировка', 'Вставки (Справочник "Номенклатура" (Общие))']]
# Out:
#       Вставки корректировка       Вставки (Справочник "Номенклатура" (Общие))
# 17792                   NaN  21Кр57-0,84-6/5А 4Кр57-0,13-6/5А 6Кр57-0,12-6/5А

# %%
df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837','Вставки (Справочник "Номенклатура" (Общие))']
# Out:
# 17792    21Кр57-0,84-6/5А 4Кр57-0,13-6/5А 6Кр57-0,12-6/5А
# Name: Вставки (Справочник "Номенклатура" (Общие)), dtype: object

# %%
df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837',  
              'Вставки корректировка'] = df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837','Вставки (Справочник "Номенклатура" (Общие))']

# %%
# Проверка
df_1c_res[df_1c_res['Вставки корректировка'].isna()]
# Out:
# Empty DataFrame
# Columns: [Код, Старый код (Справочник "Номенклатура" (Общие)), Склад, Склад.Склад / Магазин, Вставки (Справочник "Номенклатура" (Общие)), Вид номенклатуры, Тип номенклатуры, Номенклатура, Группа, Заводской номер (Справочник "Номенклатура" (Общие)), Проба (Справочник "Номенклатура" (Общие)), Цвет металла (Справочник "Номенклатура" (Общие)), Дизайн (Справочник "Номенклатура" (Общие)), Артикул , Размерная группа Центрального камня (Справочник "Номенклатура" (Общие)), Цвет Центрального Камня (Справочник "Номенклатура" (Общие)), Чистота Центрального Камня (Справочник "Номенклатура" (Общие)), Размер (Справочник "Номенклатура" (Общие)), Наименование для печати, Единица измерения веса, Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие)), Кол-во ДК (Справочник "Номенклатура" (Общие)), Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие)), Группы, родитель1_1c, родитель2_1c, родитель3_1c, родитель4_1c, родитель5_1c, Количество конечный остаток, Конечный остаток вес, розничная стоимость, закупочная стоимость, Штрихкод, Вставки корректировка, корректировка вставки была, Родитель1корр, Родитель2корр, Родитель3корр, Родитель4корр, Родитель5корр]
# Index: []
#
# [0 rows x 41 columns]

# %%
# Проверка
df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837',[ 'Вставки корректировка', 'Вставки (Справочник "Номенклатура" (Общие))']]
# Out:
#                                   Вставки корректировка  \
# 17792  21Кр57-0,84-6/5А 4Кр57-0,13-6/5А 6Кр57-0,12-6/5А
#
#             Вставки (Справочник "Номенклатура" (Общие))
# 17792  21Кр57-0,84-6/5А 4Кр57-0,13-6/5А 6Кр57-0,12-6/5А

# %% [markdown]
# ### для Родитель 1-5

# %%
#!!! Со сдвигом 
list_rod_rod_1c = [('Родитель1корр','родитель2_1c'),
 ('Родитель2корр','родитель3_1c'),
 ('Родитель3корр','родитель4_1c'),
 ('Родитель4корр','родитель5_1c')]

# %%
for rod,rod_1c in list_rod_rod_1c[:]:
    print(rod,rod_1c)
    df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837',rod] = df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837',rod_1c]
# Out:
# Родитель1корр родитель2_1c
# Родитель2корр родитель3_1c
# Родитель3корр родитель4_1c
# Родитель4корр родитель5_1c

# %%
#df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837',rod]
# Out:
# 17792    Ювелирные изделия
# Name: Родитель2корр, dtype: object

# %%
#df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837',rod_1c]
# Out:
# 17792    Ювелирные изделия
# Name: родитель2_1c, dtype: object

# %%
#df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837',rod] = df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837',rod_1c]

# %%
# проверка

# %%
df_1c_res.loc[df_1c_res['Код'] == 'ЦБ-00011837',['Родитель1корр','Родитель2корр','Родитель3корр','Родитель4корр', 'Родитель5корр']]
# Out:
#            Родитель1корр          Родитель2корр             Родитель3корр  \
# 17792  Ювелирные изделия  Саха Минералс Лимитед  SM19-01 от 27.09.2019 ДК
#
#       Родитель4корр Родитель5корр
# 17792           NaN           NaN

# %%
df_1c_res.loc[:,['Родитель1корр','Родитель2корр','Родитель3корр','Родитель4корр', 'Родитель5корр']].sample(10)
# Out:
#            Родитель1корр             Родитель2корр  \
# 23277  Ювелирные изделия  Драгоценности Якутии ООО
# 18601  Ювелирные изделия  Драгоценности Якутии ООО
# 17569  Ювелирные изделия      Туймаада Даймонд ОАО
# 22177  Ювелирные изделия  Драгоценности Якутии ООО
# 16298  Ювелирные изделия         Невский Бриллиант
# 14438  Ювелирные изделия  Драгоценности Якутии ООО
# 33502  Ювелирные изделия        ИП "Алексеев В.М."
# 17519  Ювелирные изделия  Драгоценности Якутии ООО
# 23623  Ювелирные изделия  Драгоценности Якутии ООО
# 26270  Ювелирные изделия      Туймаада Даймонд ОАО
#
#                                  Родитель3корр  \
# 23277                   №03/10-212 от 05.11.07
# 18601                  №06-249 от 30.03.2010г.
# 17569                        10-46 от 20.03.13
# 22177  №10-121 от 29.03.12 Доп.№21 от 26.11.15
# 16298                      №10-157 от 30.06.14
# 14438   №10-141 от 30.03.12 Доп 12 от 28.05.14
# 33502                 № 10-086 от 27.05.2021г.
# 17519             №194/1/03-2018 от 28.11.18г.
# 23623                   №03/10-212 от 05.11.07
# 26270                   10-469 от 30.09.2010г.
#
#                                Родитель4корр  \
# 23277  ДЯ 03/10-212 от 05.11.07  (11 партия)
# 18601              Рнк №178 от 30.03.10г. ДК
# 17569                                  36 ДК
# 22177                            т.н. №62 дк
# 16298                            накл.№35 дк
# 14438                             накл №3 ДК
# 33502                    16/21 от 09.12.2021
# 17519                            т.н.№133 ДК
# 23623   ДЯ 03/10-212 от 05.11.07 (15 партия)
# 26270            Рнк №146 от 30.09.2010г. ДК
#
#                                   Родитель5корр
# 23277  Рнк-646/265 от 09.11.07г. ДК (11 партия)
# 18601                                       NaN
# 17569                                       NaN
# 22177                                       NaN
# 16298                                       NaN
# 14438                                       NaN
# 33502                                       NaN
# 17519                                       NaN
# 23623  Рнк-696/290 от 09.11.07г. ДК (15 партия)
# 26270                                       NaN

# %%
df_1c_res[['Родитель2корр']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34269 entries, 0 to 34268
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Родитель2корр  34269 non-null  object
# dtypes: object(1)
# memory usage: 535.5+ KB

# %% [markdown]
# # Файл для вставок из ЮТД Вставкиютд

# %% [markdown]
# ## подготовка

# %%
files = os.listdir('../1 Вводные/Выгрузки ЮТД 2023-10-13/')
list(enumerate(files))
# Out:
# [(0, '2023-10-13_Остатки товаров на складах (без шк).xlsx'),
#  (1, '23-10-16 Выгрузка из ЮТД без сувениров.xlsx'),
#  (2, 'Штрихкод - НоменклатураКод (ЦБ) 2023-10-11.xlsx')]

# %%
df_utd = pd.read_excel('../1 Вводные/Выгрузки ЮТД 2023-10-13/'+files[1])#,header=9)#, dtype={5: str}

# %%
df_utd.iloc[3:]
# Out:
#               Unnamed: 0  Unnamed: 1 Unnamed: 2     Unnamed: 3  \
# 3       Номенклатура.Код         NaN        NaN          Склад
# 4                    NaN         NaN        NaN            NaN
# 5              000005200         NaN        NaN   Благовещенск
# 6              000005201         NaN        NaN   Благовещенск
# 7              000005202         NaN        NaN   Благовещенск
# ...                  ...         ...        ...            ...
# 148357         000186413         NaN        NaN  УР Бриллианты
# 148358         000186414         NaN        NaN  УР Бриллианты
# 148359         000186415         NaN        NaN  УР Бриллианты
# 148360         000186416         NaN        NaN  УР Бриллианты
# 148361             Итого         NaN        NaN            NaN
#
#                              Unnamed: 4              Unnamed: 5  Unnamed: 6  \
# 3       Серия номенклатуры.Наименование  Серия номенклатуры.УИН         NaN
# 4                                   NaN                     NaN         NaN
# 5                         2000000219721        6432205037320158         NaN
# 6                         2000000219837        6432205037445837         NaN
# 7                         2000000219899        6432205037404896         NaN
# ...                                 ...                     ...         ...
# 148357                    2000002037453        6432205148666206         NaN
# 148358                    2000002037460        6432205150175616         NaN
# 148359                    2000002037477        6432205150096331         NaN
# 148360                    2000002037484        6432205148853228         NaN
# 148361                              NaN                     NaN         NaN
#
#                     Unnamed: 7                      Unnamed: 8  \
# 3       Серия номенклатуры.Вес  Серия номенклатуры.Вес металла
# 4                          NaN                             NaN
# 5                        47.57                           47.57
# 6                        15.94                           15.94
# 7                         4.10                            4.10
# ...                        ...                             ...
# 148357                    1.15                            1.15
# 148358                    2.22                            2.22
# 148359                    1.02                            1.02
# 148360                    4.10                            4.10
# 148361                     NaN                             NaN
#
#                                       Unnamed: 9  ...  \
# 3       Серия номенклатуры.Вес металла в чистоте  ...
# 4                                            NaN  ...
# 5                                          44.01  ...
# 6                                          14.75  ...
# 7                                           3.79  ...
# ...                                          ...  ...
# 148357                                       NaN  ...
# 148358                                       NaN  ...
# 148359                                       NaN  ...
# 148360                                       NaN  ...
# 148361                                       NaN  ...
#
#                           Unnamed: 18                         Unnamed: 19  \
# 3       Номенклатура.Вид номенклатуры  Номенклатура.Номенклатурная группа
# 4                                 NaN                                 NaN
# 5                   Ювелирное изделие                     П ДМ Юи сер. БК
# 6                   Ювелирное изделие                     П ДМ Юи сер. БК
# 7                   Ювелирное изделие                     П ДМ Юи сер. БК
# ...                               ...                                 ...
# 148357                        Вставка        Бриллианты сертифицированные
# 148358                        Вставка        Бриллианты сертифицированные
# 148359                        Вставка        Бриллианты сертифицированные
# 148360                        Вставка        Бриллианты сертифицированные
# 148361                            NaN                                 NaN
#
#                                   Unnamed: 20                Unnamed: 21  \
# 3                   Номенклатура.Наименование  Номенклатура.Проба.Металл
# 4                                         NaN                        NaN
# 5                   Цепь НЦ 22-002-6 (Ag 925)       Серебро
# 6                   Цепь НЦ 22-203-6 (Ag 925)       Серебро
# 7                   Цепь НЦ 22-078-6 (Ag 925)       Серебро
# ...                                       ...                        ...
# 148357     Бриллиант Груша 9-1/10 (1.00-1.24)                        NaN
# 148358       Бриллиант Груша 7/10 (2.00-2.24)                        NaN
# 148359      Бриллиант Изумруд 5/9 (1.00-1.24)                        NaN
# 148360  Бриллиант Триллиант 8-1/8 (4.00-4.24)                        NaN
# 148361                                    NaN                        NaN
#
#                      Unnamed: 22                            Unnamed: 23  \
# 3       Номенклатура.Проба.Проба  Номенклатура.Тип изделия.Наименование
# 4                            NaN                                    NaN
# 5                            925                                   Цепь
# 6                            925                                   Цепь
# 7                            925                                   Цепь
# ...                          ...                                    ...
# 148357                       NaN                                    NaN
# 148358                       NaN                                    NaN
# 148359                       NaN                                    NaN
# 148360                       NaN                                    NaN
# 148361                       NaN                                    NaN
#
#                             Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 3       Номенклатура.Проба.Наименование     Остаток         NaN
# 4                                   NaN  Количество         Вес
# 5                                Ag 925           1       47.57
# 6                                Ag 925           1       15.94
# 7                                Ag 925           1        4.10
# ...                                 ...         ...         ...
# 148357                              NaN           1        1.15
# 148358                              NaN           1        2.22
# 148359                              NaN           1        1.02
# 148360                              NaN           1        4.10
# 148361                              NaN      149869  588,629.52
#
#             Unnamed: 27
# 3                   NaN
# 4             Стоимость
# 5              4,903.84
# 6              1,643.21
# 7                451.68
# ...                 ...
# 148357         9,859.96
# 148358        36,355.75
# 148359        29,639.06
# 148360       176,499.88
# 148361 1,707,339,825.80
#
# [148359 rows x 28 columns]

# %%
df_utd = df_utd.iloc[3:].copy(deep=True)

# %%
df_utd
# Out:
#               Unnamed: 0  Unnamed: 1 Unnamed: 2     Unnamed: 3  \
# 3       Номенклатура.Код         NaN        NaN          Склад
# 4                    NaN         NaN        NaN            NaN
# 5              000005200         NaN        NaN   Благовещенск
# 6              000005201         NaN        NaN   Благовещенск
# 7              000005202         NaN        NaN   Благовещенск
# ...                  ...         ...        ...            ...
# 148357         000186413         NaN        NaN  УР Бриллианты
# 148358         000186414         NaN        NaN  УР Бриллианты
# 148359         000186415         NaN        NaN  УР Бриллианты
# 148360         000186416         NaN        NaN  УР Бриллианты
# 148361             Итого         NaN        NaN            NaN
#
#                              Unnamed: 4              Unnamed: 5  Unnamed: 6  \
# 3       Серия номенклатуры.Наименование  Серия номенклатуры.УИН         NaN
# 4                                   NaN                     NaN         NaN
# 5                         2000000219721        6432205037320158         NaN
# 6                         2000000219837        6432205037445837         NaN
# 7                         2000000219899        6432205037404896         NaN
# ...                                 ...                     ...         ...
# 148357                    2000002037453        6432205148666206         NaN
# 148358                    2000002037460        6432205150175616         NaN
# 148359                    2000002037477        6432205150096331         NaN
# 148360                    2000002037484        6432205148853228         NaN
# 148361                              NaN                     NaN         NaN
#
#                     Unnamed: 7                      Unnamed: 8  \
# 3       Серия номенклатуры.Вес  Серия номенклатуры.Вес металла
# 4                          NaN                             NaN
# 5                        47.57                           47.57
# 6                        15.94                           15.94
# 7                         4.10                            4.10
# ...                        ...                             ...
# 148357                    1.15                            1.15
# 148358                    2.22                            2.22
# 148359                    1.02                            1.02
# 148360                    4.10                            4.10
# 148361                     NaN                             NaN
#
#                                       Unnamed: 9  ...  \
# 3       Серия номенклатуры.Вес металла в чистоте  ...
# 4                                            NaN  ...
# 5                                          44.01  ...
# 6                                          14.75  ...
# 7                                           3.79  ...
# ...                                          ...  ...
# 148357                                       NaN  ...
# 148358                                       NaN  ...
# 148359                                       NaN  ...
# 148360                                       NaN  ...
# 148361                                       NaN  ...
#
#                           Unnamed: 18                         Unnamed: 19  \
# 3       Номенклатура.Вид номенклатуры  Номенклатура.Номенклатурная группа
# 4                                 NaN                                 NaN
# 5                   Ювелирное изделие                     П ДМ Юи сер. БК
# 6                   Ювелирное изделие                     П ДМ Юи сер. БК
# 7                   Ювелирное изделие                     П ДМ Юи сер. БК
# ...                               ...                                 ...
# 148357                        Вставка        Бриллианты сертифицированные
# 148358                        Вставка        Бриллианты сертифицированные
# 148359                        Вставка        Бриллианты сертифицированные
# 148360                        Вставка        Бриллианты сертифицированные
# 148361                            NaN                                 NaN
#
#                                   Unnamed: 20                Unnamed: 21  \
# 3                   Номенклатура.Наименование  Номенклатура.Проба.Металл
# 4                                         NaN                        NaN
# 5                   Цепь НЦ 22-002-6 (Ag 925)       Серебро
# 6                   Цепь НЦ 22-203-6 (Ag 925)       Серебро
# 7                   Цепь НЦ 22-078-6 (Ag 925)       Серебро
# ...                                       ...                        ...
# 148357     Бриллиант Груша 9-1/10 (1.00-1.24)                        NaN
# 148358       Бриллиант Груша 7/10 (2.00-2.24)                        NaN
# 148359      Бриллиант Изумруд 5/9 (1.00-1.24)                        NaN
# 148360  Бриллиант Триллиант 8-1/8 (4.00-4.24)                        NaN
# 148361                                    NaN                        NaN
#
#                      Unnamed: 22                            Unnamed: 23  \
# 3       Номенклатура.Проба.Проба  Номенклатура.Тип изделия.Наименование
# 4                            NaN                                    NaN
# 5                            925                                   Цепь
# 6                            925                                   Цепь
# 7                            925                                   Цепь
# ...                          ...                                    ...
# 148357                       NaN                                    NaN
# 148358                       NaN                                    NaN
# 148359                       NaN                                    NaN
# 148360                       NaN                                    NaN
# 148361                       NaN                                    NaN
#
#                             Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 3       Номенклатура.Проба.Наименование     Остаток         NaN
# 4                                   NaN  Количество         Вес
# 5                                Ag 925           1       47.57
# 6                                Ag 925           1       15.94
# 7                                Ag 925           1        4.10
# ...                                 ...         ...         ...
# 148357                              NaN           1        1.15
# 148358                              NaN           1        2.22
# 148359                              NaN           1        1.02
# 148360                              NaN           1        4.10
# 148361                              NaN      149869  588,629.52
#
#             Unnamed: 27
# 3                   NaN
# 4             Стоимость
# 5              4,903.84
# 6              1,643.21
# 7                451.68
# ...                 ...
# 148357         9,859.96
# 148358        36,355.75
# 148359        29,639.06
# 148360       176,499.88
# 148361 1,707,339,825.80
#
# [148359 rows x 28 columns]

# %%
df_utd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148359 entries, 3 to 148361
# Data columns (total 28 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   148358 non-null  object
#  1   Unnamed: 1   0 non-null       float64
#  2   Unnamed: 2   0 non-null       object
#  3   Unnamed: 3   148357 non-null  object
#  4   Unnamed: 4   148357 non-null  object
#  5   Unnamed: 5   148339 non-null  object
#  6   Unnamed: 6   0 non-null       float64
#  7   Unnamed: 7   148357 non-null  object
#  8   Unnamed: 8   148357 non-null  object
#  9   Unnamed: 9   140663 non-null  object
#  10  Unnamed: 10  140570 non-null  object
#  11  Unnamed: 11  140626 non-null  object
#  12  Unnamed: 12  139887 non-null  object
#  13  Unnamed: 13  136903 non-null  object
#  14  Unnamed: 14  134621 non-null  object
#  15  Unnamed: 15  148353 non-null  object
#  16  Unnamed: 16  148353 non-null  object
#  17  Unnamed: 17  148357 non-null  object
#  18  Unnamed: 18  148357 non-null  object
#  19  Unnamed: 19  148268 non-null  object
#  20  Unnamed: 20  148357 non-null  object
#  21  Unnamed: 21  140689 non-null  object
#  22  Unnamed: 22  140689 non-null  object
#  23  Unnamed: 23  140689 non-null  object
#  24  Unnamed: 24  140689 non-null  object
#  25  Unnamed: 25  148359 non-null  object
#  26  Unnamed: 26  148358 non-null  object
#  27  Unnamed: 27  148358 non-null  object
# dtypes: float64(2), object(26)
# memory usage: 31.7+ MB

# %%
df_utd.drop(columns=['Unnamed: 1','Unnamed: 2','Unnamed: 6'], inplace=True)

# %%
df_utd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148359 entries, 3 to 148361
# Data columns (total 25 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   148358 non-null  object
#  1   Unnamed: 3   148357 non-null  object
#  2   Unnamed: 4   148357 non-null  object
#  3   Unnamed: 5   148339 non-null  object
#  4   Unnamed: 7   148357 non-null  object
#  5   Unnamed: 8   148357 non-null  object
#  6   Unnamed: 9   140663 non-null  object
#  7   Unnamed: 10  140570 non-null  object
#  8   Unnamed: 11  140626 non-null  object
#  9   Unnamed: 12  139887 non-null  object
#  10  Unnamed: 13  136903 non-null  object
#  11  Unnamed: 14  134621 non-null  object
#  12  Unnamed: 15  148353 non-null  object
#  13  Unnamed: 16  148353 non-null  object
#  14  Unnamed: 17  148357 non-null  object
#  15  Unnamed: 18  148357 non-null  object
#  16  Unnamed: 19  148268 non-null  object
#  17  Unnamed: 20  148357 non-null  object
#  18  Unnamed: 21  140689 non-null  object
#  19  Unnamed: 22  140689 non-null  object
#  20  Unnamed: 23  140689 non-null  object
#  21  Unnamed: 24  140689 non-null  object
#  22  Unnamed: 25  148359 non-null  object
#  23  Unnamed: 26  148358 non-null  object
#  24  Unnamed: 27  148358 non-null  object
# dtypes: object(25)
# memory usage: 28.3+ MB

# %%
dict_col = df_utd.iloc[0,:-3].to_dict()
dict_col
# Out:
# {'Unnamed: 0': 'Номенклатура.Код',
#  'Unnamed: 3': 'Склад',
#  'Unnamed: 4': 'Серия номенклатуры.Наименование',
#  'Unnamed: 5': 'Серия номенклатуры.УИН',
#  'Unnamed: 7': 'Серия номенклатуры.Вес',
#  'Unnamed: 8': 'Серия номенклатуры.Вес металла',
#  'Unnamed: 9': 'Серия номенклатуры.Вес металла в чистоте',
#  'Unnamed: 10': 'Серия номенклатуры.Вес металла в чистоте ГИИСДМДК',
#  'Unnamed: 11': 'Серия номенклатуры.Вес металла ГИИС ДМДК',
#  'Unnamed: 12': 'Серия номенклатуры.Характеристика номенклатуры.Полное наименование',
#  'Unnamed: 13': 'Серия номенклатуры.Размер',
#  'Unnamed: 14': 'Размер',
#  'Unnamed: 15': 'Серия номенклатуры.Владелец.Артикул ',
#  'Unnamed: 16': 'Номенклатура.Артикул ',
#  'Unnamed: 17': 'Номенклатура.Текстовое описание',
#  'Unnamed: 18': 'Номенклатура.Вид номенклатуры',
#  'Unnamed: 19': 'Номенклатура.Номенклатурная группа',
#  'Unnamed: 20': 'Номенклатура.Наименование',
#  'Unnamed: 21': 'Номенклатура.Проба.Металл',
#  'Unnamed: 22': 'Номенклатура.Проба.Проба',
#  'Unnamed: 23': 'Номенклатура.Тип изделия.Наименование',
#  'Unnamed: 24': 'Номенклатура.Проба.Наименование'}

# %%
df_utd.iloc[1,-3:]
# Out:
# Unnamed: 25    Количество
# Unnamed: 26           Вес
# Unnamed: 27     Стоимость
# Name: 4, dtype: object

# %%
if input('правильно?') == 'y':
    dict_col['Unnamed: 25']='Количество'
    dict_col['Unnamed: 26'] = 'Вес'
    dict_col['Unnamed: 27'] = 'Стоимость'
    print(i)
# Out:
# правильно?y
# 2

# %%
dict_col
# Out:
# {'Unnamed: 0': 'Номенклатура.Код',
#  'Unnamed: 3': 'Склад',
#  'Unnamed: 4': 'Серия номенклатуры.Наименование',
#  'Unnamed: 5': 'Серия номенклатуры.УИН',
#  'Unnamed: 7': 'Серия номенклатуры.Вес',
#  'Unnamed: 8': 'Серия номенклатуры.Вес металла',
#  'Unnamed: 9': 'Серия номенклатуры.Вес металла в чистоте',
#  'Unnamed: 10': 'Серия номенклатуры.Вес металла в чистоте ГИИСДМДК',
#  'Unnamed: 11': 'Серия номенклатуры.Вес металла ГИИС ДМДК',
#  'Unnamed: 12': 'Серия номенклатуры.Характеристика номенклатуры.Полное наименование',
#  'Unnamed: 13': 'Серия номенклатуры.Размер',
#  'Unnamed: 14': 'Размер',
#  'Unnamed: 15': 'Серия номенклатуры.Владелец.Артикул ',
#  'Unnamed: 16': 'Номенклатура.Артикул ',
#  'Unnamed: 17': 'Номенклатура.Текстовое описание',
#  'Unnamed: 18': 'Номенклатура.Вид номенклатуры',
#  'Unnamed: 19': 'Номенклатура.Номенклатурная группа',
#  'Unnamed: 20': 'Номенклатура.Наименование',
#  'Unnamed: 21': 'Номенклатура.Проба.Металл',
#  'Unnamed: 22': 'Номенклатура.Проба.Проба',
#  'Unnamed: 23': 'Номенклатура.Тип изделия.Наименование',
#  'Unnamed: 24': 'Номенклатура.Проба.Наименование',
#  'Unnamed: 25': 'Количество',
#  'Unnamed: 26': 'Вес',
#  'Unnamed: 27': 'Стоимость'}

# %%
df_utd.rename(columns=dict_col, inplace=True)
df_utd
# Out:
#         Номенклатура.Код          Склад  Серия номенклатуры.Наименование  \
# 3       Номенклатура.Код          Склад  Серия номенклатуры.Наименование
# 4                    NaN            NaN                              NaN
# 5              000005200   Благовещенск                    2000000219721
# 6              000005201   Благовещенск                    2000000219837
# 7              000005202   Благовещенск                    2000000219899
# ...                  ...            ...                              ...
# 148357         000186413  УР Бриллианты                    2000002037453
# 148358         000186414  УР Бриллианты                    2000002037460
# 148359         000186415  УР Бриллианты                    2000002037477
# 148360         000186416  УР Бриллианты                    2000002037484
# 148361             Итого            NaN                              NaN
#
#         Серия номенклатуры.УИН  Серия номенклатуры.Вес  \
# 3       Серия номенклатуры.УИН  Серия номенклатуры.Вес
# 4                          NaN                     NaN
# 5             6432205037320158                   47.57
# 6             6432205037445837                   15.94
# 7             6432205037404896                    4.10
# ...                        ...                     ...
# 148357        6432205148666206                    1.15
# 148358        6432205150175616                    2.22
# 148359        6432205150096331                    1.02
# 148360        6432205148853228                    4.10
# 148361                     NaN                     NaN
#
#         Серия номенклатуры.Вес металла  \
# 3       Серия номенклатуры.Вес металла
# 4                                  NaN
# 5                                47.57
# 6                                15.94
# 7                                 4.10
# ...                                ...
# 148357                            1.15
# 148358                            2.22
# 148359                            1.02
# 148360                            4.10
# 148361                             NaN
#
#         Серия номенклатуры.Вес металла в чистоте  \
# 3       Серия номенклатуры.Вес металла в чистоте
# 4                                            NaN
# 5                                          44.01
# 6                                          14.75
# 7                                           3.79
# ...                                          ...
# 148357                                       NaN
# 148358                                       NaN
# 148359                                       NaN
# 148360                                       NaN
# 148361                                       NaN
#
#         Серия номенклатуры.Вес металла в чистоте ГИИСДМДК  \
# 3       Серия номенклатуры.Вес металла в чистоте ГИИСДМДК
# 4                                                     NaN
# 5                                                   44.01
# 6                                                   14.75
# 7                                                    3.79
# ...                                                   ...
# 148357                                                NaN
# 148358                                                NaN
# 148359                                                NaN
# 148360                                                NaN
# 148361                                                NaN
#
#         Серия номенклатуры.Вес металла ГИИС ДМДК  \
# 3       Серия номенклатуры.Вес металла ГИИС ДМДК
# 4                                            NaN
# 5                                          47.57
# 6                                          15.94
# 7                                           4.10
# ...                                          ...
# 148357                                       NaN
# 148358                                       NaN
# 148359                                       NaN
# 148360                                       NaN
# 148361                                       NaN
#
#        Серия номенклатуры.Характеристика номенклатуры.Полное наименование  \
# 3       Серия номенклатуры.Характеристика номенклатуры...
# 4                                                     NaN
# 5                                              Без камней
# 6                                              Без камней
# 7                                              Без камней
# ...                                                   ...
# 148357                                                NaN
# 148358                                                NaN
# 148359                                                NaN
# 148360                                                NaN
# 148361                                                NaN
#
#         ...  Номенклатура.Вид номенклатуры  \
# 3       ...  Номенклатура.Вид номенклатуры
# 4       ...                            NaN
# 5       ...              Ювелирное изделие
# 6       ...              Ювелирное изделие
# 7       ...              Ювелирное изделие
# ...     ...                            ...
# 148357  ...                        Вставка
# 148358  ...                        Вставка
# 148359  ...                        Вставка
# 148360  ...                        Вставка
# 148361  ...                            NaN
#
#         Номенклатура.Номенклатурная группа  \
# 3       Номенклатура.Номенклатурная группа
# 4                                      NaN
# 5                          П ДМ Юи сер. БК
# 6                          П ДМ Юи сер. БК
# 7                          П ДМ Юи сер. БК
# ...                                    ...
# 148357        Бриллианты сертифицированные
# 148358        Бриллианты сертифицированные
# 148359        Бриллианты сертифицированные
# 148360        Бриллианты сертифицированные
# 148361                                 NaN
#
#                     Номенклатура.Наименование  Номенклатура.Проба.Металл  \
# 3                   Номенклатура.Наименование  Номенклатура.Проба.Металл
# 4                                         NaN                        NaN
# 5                   Цепь НЦ 22-002-6 (Ag 925)       Серебро
# 6                   Цепь НЦ 22-203-6 (Ag 925)       Серебро
# 7                   Цепь НЦ 22-078-6 (Ag 925)       Серебро
# ...                                       ...                        ...
# 148357     Бриллиант Груша 9-1/10 (1.00-1.24)                        NaN
# 148358       Бриллиант Груша 7/10 (2.00-2.24)                        NaN
# 148359      Бриллиант Изумруд 5/9 (1.00-1.24)                        NaN
# 148360  Бриллиант Триллиант 8-1/8 (4.00-4.24)                        NaN
# 148361                                    NaN                        NaN
#
#         Номенклатура.Проба.Проба  Номенклатура.Тип изделия.Наименование  \
# 3       Номенклатура.Проба.Проба  Номенклатура.Тип изделия.Наименование
# 4                            NaN                                    NaN
# 5                            925                                   Цепь
# 6                            925                                   Цепь
# 7                            925                                   Цепь
# ...                          ...                                    ...
# 148357                       NaN                                    NaN
# 148358                       NaN                                    NaN
# 148359                       NaN                                    NaN
# 148360                       NaN                                    NaN
# 148361                       NaN                                    NaN
#
#         Номенклатура.Проба.Наименование  Количество        Вес  \
# 3       Номенклатура.Проба.Наименование     Остаток        NaN
# 4                                   NaN  Количество        Вес
# 5                                Ag 925           1      47.57
# 6                                Ag 925           1      15.94
# 7                                Ag 925           1       4.10
# ...                                 ...         ...        ...
# 148357                              NaN           1       1.15
# 148358                              NaN           1       2.22
# 148359                              NaN           1       1.02
# 148360                              NaN           1       4.10
# 148361                              NaN      149869 588,629.52
#
#               Стоимость
# 3                   NaN
# 4             Стоимость
# 5              4,903.84
# 6              1,643.21
# 7                451.68
# ...                 ...
# 148357         9,859.96
# 148358        36,355.75
# 148359        29,639.06
# 148360       176,499.88
# 148361 1,707,339,825.80
#
# [148359 rows x 25 columns]

# %%
df_utd.drop([3,4]).iloc[:-1]#, inplace=True)
# Out:
#        Номенклатура.Код          Склад Серия номенклатуры.Наименование  \
# 5             000005200   Благовещенск                   2000000219721
# 6             000005201   Благовещенск                   2000000219837
# 7             000005202   Благовещенск                   2000000219899
# 8             000005203   Благовещенск                   2000000219905
# 9             000005204   Благовещенск                   2000000219943
# ...                 ...            ...                             ...
# 148356        000186412  УР Бриллианты                   2000002037446
# 148357        000186413  УР Бриллианты                   2000002037453
# 148358        000186414  УР Бриллианты                   2000002037460
# 148359        000186415  УР Бриллианты                   2000002037477
# 148360        000186416  УР Бриллианты                   2000002037484
#
#        Серия номенклатуры.УИН Серия номенклатуры.Вес  \
# 5            6432205037320158                  47.57
# 6            6432205037445837                  15.94
# 7            6432205037404896                   4.10
# 8            6432205037404958                   4.36
# 9            6432205037405012                   4.86
# ...                       ...                    ...
# 148356       6432205148685393                   1.13
# 148357       6432205148666206                   1.15
# 148358       6432205150175616                   2.22
# 148359       6432205150096331                   1.02
# 148360       6432205148853228                   4.10
#
#        Серия номенклатуры.Вес металла  \
# 5                               47.57
# 6                               15.94
# 7                                4.10
# 8                                4.36
# 9                                4.86
# ...                               ...
# 148356                           1.13
# 148357                           1.15
# 148358                           2.22
# 148359                           1.02
# 148360                           4.10
#
#        Серия номенклатуры.Вес металла в чистоте  \
# 5                                         44.01
# 6                                         14.75
# 7                                          3.79
# 8                                          4.03
# 9                                          4.50
# ...                                         ...
# 148356                                      NaN
# 148357                                      NaN
# 148358                                      NaN
# 148359                                      NaN
# 148360                                      NaN
#
#        Серия номенклатуры.Вес металла в чистоте ГИИСДМДК  \
# 5                                                  44.01
# 6                                                  14.75
# 7                                                   3.79
# 8                                                   4.03
# 9                                                   4.50
# ...                                                  ...
# 148356                                               NaN
# 148357                                               NaN
# 148358                                               NaN
# 148359                                               NaN
# 148360                                               NaN
#
#        Серия номенклатуры.Вес металла ГИИС ДМДК  \
# 5                                         47.57
# 6                                         15.94
# 7                                          4.10
# 8                                          4.36
# 9                                          4.86
# ...                                         ...
# 148356                                      NaN
# 148357                                      NaN
# 148358                                      NaN
# 148359                                      NaN
# 148360                                      NaN
#
#        Серия номенклатуры.Характеристика номенклатуры.Полное наименование  \
# 5                                              Без камней
# 6                                              Без камней
# 7                                              Без камней
# 8                                              Без камней
# 9                                              Без камней
# ...                                                   ...
# 148356                                                NaN
# 148357                                                NaN
# 148358                                                NaN
# 148359                                                NaN
# 148360                                                NaN
#
#         ... Номенклатура.Вид номенклатуры Номенклатура.Номенклатурная группа  \
# 5       ...             Ювелирное изделие                    П ДМ Юи сер. БК
# 6       ...             Ювелирное изделие                    П ДМ Юи сер. БК
# 7       ...             Ювелирное изделие                    П ДМ Юи сер. БК
# 8       ...             Ювелирное изделие                    П ДМ Юи сер. БК
# 9       ...             Ювелирное изделие                    П ДМ Юи сер. БК
# ...     ...                           ...                                ...
# 148356  ...                       Вставка       Бриллианты сертифицированные
# 148357  ...                       Вставка       Бриллианты сертифицированные
# 148358  ...                       Вставка       Бриллианты сертифицированные
# 148359  ...                       Вставка       Бриллианты сертифицированные
# 148360  ...                       Вставка       Бриллианты сертифицированные
#
#                     Номенклатура.Наименование Номенклатура.Проба.Металл  \
# 5                   Цепь НЦ 22-002-6 (Ag 925)      Серебро
# 6                   Цепь НЦ 22-203-6 (Ag 925)      Серебро
# 7                   Цепь НЦ 22-078-6 (Ag 925)      Серебро
# 8                   Цепь НЦ 22-078-6 (Ag 925)      Серебро
# 9                   Цепь НЦ 22-078-6 (Ag 925)      Серебро
# ...                                       ...                       ...
# 148356        Бриллиант Груша 3/8 (1.00-1.24)                       NaN
# 148357     Бриллиант Груша 9-1/10 (1.00-1.24)                       NaN
# 148358       Бриллиант Груша 7/10 (2.00-2.24)                       NaN
# 148359      Бриллиант Изумруд 5/9 (1.00-1.24)                       NaN
# 148360  Бриллиант Триллиант 8-1/8 (4.00-4.24)                       NaN
#
#        Номенклатура.Проба.Проба Номенклатура.Тип изделия.Наименование  \
# 5                           925                                  Цепь
# 6                           925                                  Цепь
# 7                           925                                  Цепь
# 8                           925                                  Цепь
# 9                           925                                  Цепь
# ...                         ...                                   ...
# 148356                      NaN                                   NaN
# 148357                      NaN                                   NaN
# 148358                      NaN                                   NaN
# 148359                      NaN                                   NaN
# 148360                      NaN                                   NaN
#
#        Номенклатура.Проба.Наименование Количество   Вес  Стоимость
# 5                               Ag 925          1 47.57   4,903.84
# 6                               Ag 925          1 15.94   1,643.21
# 7                               Ag 925          1  4.10     451.68
# 8                               Ag 925          1  4.36     480.33
# 9                               Ag 925          1  4.86     535.41
# ...                                ...        ...   ...        ...
# 148356                             NaN          1  1.13  40,679.46
# 148357                             NaN          1  1.15   9,859.96
# 148358                             NaN          1  2.22  36,355.75
# 148359                             NaN          1  1.02  29,639.06
# 148360                             NaN          1  4.10 176,499.88
#
# [148356 rows x 25 columns]

# %%
if input('правильно (см итог)?y/*:')=='y':
    df_utd.drop([3,4], inplace=True)
    df_utd = df_utd.iloc[:-1].copy(deep=True)
# Out:
# правильно (см итог)?y/*:y

# %%
df_utd
# Out:
#        Номенклатура.Код          Склад Серия номенклатуры.Наименование  \
# 5             000005200   Благовещенск                   2000000219721
# 6             000005201   Благовещенск                   2000000219837
# 7             000005202   Благовещенск                   2000000219899
# 8             000005203   Благовещенск                   2000000219905
# 9             000005204   Благовещенск                   2000000219943
# ...                 ...            ...                             ...
# 148356        000186412  УР Бриллианты                   2000002037446
# 148357        000186413  УР Бриллианты                   2000002037453
# 148358        000186414  УР Бриллианты                   2000002037460
# 148359        000186415  УР Бриллианты                   2000002037477
# 148360        000186416  УР Бриллианты                   2000002037484
#
#        Серия номенклатуры.УИН Серия номенклатуры.Вес  \
# 5            6432205037320158                  47.57
# 6            6432205037445837                  15.94
# 7            6432205037404896                   4.10
# 8            6432205037404958                   4.36
# 9            6432205037405012                   4.86
# ...                       ...                    ...
# 148356       6432205148685393                   1.13
# 148357       6432205148666206                   1.15
# 148358       6432205150175616                   2.22
# 148359       6432205150096331                   1.02
# 148360       6432205148853228                   4.10
#
#        Серия номенклатуры.Вес металла  \
# 5                               47.57
# 6                               15.94
# 7                                4.10
# 8                                4.36
# 9                                4.86
# ...                               ...
# 148356                           1.13
# 148357                           1.15
# 148358                           2.22
# 148359                           1.02
# 148360                           4.10
#
#        Серия номенклатуры.Вес металла в чистоте  \
# 5                                         44.01
# 6                                         14.75
# 7                                          3.79
# 8                                          4.03
# 9                                          4.50
# ...                                         ...
# 148356                                      NaN
# 148357                                      NaN
# 148358                                      NaN
# 148359                                      NaN
# 148360                                      NaN
#
#        Серия номенклатуры.Вес металла в чистоте ГИИСДМДК  \
# 5                                                  44.01
# 6                                                  14.75
# 7                                                   3.79
# 8                                                   4.03
# 9                                                   4.50
# ...                                                  ...
# 148356                                               NaN
# 148357                                               NaN
# 148358                                               NaN
# 148359                                               NaN
# 148360                                               NaN
#
#        Серия номенклатуры.Вес металла ГИИС ДМДК  \
# 5                                         47.57
# 6                                         15.94
# 7                                          4.10
# 8                                          4.36
# 9                                          4.86
# ...                                         ...
# 148356                                      NaN
# 148357                                      NaN
# 148358                                      NaN
# 148359                                      NaN
# 148360                                      NaN
#
#        Серия номенклатуры.Характеристика номенклатуры.Полное наименование  \
# 5                                              Без камней
# 6                                              Без камней
# 7                                              Без камней
# 8                                              Без камней
# 9                                              Без камней
# ...                                                   ...
# 148356                                                NaN
# 148357                                                NaN
# 148358                                                NaN
# 148359                                                NaN
# 148360                                                NaN
#
#         ... Номенклатура.Вид номенклатуры Номенклатура.Номенклатурная группа  \
# 5       ...             Ювелирное изделие                    П ДМ Юи сер. БК
# 6       ...             Ювелирное изделие                    П ДМ Юи сер. БК
# 7       ...             Ювелирное изделие                    П ДМ Юи сер. БК
# 8       ...             Ювелирное изделие                    П ДМ Юи сер. БК
# 9       ...             Ювелирное изделие                    П ДМ Юи сер. БК
# ...     ...                           ...                                ...
# 148356  ...                       Вставка       Бриллианты сертифицированные
# 148357  ...                       Вставка       Бриллианты сертифицированные
# 148358  ...                       Вставка       Бриллианты сертифицированные
# 148359  ...                       Вставка       Бриллианты сертифицированные
# 148360  ...                       Вставка       Бриллианты сертифицированные
#
#                     Номенклатура.Наименование Номенклатура.Проба.Металл  \
# 5                   Цепь НЦ 22-002-6 (Ag 925)      Серебро
# 6                   Цепь НЦ 22-203-6 (Ag 925)      Серебро
# 7                   Цепь НЦ 22-078-6 (Ag 925)      Серебро
# 8                   Цепь НЦ 22-078-6 (Ag 925)      Серебро
# 9                   Цепь НЦ 22-078-6 (Ag 925)      Серебро
# ...                                       ...                       ...
# 148356        Бриллиант Груша 3/8 (1.00-1.24)                       NaN
# 148357     Бриллиант Груша 9-1/10 (1.00-1.24)                       NaN
# 148358       Бриллиант Груша 7/10 (2.00-2.24)                       NaN
# 148359      Бриллиант Изумруд 5/9 (1.00-1.24)                       NaN
# 148360  Бриллиант Триллиант 8-1/8 (4.00-4.24)                       NaN
#
#        Номенклатура.Проба.Проба Номенклатура.Тип изделия.Наименование  \
# 5                           925                                  Цепь
# 6                           925                                  Цепь
# 7                           925                                  Цепь
# 8                           925                                  Цепь
# 9                           925                                  Цепь
# ...                         ...                                   ...
# 148356                      NaN                                   NaN
# 148357                      NaN                                   NaN
# 148358                      NaN                                   NaN
# 148359                      NaN                                   NaN
# 148360                      NaN                                   NaN
#
#        Номенклатура.Проба.Наименование Количество   Вес  Стоимость
# 5                               Ag 925          1 47.57   4,903.84
# 6                               Ag 925          1 15.94   1,643.21
# 7                               Ag 925          1  4.10     451.68
# 8                               Ag 925          1  4.36     480.33
# 9                               Ag 925          1  4.86     535.41
# ...                                ...        ...   ...        ...
# 148356                             NaN          1  1.13  40,679.46
# 148357                             NaN          1  1.15   9,859.96
# 148358                             NaN          1  2.22  36,355.75
# 148359                             NaN          1  1.02  29,639.06
# 148360                             NaN          1  4.10 176,499.88
#
# [148356 rows x 25 columns]

# %%
len(df_utd['Номенклатура.Код'].unique()), len(df_utd)
# Out:
# (148356, 148356)

# %%
df_utd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148356 entries, 5 to 148360
# Data columns (total 25 columns):
#  #   Column                                                              Non-Null Count   Dtype
# ---  ------                                                              --------------   -----
#  0   Номенклатура.Код                                                    148356 non-null  object
#  1   Склад                                                               148356 non-null  object
#  2   Серия номенклатуры.Наименование                                     148356 non-null  object
#  3   Серия номенклатуры.УИН                                              148338 non-null  object
#  4   Серия номенклатуры.Вес                                              148356 non-null  object
#  5   Серия номенклатуры.Вес металла                                      148356 non-null  object
#  6   Серия номенклатуры.Вес металла в чистоте                            140662 non-null  object
#  7   Серия номенклатуры.Вес металла в чистоте ГИИСДМДК                   140569 non-null  object
#  8   Серия номенклатуры.Вес металла ГИИС ДМДК                            140625 non-null  object
#  9   Серия номенклатуры.Характеристика номенклатуры.Полное наименование  139886 non-null  object
#  10  Серия номенклатуры.Размер                                           136902 non-null  object
#  11  Размер                                                              134620 non-null  object
#  12  Серия номенклатуры.Владелец.Артикул                                 148352 non-null  object
#  13  Номенклатура.Артикул                                                148352 non-null  object
#  14  Номенклатура.Текстовое описание                                     148356 non-null  object
#  15  Номенклатура.Вид номенклатуры                                       148356 non-null  object
#  16  Номенклатура.Номенклатурная группа                                  148267 non-null  object
#  17  Номенклатура.Наименование                                           148356 non-null  object
#  18  Номенклатура.Проба.Металл                                           140688 non-null  object
#  19  Номенклатура.Проба.Проба                                            140688 non-null  object
#  20  Номенклатура.Тип изделия.Наименование                               140688 non-null  object
#  21  Номенклатура.Проба.Наименование                                     140688 non-null  object
#  22  Количество                                                          148356 non-null  object
#  23  Вес                                                                 148356 non-null  object
#  24  Стоимость                                                           148356 non-null  object
# dtypes: object(25)
# memory usage: 29.4+ MB

# %%
df_utd.loc[df_utd['Серия номенклатуры.Характеристика номенклатуры.Полное наименование'].isna(),
           ['Серия номенклатуры.Характеристика номенклатуры.Полное наименование']] = ''

# %% [markdown]
# ## подсчет длина вставки == 100

# %%
df_utd['Серия номенклатуры.Характеристика номенклатуры.Полное наименование'].apply(lambda x: True if len(x) == 100 else False).sum()
# Out:
# 12

# %%
df_utd.loc[df_utd['Серия номенклатуры.Характеристика номенклатуры.Полное наименование']\
 .apply(lambda x: True if len(x) == 100 else False),
  'Серия номенклатуры.Характеристика номенклатуры.Полное наименование'].unique()
# Out:
# array(['Хромдиопсид Гранат ТопазГ Цитрин 4Кр57-0,079-6/6А 4Кр57-0,063-6/6А 4Кр57-0,043-4/5А 3Кр57-0,153-3/5А',
#        '1Кр57-0,860-5/8А 1Кр57-0,030-3/5Б 1Кр57-0,030-3/5Б 1Кр57-0,030-3/3Б 3Кр57-0,010-3/5Б 3Кр57-0,090-3/6',
#        '1КР57-0,810-4/8А 2КР57-0,070-4/5А 1КР57-0,030-4/5А 2КР57-0,060-4/6А 2КР57-0,060-3/6Б 3КР57-0,090-4/3',
#        '1КР17-0,003-3/3А 8КР57-0,029-4/6А 5КР57-0,015-4/6А 5КР57-0,017-4/6А 4КР57-0,016-6/6Б 9КР57-0,041-6/6',
#        '17Кр57-0,2-1/4А 99Кр57-1,78-1/7А 65Кр57-0,89-3/6А 4Кр57-0,03-3/6А 15Кр57-0,16-7/7Б 165Кр57-2,82-7/7Б',
#        '1Г56-1,15-5/4Б 1Ов57-0,51-8-5/7а 1Ов57-0,-8.5/4А 10кр57-0,14-3/5А 36кр57-0,35-3/5А 147кр57-0,83-3/5А',
#        'рубинВ 9кр57-0,8-4/5А 2кр57-0,03-4/5А 2кр57-0,04-4/5А 2кр57-0,05-4/5А 2кр57-0,08-4/5А 4кр57-0,19-4/5',
#        'ЖемчугБ 10КР57-0,180-3/5А 11КР57-0,470-2/2А 9КР57-0,320-2/2А 10КР57-0,290-2/2А 6КР57-0,180-2/3А 38КР',
#        '1Кр57-0,080-3/5А 1Кр57-0,090-2/5А 1Кр57-0,070-2/5А 6Кр57-0,54-2/5А 3Кр57-0,020-3/4А 5Кр57-0,046-2/4А',
#        '4Кр57-0,060-4/6А 4Кр57-0,040-4/6А 4Кр57-0,040-4/6А 4Кр57-0,030-4/6А 4Кр57-0,030-4/6А 2Кр57-0,010-4/7'],
#       dtype=object)

# %%
len(_)
# Out:
# 10

# %%
df_utd['проблема вставок ЮТД 100'] = False
df_utd.loc[df_utd['Серия номенклатуры.Характеристика номенклатуры.Полное наименование'].apply(lambda x: True if len(x) == 100 else False),
          'проблема вставок ЮТД 100'] = True

# %%
df_utd['проблема вставок ЮТД 100'].sum()
# Out:
# 12

# %% [markdown]
# ## вывод кода ЦБ

# %%
df_utd['Код'] = df_utd['Номенклатура.Текстовое описание'].apply(lambda x: x.split(';')[0])

# %%
len(df_utd['Код'].unique()), len(df_utd)
# Out:
# (148336, 148356)

# %%
df_utd = df_utd[~df_utd['Код'].duplicated(keep='first')].copy(deep=True)#.sort_values('Номенклатура.Текстовое описание')

# %%
#_.to_excel('файл для Василия_дупликаты 20 изделий в ЮТД.xlsx')

# %% [markdown]
# # merge. У ЮТД переименовываем склад на склад_ютд

# %%
df_1c_res
# Out:
#                Код Старый код (Справочник "Номенклатура" (Общие))  \
# 0      ЦБ-00200503                                            NaN
# 1      ЦБ-00002854                                     МС00057368
# 2      ЦБ-00019951                                     МС00152100
# 3      ЦБ-00019953                                     МС00146311
# 4      ЦБ-00111074                                     МС00111422
# ...            ...                                            ...
# 34264  ЦБ-00182016                                     0000032928
# 34265  ЦБ-00182017                                     0000032929
# 34266  ЦБ-00182019                                     0000032934
# 34267  ЦБ-00182020                                     0000032935
# 34268  ЦБ-00182021                                     0000032936
#
#                    Склад Склад.Склад / Магазин  \
# 0           Благовещенск     Розничный магазин
# 1           Благовещенск     Розничный магазин
# 2           Благовещенск     Розничный магазин
# 3           Благовещенск     Розничный магазин
# 4           Благовещенск     Розничный магазин
# ...                  ...                   ...
# 34264  Ювелирные изделия         Оптовый склад
# 34265  Ювелирные изделия         Оптовый склад
# 34266  Ювелирные изделия         Оптовый склад
# 34267  Ювелирные изделия         Оптовый склад
# 34268  Ювелирные изделия         Оптовый склад
#
#              Вставки (Справочник "Номенклатура" (Общие)) Вид номенклатуры  \
# 0                                      45КР57-0,520-4/5А     Т ДМ Юи с ДК
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...     Т ДМ Юи с ДК
# 2                                       1Кр57-0,086-4/5А     П ДМ Юи с ДК
# 3                                        3Кр57-0,06-4/5А     П ДМ Юи с ДК
# 4      1Кр57-0,050-4/5А 1Кр57-0,031-6/6А 1Кр57-0,014-...     Т ДМ Юи с ДК
# ...                                                  ...              ...
# 34264                                                NaN     Т ДМ Юи с ДК
# 34265                                                NaN     Т ДМ Юи с ДК
# 34266                                                NaN     Т ДМ Юи с ДК
# 34267                                                NaN     Т ДМ Юи с ДК
# 34268                                                NaN     Т ДМ Юи с ДК
#
#       Тип номенклатуры Номенклатура                           Группа  \
# 0                Товар      Браслет  спецификация №1 от 27.01.2022г.
# 1                Товар      Браслет                         Товар ДК
# 2                Товар        Брошь                            Броши
# 3                Товар        Брошь                          накл.№5
# 4                Товар        Брошь                            51 ДК
# ...                ...          ...                              ...
# 34264            Товар  серьги с ДК        Акт №1 АК "Золото Якутии"
# 34265            Товар  серьги с ДК        Акт №1 АК "Золото Якутии"
# 34266            Товар  серьги с ДК        Акт №1 АК "Золото Якутии"
# 34267            Товар  серьги с ДК        Акт №1 АК "Золото Якутии"
# 34268            Товар  серьги с ДК        Акт №1 АК "Золото Якутии"
#
#       Заводской номер (Справочник "Номенклатура" (Общие))  ...  \
# 0                                                    512   ...
# 1                                               30575,51   ...
# 2                                                1191890   ...
# 3                                                   1094   ...
# 4                                                    422   ...
# ...                                                  ...   ...
# 34264                                           01-12308   ...
# 34265                                           01-12309   ...
# 34266                                           01-14045   ...
# 34267                                           01-14046   ...
# 34268                                           01-14047   ...
#
#        розничная стоимость закупочная стоимость             Штрихкод  \
# 0               185,375.00            61,791.55 2,000,001,838,327.00
# 1               333,693.00            83,173.87 2,000,000,015,637.00
# 2                29,041.00             9,680.06 2,000,000,179,179.00
# 3                33,789.00            14,078.47 2,000,000,179,193.00
# 4                52,866.00            21,693.89 2,000,000,993,782.00
# ...                    ...                  ...                  ...
# 34264                  NaN             5,446.00 2,000,001,783,672.00
# 34265                  NaN             5,446.00 2,000,001,783,689.00
# 34266                  NaN             3,850.00 2,000,001,783,702.00
# 34267                  NaN             3,850.00 2,000,001,783,719.00
# 34268                  NaN             3,850.00 2,000,001,783,726.00
#
#                                    Вставки корректировка  \
# 0                                      45КР57-0,520-4/5А
# 1      2Кр57-0,083-2/2А 4Кр57-0,084-2/2А 6Кр57-0,280-...
# 2                                       1Кр57-0,086-4/5А
# 3                                        3Кр57-0,06-4/5А
# 4      1Кр57-0,050-4/5А 1Кр57-0,031-6/6А 1Кр57-0,014-...
# ...                                                  ...
# 34264                           СапфирВ 6КР57-0,080-3/4А
# 34265                           СапфирВ 6КР57-0,080-3/4А
# 34266                          ИзумрудВ 4КР57-0,040-2/3А
# 34267                          ИзумрудВ 4КР57-0,040-2/3А
# 34268                          ИзумрудВ 4КР57-0,040-2/3А
#
#            корректировка вставки была      Родитель1корр  \
# 0      НЕТ по состоянию на 01.01-2023  Ювелирные изделия
# 1      НЕТ по состоянию на 01.01-2023  Ювелирные изделия
# 2      НЕТ по состоянию на 01.01-2023  Ювелирные изделия
# 3      НЕТ по состоянию на 01.01-2023  Ювелирные изделия
# 4      НЕТ по состоянию на 01.01-2023  Ювелирные изделия
# ...                               ...                ...
# 34264  НЕТ по состоянию на 01.01-2023  Ювелирные изделия
# 34265  НЕТ по состоянию на 01.01-2023  Ювелирные изделия
# 34266  НЕТ по состоянию на 01.01-2023  Ювелирные изделия
# 34267  НЕТ по состоянию на 01.01-2023  Ювелирные изделия
# 34268  НЕТ по состоянию на 01.01-2023  Ювелирные изделия
#
#                   Родитель2корр                                 Родитель3корр  \
# 0         Саха Минералс Лимитед  Sakha Minerals Limited SM21-01 от 28.09.2021
# 1                     Из Москвы                                      Товар ДК
# 2            ИП "Алексеев В.М."                          10-271 от 21.12.2018
# 3      Драгоценности Якутии ООО                        № 06-329/2 от 12.12.16
# 4      Драгоценности Якутии ООО                        06-341/4 от 26.12.2016
# ...                         ...                                           ...
# 34264    Золото Якутии ОАО АПЮК                                   Из магазина
# 34265    Золото Якутии ОАО АПЮК                                   Из магазина
# 34266    Золото Якутии ОАО АПЮК                                   Из магазина
# 34267    Золото Якутии ОАО АПЮК                                   Из магазина
# 34268    Золото Якутии ОАО АПЮК                                   Из магазина
#
#                            Родитель4корр Родитель5корр
# 0        спецификация №1 от 27.01.2022г.           NaN
# 1                                    NaN           NaN
# 2                                  Броши           NaN
# 3      06-329/2 от 12.12.2016 Задание №4       накл.№5
# 4                                  51 ДК           NaN
# ...                                  ...           ...
# 34264          Акт №1 АК "Золото Якутии"           NaN
# 34265          Акт №1 АК "Золото Якутии"           NaN
# 34266          Акт №1 АК "Золото Якутии"           NaN
# 34267          Акт №1 АК "Золото Якутии"           NaN
# 34268          Акт №1 АК "Золото Якутии"           NaN
#
# [34269 rows x 41 columns]

# %%
df_utd.rename(columns={'Склад':'Склад_ютд'}, inplace=True)

# %%
df_utd['Серия номенклатуры.Характеристика номенклатуры.Полное наименование'].sample(30)
# Out:
# 76230                                                Фианит
# 131563
# 147729
# 145312                                           Без камней
# 88377                                                Фианит
# 72708                                                Фианит
# 30778                                      1Кр57-0,063-2/3А
# 133316                                     1КР57-0,060-1/3А
# 116327                                     1Кр57-0,110-2/6А
# 20687                                                Фианит
# 59055                                            Без Камней
# 71781                                        Аметист Фианит
# 122238              5СапфирПТ-0,160-кр+3/2 4КР57-0,100-2/3А
# 58380                                            Без Камней
# 16421                                            Без камней
# 126331                    1КР57-0,043-2/2А 6КР57-0,250-2/2А
# 49175                                     20КР57-0,170-5/5А
# 77590                                                Фианит
# 6428                                             Без камней
# 114435                       Жемчуг*Черный 3Кр57-0,070-2/7А
# 39702                                         ТопазГ Фианит
# 50470                                            Без Камней
# 12463     32КР57-0,140-4/5А 16КР57-0,090-4/5А 2КР57-0,04...
# 57045                                            Без Камней
# 52206                                            Без камней
# 44792                                            Без Камней
# 6211                                             Без камней
# 61423                                            Без Камней
# 23880                                                  Яшма
# 116432                        Жемчуг*Белый 2Кр57-0,070-5/2А
# Name: Серия номенклатуры.Характеристика номенклатуры.Полное наименование, dtype: object

# %%
#Присоединяем к df_1c_res
df_1c_res = pd.merge(df_1c_res,
         df_utd[['Код', 'Серия номенклатуры.Характеристика номенклатуры.Полное наименование']],
         how='left',
         right_on=['Код'],
         left_on=['Код']
         )

# %%
df_1c_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34269 entries, 0 to 34268
# Data columns (total 42 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Код                                                                      34269 non-null  object
#  1   Старый код (Справочник "Номенклатура" (Общие))                           28239 non-null  object
#  2   Склад                                                                    34269 non-null  object
#  3   Склад.Склад / Магазин                                                    34269 non-null  object
#  4   Вставки (Справочник "Номенклатура" (Общие))                              24298 non-null  object
#  5   Вид номенклатуры                                                         34269 non-null  object
#  6   Тип номенклатуры                                                         34269 non-null  object
#  7   Номенклатура                                                             34269 non-null  object
#  8   Группа                                                                   34269 non-null  object
#  9   Заводской номер (Справочник "Номенклатура" (Общие))                      33068 non-null  object
#  10  Проба (Справочник "Номенклатура" (Общие))                                34269 non-null  float64
#  11  Цвет металла (Справочник "Номенклатура" (Общие))                         34183 non-null  object
#  12  Дизайн (Справочник "Номенклатура" (Общие))                               34269 non-null  object
#  13  Артикул                                                                  34268 non-null  object
#  14  Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))  34269 non-null  object
#  15  Цвет Центрального Камня (Справочник "Номенклатура" (Общие))              34269 non-null  object
#  16  Чистота Центрального Камня (Справочник "Номенклатура" (Общие))           34269 non-null  object
#  17  Размер (Справочник "Номенклатура" (Общие))                               34182 non-null  object
#  18  Наименование для печати                                                  34269 non-null  object
#  19  Единица измерения веса                                                   34269 non-null  object
#  20  Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))              6041 non-null   float64
#  21  Кол-во ДК (Справочник "Номенклатура" (Общие))                            29116 non-null  float64
#  22  Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))               29113 non-null  float64
#  23  Группы                                                                   9480 non-null   object
#  24  родитель1_1c                                                             30388 non-null  object
#  25  родитель2_1c                                                             34262 non-null  object
#  26  родитель3_1c                                                             34269 non-null  object
#  27  родитель4_1c                                                             34269 non-null  object
#  28  родитель5_1c                                                             1 non-null      object
#  29  Количество конечный остаток                                              34269 non-null  float64
#  30  Конечный остаток вес                                                     34269 non-null  float64
#  31  розничная стоимость                                                      20480 non-null  float64
#  32  закупочная стоимость                                                     34269 non-null  float64
#  33  Штрихкод                                                                 34046 non-null  float64
#  34  Вставки корректировка                                                    34269 non-null  object
#  35  корректировка вставки была                                               34268 non-null  object
#  36  Родитель1корр                                                            34269 non-null  object
#  37  Родитель2корр                                                            34269 non-null  object
#  38  Родитель3корр                                                            34262 non-null  object
#  39  Родитель4корр                                                            30388 non-null  object
#  40  Родитель5корр                                                            9480 non-null   object
#  41  Серия номенклатуры.Характеристика номенклатуры.Полное наименование       34206 non-null  object
# dtypes: float64(9), object(33)
# memory usage: 11.2+ MB

# %%
# Потом проверить
df_1c_res[df_1c_res['Номенклатура.Код'].isna()]
# Out:
#                Код Старый код (Справочник "Номенклатура" (Общие))  \
# 951    ЦБ-00201416                                            NaN
# 4280   ЦБ-00201418                                            NaN
# 4989   ЦБ-00201422                                            NaN
# 6668   ЦБ-00201420                                            NaN
# 7933   ЦБ-00201421                                            NaN
# ...            ...                                            ...
# 15649  ЦБ-00201415                                            NaN
# 16851  ЦБ-00201419                                            NaN
# 18372  ЦБ-00075259                                     МС00019549
# 26684  ЦБ-00219596                                            NaN
# 34182  ЦБ-00201586                                            NaN
#
#                    Склад Склад.Склад / Магазин  \
# 951         Благовещенск     Розничный магазин
# 4280             Иркутск     Розничный магазин
# 4989             Кружало     Розничный магазин
# 6668          Ленина, 28     Розничный магазин
# 7933            Ленина23     Розничный магазин
# ...                  ...                   ...
# 15649          Хабаровск     Розничный магазин
# 16851        Центральный     Розничный магазин
# 18372  Ювелирные изделия         Оптовый склад
# 26684  Ювелирные изделия         Оптовый склад
# 34182  Ювелирные изделия         Оптовый склад
#
#              Вставки (Справочник "Номенклатура" (Общие)) Вид номенклатуры  \
# 951    36КР57-0,137-4/5А 24КР57-0,173-4/5А 4КР57-0,12...     Т ДМ Юи с ДК
# 4280   36КР57-0,137-4/5А 24КР57-0,173-4/5А 4КР57-0,12...     Т ДМ Юи с ДК
# 4989   18КР57-0,070-4/5А 12КР57-0,090-4/5А 2КР57-0,06...     Т ДМ Юи с ДК
# 6668   18КР57-0,070-4/5А 12КР57-0,090-4/5А 2КР57-0,06...     Т ДМ Юи с ДК
# 7933   18КР57-0,070-4/5А 12КР57-0,090-4/5А 2КР57-0,06...     Т ДМ Юи с ДК
# ...                                                  ...              ...
# 15649                  6КР57-0,197-4/5А 1КР57-0,050-4/5А     Т ДМ Юи с ДК
# 16851  18КР57-0,070-4/5А 12КР57-0,090-4/5А 2КР57-0,06...     Т ДМ Юи с ДК
# 18372                                                NaN     Т ДМ Юи с ДК
# 26684  1МодГ-1,010-4/5А 36Кр57-0,425-5/5А 8Кр57-0,260...     П ДМ Юи с ДК
# 34182                                   2КР57-0,050-4/5А     Т ДМ Юи с ДК
#
#       Тип номенклатуры Номенклатура                           Группа  \
# 951              Товар       Серьги  спецификация №1 от 27.01.2022г.
# 4280             Товар       Серьги  спецификация №1 от 27.01.2022г.
# 4989             Товар       Кольцо  спецификация №1 от 27.01.2022г.
# 6668             Товар       Кольцо  спецификация №1 от 27.01.2022г.
# 7933             Товар       Кольцо  спецификация №1 от 27.01.2022г.
# ...                ...          ...                              ...
# 15649            Товар     Подвеска  спецификация №1 от 27.01.2022г.
# 16851            Товар       Кольцо  спецификация №1 от 27.01.2022г.
# 18372            Товар       Кольцо                           126 дк
# 26684            Товар       Кольцо                        эксклюзив
# 34182            Товар       Серьги  спецификация №1 от 27.01.2022г.
#
#       Заводской номер (Справочник "Номенклатура" (Общие))  ...  \
# 951                                                 1427   ...
# 4280                                                1429   ...
# 4989                                                1433   ...
# 6668                                                1431   ...
# 7933                                                1432   ...
# ...                                                  ...   ...
# 15649                                               1426   ...
# 16851                                               1430   ...
# 18372                                            1177-12   ...
# 26684                                   3562200005684812   ...
# 34182                                                674   ...
#
#        Номенклатура.Артикул  Номенклатура.Текстовое описание  \
# 951                      NaN                             NaN
# 4280                     NaN                             NaN
# 4989                     NaN                             NaN
# 6668                     NaN                             NaN
# 7933                     NaN                             NaN
# ...                      ...                             ...
# 15649                    NaN                             NaN
# 16851                    NaN                             NaN
# 18372                    NaN                             NaN
# 26684                    NaN                             NaN
# 34182                    NaN                             NaN
#
#       Номенклатура.Проба Номенклатура.Вид номенклатуры  \
# 951                  NaN                           NaN
# 4280                 NaN                           NaN
# 4989                 NaN                           NaN
# 6668                 NaN                           NaN
# 7933                 NaN                           NaN
# ...                  ...                           ...
# 15649                NaN                           NaN
# 16851                NaN                           NaN
# 18372                NaN                           NaN
# 26684                NaN                           NaN
# 34182                NaN                           NaN
#
#       Номенклатура.Номенклатурная группа Номенклатура.Наименование Количество  \
# 951                                  NaN                       NaN        NaN
# 4280                                 NaN                       NaN        NaN
# 4989                                 NaN                       NaN        NaN
# 6668                                 NaN                       NaN        NaN
# 7933                                 NaN                       NaN        NaN
# ...                                  ...                       ...        ...
# 15649                                NaN                       NaN        NaN
# 16851                                NaN                       NaN        NaN
# 18372                                NaN                       NaN        NaN
# 26684                                NaN                       NaN        NaN
# 34182                                NaN                       NaN        NaN
#
#        Вес Стоимость проблема вставок ЮТД 100
# 951    NaN       NaN                      NaN
# 4280   NaN       NaN                      NaN
# 4989   NaN       NaN                      NaN
# 6668   NaN       NaN                      NaN
# 7933   NaN       NaN                      NaN
# ...    ...       ...                      ...
# 15649  NaN       NaN                      NaN
# 16851  NaN       NaN                      NaN
# 18372  NaN       NaN                      NaN
# 26684  NaN       NaN                      NaN
# 34182  NaN       NaN                      NaN
#
# [63 rows x 63 columns]

# %%
# Запись для сверки врем файл
#df_1c_res.to_excel(folder_res+'сравнение ЮТД и УТ по ДК.xlsx')

# %%
folder_res
# Out:
# '../for_script08-10-2023/'

# %%
#  имеется ошибки вставок в ЮТД в виде слова 'ЛОЖЬ'
df_utd['Серия номенклатуры.Характеристика номенклатуры.Полное наименование'] == 'ЛОЖЬ'
# Out:
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
#           ...
# 148356    False
# 148357    False
# 148358    False
# 148359    False
# 148360    False
# Name: Серия номенклатуры.Характеристика номенклатуры.Полное наименование, Length: 148336, dtype: bool

# %%
sum(_)
# Out:
# 23

# %%
df_1c_res['Штрихкод'].isna().sum()
# Out:
# 223

# %%
df_1c_res['Вставки корректировка'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Найти 223 нехватающих штрихкода через файл Штрихкод - НоменклатураКод (ЦБ) 2023-10-11.xlsx

# %%
df_sh = pd.read_excel('//UR-JVV/Users/DAS/Desktop/GM TMP/Analytics/Общее/Выгрузки/1СЮТД/Штрихкод - НоменклатураКод (ЦБ) 2023-10-11.xlsx')

# %%
df_sh
# Out:
#            Unnamed: 0  Unnamed: 1  \
# 0          Параметры:         NaN
# 1                 NaN         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4            Штрихкод         NaN
# ...               ...         ...
# 202112  2000002037453         NaN
# 202113  2000002037460         NaN
# 202114  2000002037477         NaN
# 202115  2000002037484         NaN
# 202116          Итого         NaN
#
#                                          Unnamed: 2 Unnamed: 3  \
# 0                     Тип объекта: РегистрыСведений        NaN
# 1                Имя объекта: ШтрихкодыНоменклатуры        NaN
# 2       Выводить количество подчиненных записей: Да        NaN
# 3                                               NaN        NaN
# 4                                               NaN   Упаковка
# ...                                             ...        ...
# 202112                                          NaN        NaN
# 202113                                          NaN        NaN
# 202114                                          NaN        NaN
# 202115                                          NaN        NaN
# 202116                                          NaN        NaN
#
#               Unnamed: 4          Unnamed: 5  Unnamed: 6
# 0                    NaN                 NaN         NaN
# 1                    NaN                 NaN         NaN
# 2                    NaN                 NaN         NaN
# 3                    NaN                 NaN         NaN
# 4       Номенклатура.Код  Количество записей         NaN
# ...                  ...                 ...         ...
# 202112       ЦБ-00220540                   1         NaN
# 202113       ЦБ-00220541                   1         NaN
# 202114       ЦБ-00220542                   1         NaN
# 202115       ЦБ-00220543                   1         NaN
# 202116               NaN              202111         NaN
#
# [202117 rows x 7 columns]

# %%
df_sh.columns = df_sh.iloc[4,:]

# %%
#df_sh.drop(list(range(5)))
#df_sh.loc[5:,['Штрихкод','Номенклатура.Код']]
df_sh.iloc[5:,[0,4]]
# Out:
# 4            Штрихкод Номенклатура.Код
# 5       2000000093239      ЦБ-00000005
# 6       2000000093246      ЦБ-00000008
# 7       2000000093253      ЦБ-00000009
# 8       2000000093260      ЦБ-00000010
# 9       2000000093277      ЦБ-00000012
# ...               ...              ...
# 202112  2000002037453      ЦБ-00220540
# 202113  2000002037460      ЦБ-00220541
# 202114  2000002037477      ЦБ-00220542
# 202115  2000002037484      ЦБ-00220543
# 202116          Итого              NaN
#
# [202112 rows x 2 columns]

# %%
if input('правильно? см посл строка y/*'):
    df_sh.iloc[5:-1,[0,4]]
# Out:
# правильно? см посл строка y/*f

# %%
df_sh.iloc[5:-1,[0,4]]
# Out:
# 4            Штрихкод Номенклатура.Код
# 5       2000000093239      ЦБ-00000005
# 6       2000000093246      ЦБ-00000008
# 7       2000000093253      ЦБ-00000009
# 8       2000000093260      ЦБ-00000010
# 9       2000000093277      ЦБ-00000012
# ...               ...              ...
# 202111  2000002037446      ЦБ-00220539
# 202112  2000002037453      ЦБ-00220540
# 202113  2000002037460      ЦБ-00220541
# 202114  2000002037477      ЦБ-00220542
# 202115  2000002037484      ЦБ-00220543
#
# [202111 rows x 2 columns]

# %%
df_sh = _.copy()

# %% [markdown]
# # merge штрихкод

# %%
len(df_sh['Штрихкод'].unique()), len(df_sh['Номенклатура.Код'].unique()), len(df_sh)
# Out:
# (202111, 202107, 202111)

# %%
df_1c_res = pd.merge(df_1c_res,
         df_utd[['Код', 'Серия номенклатуры.Характеристика номенклатуры.Полное наименование']],
         how='left',
         right_on=['Код'],
         left_on=['Код']
         )

# %% [markdown]
# # Запись результата в файл 2

# %%
os.listdir('../')
# Out:
# ['1 Вводные',
#  'del',
#  'for_script08-10-2023',
#  'for_script17-10-2023',
#  'for_script19-09-2023',
#  'ipynb',
#  'ReadMe2023-10-18.docx',
#  '~$adMe2023-09-19.docx',
#  '~$adMe2023-10-18.docx',
#  '~WRL2175.tmp',
#  'Вставки Родитель1-5 коррекция',
#  'Новая папка',
#  'Приложение к readme обнаружены несоответствия по номенклатуре 26-09-2023.xlsx',
#  'Расчет08-10-2023']

# %%
folder_res = '../for_script17-10-2023/'
folder_res
# Out:
# '../for_script17-10-2023/'

# %%
#запись промрезультата для проверки на excel
df_1c_res.to_excel(folder_res+'Остатки1С__все_склады_ДК_2023-10-17_16-12.xlsx')

# %%
#df_1c_res.loc[df_1c_res['Код'] =='ЦБ-00040270','Сводка Вставки' ].to_list()

# %% [markdown]
# # del

# %% [markdown]
# ## проверка правильности присоеденения недостающих Поставщик, договор, накладная из 1C

# %% [markdown]
# родитель2_1c              родитель3_1c                родитель4_1c
# Драгоценности Якутии ООО  №10-171 от 13.10.2022       РТ-5 от 24.10.2022      113
#                           №103/03-2022 от 27.12.2022  Рт-25 от 28.12.2022      66
# ОСОО "Валив"              №V22-01 от 07.07.2022       эксклюзив                33
# Ювелирные изделия         ИП "Алексеев В.М."          10-064 от 07.04.2021     10
# dtype: int64

# %%
df_1c_res.loc[df_1c_res['Родитель3'] == '10-064 от 07.04.2021']
# Out:
#                Код Старый код (Справочник "Номенклатура" (Общие))  \
# 11604  ЦБ-00096408                                            NaN
# 11605  ЦБ-00096400                                            NaN
# 11606  ЦБ-00096401                                            NaN
# 11607  ЦБ-00096402                                            NaN
# 11608  ЦБ-00096403                                            NaN
# 11609  ЦБ-00096404                                            NaN
# 11610  ЦБ-00096406                                            NaN
# 11611  ЦБ-00096407                                            NaN
# 11612  ЦБ-00096409                                            NaN
# 11653  ЦБ-00096405                                            NaN
#
#                               Склад Склад.Склад / Магазин  \
# 11604  Московское представительство         Оптовый склад
# 11605  Московское представительство         Оптовый склад
# 11606  Московское представительство         Оптовый склад
# 11607  Московское представительство         Оптовый склад
# 11608  Московское представительство         Оптовый склад
# 11609  Московское представительство         Оптовый склад
# 11610  Московское представительство         Оптовый склад
# 11611  Московское представительство         Оптовый склад
# 11612  Московское представительство         Оптовый склад
# 11653  Московское представительство         Оптовый склад
#
#              Вставки (Справочник "Номенклатура" (Общие)) Вид номенклатуры  \
# 11604  1Груша-5,130-8-5/7аА 3КР57-0,100-3/5А 1КР57-0,...     П ДМ Юи с ДК
# 11605  1Радиант-5,130-6/8А 1КР57-0,220-3/5А 1КР57-0,2...     П ДМ Юи с ДК
# 11606  1Овал-9,040-8-4/7А 10КР57-1,110-4/5А 1КР57-0,1...     П ДМ Юи с ДК
# 11607               1Кушон-5,130-8-5/6Б 6КР57-0,320-2/2А     П ДМ Юи с ДК
# 11608                1Кушон-5,010-1/6А 60КР57-0,940-4/3А     П ДМ Юи с ДК
# 11609  1КР57-10,090-7/6А 11КР17-0,070-2/4А 4КР17-0,03...     П ДМ Юи с ДК
# 11610               1КР57-8,010-8-4/5А 20КР57-1,170-3/2А     П ДМ Юи с ДК
# 11611  1Принцесса-5,010-6/7аА 4КР57-0,060-4/3А 1КР57-...     П ДМ Юи с ДК
# 11612  1КР57-8,000-8-4/7А 21КР17-0,170-3/4А 7КР17-0,0...     П ДМ Юи с ДК
# 11653  1КР57-5,590-8-1/7А 36КР57-1,950-2/2А 26КР57-1,...     П ДМ Юи с ДК
#
#       Тип номенклатуры Номенклатура                Группа  \
# 11604            Товар        Колье  10-064 от 07.04.2021
# 11605            Товар       Кольцо  10-064 от 07.04.2021
# 11606            Товар       Кольцо  10-064 от 07.04.2021
# 11607            Товар       Кольцо  10-064 от 07.04.2021
# 11608            Товар       Кольцо  10-064 от 07.04.2021
# 11609            Товар       Кольцо  10-064 от 07.04.2021
# 11610            Товар       Кольцо  10-064 от 07.04.2021
# 11611            Товар       Кольцо  10-064 от 07.04.2021
# 11612            Товар       Кольцо  10-064 от 07.04.2021
# 11653            Товар       Серьги  10-064 от 07.04.2021
#
#       Заводской номер (Справочник "Номенклатура" (Общие))  ...  \
# 11604                                            1201378   ...
# 11605                                            1201369   ...
# 11606                                            1201371   ...
# 11607                                            1201372   ...
# 11608                                            1201373   ...
# 11609                                            1201374   ...
# 11610                                            1201376   ...
# 11611                                            1201377   ...
# 11612                                            1201379   ...
# 11653                                            1201375   ...
#
#        розничная стоимость закупочная стоимость  \
# 11604        25,804,328.00           545,341.98
# 11605        12,884,141.00           166,057.47
# 11606        26,728,069.00           594,560.89
# 11607        11,068,247.00           255,955.52
# 11608        37,085,777.00         1,290,177.12
# 11609       135,311,565.00         5,187,643.34
# 11610        29,202,576.00           557,228.89
# 11611        21,039,916.00           806,638.93
# 11612        24,209,671.00           419,600.13
# 11653        55,486,276.00         2,127,260.94
#
#                                            Вставки010123 Штрихкод Старый код  \
# 11604  1Груша-5,130-8-5/7аА 3КР57-0,100-3/5А 1КР57-0,...      NaN        NaN
# 11605  1Радиант-5,130-6/8А 1КР57-0,220-3/5А 1КР57-0,2...      NaN        NaN
# 11606  1Овал-9,040-8-4/7А 10КР57-1,110-4/5А 1КР57-0,1...      NaN        NaN
# 11607               1Кушон-5,130-8-5/6Б 6КР57-0,320-2/2А      NaN        NaN
# 11608                1Кушон-5,010-1/6А 60КР57-0,940-4/3А      NaN        NaN
# 11609  1КР57-10,090-7/6А 11КР17-0,070-2/4А 4КР17-0,03...      NaN        NaN
# 11610               1КР57-8,010-8-4/5А 20КР57-1,170-3/2А      NaN        NaN
# 11611  1Принцесса-5,010-6/7аА 4КР57-0,060-4/3А 1КР57-...      NaN        NaN
# 11612  1КР57-8,000-8-4/7А 21КР17-0,170-3/4А 7КР17-0,0...      NaN        NaN
# 11653  1КР57-5,590-8-1/7А 36КР57-1,950-2/2А 26КР57-1,...      NaN        NaN
#
#                Родитель1           Родитель2             Родитель3 Родитель4  \
# 11604  Ювелирные изделия  ИП "Алексеев В.М."  10-064 от 07.04.2021       NaN
# 11605  Ювелирные изделия  ИП "Алексеев В.М."  10-064 от 07.04.2021       NaN
# 11606  Ювелирные изделия  ИП "Алексеев В.М."  10-064 от 07.04.2021       NaN
# 11607  Ювелирные изделия  ИП "Алексеев В.М."  10-064 от 07.04.2021       NaN
# 11608  Ювелирные изделия  ИП "Алексеев В.М."  10-064 от 07.04.2021       NaN
# 11609  Ювелирные изделия  ИП "Алексеев В.М."  10-064 от 07.04.2021       NaN
# 11610  Ювелирные изделия  ИП "Алексеев В.М."  10-064 от 07.04.2021       NaN
# 11611  Ювелирные изделия  ИП "Алексеев В.М."  10-064 от 07.04.2021       NaN
# 11612  Ювелирные изделия  ИП "Алексеев В.М."  10-064 от 07.04.2021       NaN
# 11653  Ювелирные изделия  ИП "Алексеев В.М."  10-064 от 07.04.2021       NaN
#
#       Родитель5
# 11604       NaN
# 11605       NaN
# 11606       NaN
# 11607       NaN
# 11608       NaN
# 11609       NaN
# 11610       NaN
# 11611       NaN
# 11612       NaN
# 11653       NaN
#
# [10 rows x 41 columns]

# %%
df_1c_res['Родитель3'].unique()
# Out:
# array(['Sakha Minerals Limited SM21-01 от 28.09.2021', 'Товар ДК',
#        '10-271 от 21.12.2018', '№ 06-329/2 от 12.12.16',
#        '06-341/4 от 26.12.2016', '03/10-95 от 15.05.08',
#        '89/1/06 от 20.04.06', '№03/10-212 от 05.11.07',
#        '№6/2-08-КП от 14.01.2008г.', '06-329/2 от 12.12.16 задание 6',
#        'SM10-04 от 11.10.2011 доп2', '№10-159 от 30.06.14',
#        '06-13 от 24.01.2011г.', 'SM10-03 от 14.07.2011 доп.1',
#        '№03/10-214 от 01.09.06', '№03/10-151 от 30.06.06 г.',
#        '№10-121 от 29.03.12 Доп.10 от 29.03.13',
#        'SM12-01 от 30.03.12 доп2',
#        '№10-206 от 07.07.2016 доп.1 от 30.07.16',
#        '№10-141 от 30.03.12 доп.7 от 04.03.13  дав.ДК',
#        '10-184 от 06.10.17', '10-246 от 20.12.2019',
#        '10-012 от 10.07.2019',
#        '№10-141 от 30.03.12 доп.10 от 01.08.13  дав.',
#        'SM10/01 от 07.10.10г', 'Договор №03/10-246 от 18.10.06',
#        '№11/08-КП от 21.01.2008г.',
#        '№10-135 от 30.03.2012г. (давальческий)', '10-100 от 24.05.2019',
#        'Продукция ДК', 'Договор комиссии №03/10-31 от 28.02.02',
#        '№10-121 от 29.03.12 Доп 5 от 26.12.12',
#        '10-126 от 04.05.16 согл.к доп.согл.3 от 18.10.16',
#        '№11дм-10-00(доп.соглашение №7 от 18.06.01)',
#        '№31дм-10-01 от 05.09.2001 г.',
#        '10-126 от 04.05.2016 доп.1 от 04.05.2016',
#        '10-231 от 10.12.2019 фант.',
#        '№10-121 от 29.03.12 Доп №16 от 09.06.15',
#        '№10-121 от 29.03.12 Доп.№19 от 20.11.15',
#        '№10-121 от 29.03.12 Доп.№20 от 20.11.15',
#        '№10-121 от 29.03.12 Доп.№23 от 29.12.15',
#        '№10-121 от 29.03.12г. Доп 8от 23.04.13',
#        '№10-121 от 29.03.12г. Доп. 9', '№10-121 от 29.03.2012г. Доп. 12',
#        '№10-121 от 29.03.12г. Доп  14 от 31.12.14г.', 'ДЯ',
#        '10-154 от 11.03.2011', '10-142 от 30.03.2012 доп.1',
#        '13/03-2020 от 26.03.2020', '06-199/2 от 30.06.2016',
#        '№ 10-398 от 28.09.2011г.', '№194/1/03-2018 от 28.11.18г.',
#        '№10-121 от 29.03.12 Доп.№21 от 26.11.15', 'Ноблес ДК',
#        '№ 10-289 от 11.12.13г.', '10-265 от 01.06.2011',
#        '03-10-99 от 19.03.2004 г.', '07/10-587-09 от 11.12.09',
#        '10-299 от 29.04.2010г.', '11дм-06-01 от 30.11.2001 г.',
#        'Из магазина', '10-46 от 20.03.13', '10-469 от 30.09.2010г.',
#        '10-57 от 08.02.2012г. доп.1', '№10-465 от 10.11.2011',
#        '№10/605 от 30.12.2011 доп.1', '10-265 от 22.12.2021',
#        '31/03-2022 от 29.06.2022', '№10-048 от 05.04.2022 г.',
#        '06-140 от 30.03.2012 доп.7 14.03.14',
#        '№193/1/03-2018 от 12.11.18г.', '06/169/2 от 20.08.18',
#        '№03/10-198 от 20.09.07', '07/10-590-09 от 14.12.2009г.',
#        '№ 10-086 от 27.05.2021г.', '№06-249 от 30.03.2010г.',
#        '№03/10-24 от 30.01.04 (128-141п)',
#        '№10-141 от 30.03.12 Доп  13 от 01.10.14г.',
#        '10-147/2 от 30.11.2020г.', '№10-142 от 30.03.12г. Доп.№3',
#        '48/03-2019 от 26.09.19', '№10-142 от 30.03.12 доп. №2',
#        '03/10-122 от 31.05.2006 г.', '03/10-254 от 13.11.2008 г.',
#        '03/10-261 от 26.09.2003 г.', '07/10-245-09 от 12.05.2009',
#        '10-207 от 15.04.2011', 'Тн №183 от 04.08.04 г.',
#        '10-231 от 29.08.2016', '10-252 от 28.12.19г.',
#        '122/04-2019 от 24.12.2019', '14/1/03-2019-КП от 01.03.2019',
#        'Договор 03/10-188 от 14.08.06', 'SM19-01 от 27.09.2019 ДК',
#        '06-338/1 от 19.12.2016', '17/1/03-2019-КП от 28.03.2019',
#        '88/04-2020 от 25.12.2020', '10-058/1 от 30.03.2021',
#        'Возврат ООО "Невский бриллиант"', '312 от 21.04.09',
#        '10-145 от 04.09.2019', '76/03-2021 от 08.12.2021',
#        '№10-065 от 20.03.14г.', '10-335 от 18.12.2014',
#        'Договор новации № 10-179/1 от 10.06.16г.',
#        'Договор №03/10-92 от 21.05.07',
#        '№10-141 от 30.03.12г. Доп  16 от 06.08.15г.',
#        '06-140 от 30.03.12 доп.15 от 30.07.15',
#        '№03/10-299 от24.11.2003 г.(96, 112-127п)',
#        '№03/10-209-1 от 21.10.05г.(комиссия)',
#        '№10-141 от 30.03.12 Доп 12 от 28.05.14',
#        '№10-141 от 30.03.12 доп.3 от 30.03.12  дав.',
#        '№03/10-167 от 03.07.2003 г. (81-95п, 97п)',
#        '06-140 от 30.03.2012 доп.9 12.08.14',
#        '06-140 от 30.03.2012 доп.11 10.02.15',
#        '06-140 от 30.03.2012 доп.5 13.09.13', '06-140 от 30.03.2012',
#        '07/10-318 от 29.12.2008 г.', '№03/10-179 от 02.08.06г.',
#        '№03/10-124а от 01.06.2006 г.',
#        'Дог. о совм. деятельности  №01/04-01',
#        '№10-121 от 29.03.2012г. Доп. 1', '№03/10-62а от 27.03.07г.',
#        '07/10-169-09 от 27.03.2009', '№10-121 от 29.03.2012г. Доп.  11',
#        'Исп. лист №014289 от 27.03.03 г.', 'SM10-04 от 11.10.2011 доп1',
#        '03/10-183 от 21.08.07г.', '07/10-576-09 от 08.12.2009',
#        '№10-158 от 30.06.14г.', '10-590 от 30.12.2011',
#        '№03/10-253 от 23.09.2003 г. (97-111п)', 'ДК',
#        '№10-141 от 30.03.12 Доп №13 от 01.10.14г.', '№10-066 от 20.03.14',
#        '140/1/11 от 22.11.2011', '№ 06-604 от 30.11.2011г.',
#        '№10-247/2 от 23.08.12 Доп.№1', '№10-366 от 29.06.2010г.',
#        '№10-471 от 30.09.2010г.', '№34дм-10-01 от 01.10.2001 г.',
#        '№10-141 от 30.03.12г Доп.№19 от 30.11.15г.',
#        'SM10/01 от 07.10.10  18шт.', '№03/10-203 от 26.09.07 (купля)',
#        '№10-121 от 29.03.12г. Доп. 3', '№03/10-240 от 29.10.08 г.',
#        '№10-121 от 29.03.12г. Доп 7от 22.04.13',
#        'SM12-03 от 23.09.2013 серебро', 'Договор №10-144 от 26.10.2020г.',
#        'Ювелирные изделия с ДК', 'Сапфир М ДК',
#        '№03/10-136 от 04.06.2003г (75-81п)', '03/10-166 от 30.07.08',
#        '07/10-180А-09 от 31.03.2009', '№ 06-603 от 30.12.2011г.',
#        '10-442 от 31.10.11', '№03/10-258 от 20.12.02 г.',
#        '№10-121 от 29.03.12 До.№20 от 20.11.15', 'дк',
#        '№06-193 от 17.03.2010г.', '№54/03-2021 от 27.10.2021г.',
#        '№8/2-08-КП от 16.01.2008г.', '№ 2019.214156 от 25.06.2019', nan,
#        '03/10-54 от 22.03.2006', '06-341/3 23.12.2016',
#        'Соглашение об отступном 10-006/2 от 29.01.2021',
#        '№03/10-261 от 24.12.03 г.', '№10-121 от 29.03.12г. Доп.№3',
#        '№03/256а от 31.10.06(купля-продажа)',
#        'Договор № 10-357 от 17.06.2010г', '06-283 от 29.12.17',
#        'Тн №5 от 13.05.03 (3 партия)', 'новации №10-47 от 21.03.13г.',
#        'новации №10-198 от 12.09.13', '07/10-613-09 от 21.12.2009',
#        '№10-157 от 30.06.14', 'новации №10-107 от 24.06.13',
#        '№10-121 от 29.03.12г. Доп. 4 от 18.12.12',
#        'новации №10-135 от 10.07.13г.', 'новации №10-79 от 29.04.13г.',
#        'новации №10-14 от 11.02.13г.', 'С/ф №140 от 07.08.98 г.ДК',
#        'новации №06-039 от 24.02.14г.',
#        '№03-10-172 от 20.09.2002 г. (46-51п)',
#        'Договор новации № 10-183 от 15.06.16г.', '10-128 от 25.05.2015',
#        '№03/10-232 от 02.10.06г.', '№03/10-220 от 16.10.07г.',
#        'Акт приема №34 от 02.10.98 г.ДК', 'С/ф №25юв от 28.07.00 г. ДК',
#        'Договор б/н от 02.08.99 г.', '№23 ПДК', '№27 ДК', '№23 ДК',
#        '03/10-184 от 21.08.07г.', '10-097/5 от 31.07.2020г.',
#        '№10-094 от 20.07.2020г.', '36/11-КП-ЮИ от 06.05.2011',
#        'Акт №1 от 21.10.05 г.', '№33/10-99 (Соглашение №1)',
#        '10-141 от 30.03.12 доп.10 от 01.08.13  дав.',
#        '№03-10-93 от 16.04.2003 г. (72-75п)', '10-064 от 07.04.2021',
#        '10-216 от 12.11.2022', '10-216 от 12.11.2024',
#        '10-216 от 12.11.2025', '10-216 от 12.11.2026',
#        '10-216 от 12.11.2027', '10-216 от 12.11.2028',
#        '10-216 от 12.11.2029', '10-216 от 12.11.2023',
#        '№10-357 от 17.06.2010г.',
#        '№10-121 от 29.03.12г. Доп.№4 от 18.12.12',
#        '№10-121 от 29.03.2012г. Доп. №11', '0',
#        '№10-121 от 29.03.12 Доп №18 от 17.09.15',
#        '№10-121 от 29.03.12 Доп.17 от 09.06.15', '10-181 от 01.04.2011г.',
#        '07/10-352-09 от 19.08.2009', 'Договор №03/10-217 от 31.10.05 г.',
#        'Возврат от Саха-Таас', 'Договор комиссии №3/12 от 19.06.2012г.',
#        '10-112/1 от 30.09.2020', 'Тн №3 от 03.04.03 г.(2 партия)',
#        'Договор №03/10-157 от 10.07.06 г.',
#        'Доп.3 к дог. комиссии №3/12 от 19.06.2012г.',
#        'Договор №03/10-152 от 30.06.06 г.',
#        'Доп.2 к дог. комиссии №3/12 от 19.06.2012г.',
#        'Sakha Diamond Shanghai Company Ltd.', '22-ДМ от 01.07.2001 г.',
#        '07/10-13-10 от 22.01.2010 г. х/д', '10-590 от 30.12.2012',
#        '№07/2-149 от 19.03.07г.', '06-284 от 29.12.17',
#        'Нюрбинский гранильно-ювелирный завод',
#        '07/10-85-09 от 16.02.2009', '№03/256а от 31.10.06',
#        '03/10-110  от 10.07.2002 г.', '03/10-170 от 06.08.08',
#        '84/09-КП от 19.08.2009г.', 'новации №10-425 от 27.12.12г.',
#        '№1/1-08-КП от 09.01.2008г.', '№03/10-206а от 27.09.07(купля)',
#        'Возврат из Благовещенска', 'Договор №03/10-234 от 29.11.02 г.',
#        'Договор №03/10-243 от 10.12.2003г.', 'накл.№1',
#        '10-162 от 26.09.19', 'Договор №03/10-109а от 23.05.06',
#        '№10-064 от 20.03.14г', 'Тн №7 от 30.06.03 г.(4 партия)',
#        '№03/10-283 от 17.12.07г.', '10-220 от 26.10.2017',
#        '07/10-118-09 от 04.03.2009', '№03/10-61а от 28.03.2006 г.',
#        '07/10-341А от 13.08.2009г.', '03/10-85 от 29.04.08'], dtype=object)

# %%
df_1c_res.columns
# Out:
# Index(['Код', 'Старый код (Справочник "Номенклатура" (Общие))', 'Склад',
#        'Склад.Склад / Магазин', 'Вставки (Справочник "Номенклатура" (Общие))',
#        'Вид номенклатуры', 'Тип номенклатуры', 'Номенклатура', 'Группа',
#        'Заводской номер (Справочник "Номенклатура" (Общие))',
#        'Проба (Справочник "Номенклатура" (Общие))',
#        'Цвет металла (Справочник "Номенклатура" (Общие))',
#        'Дизайн (Справочник "Номенклатура" (Общие))', 'Артикул ',
#        'Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))',
#        'Цвет Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Чистота Центрального Камня (Справочник "Номенклатура" (Общие))',
#        'Размер (Справочник "Номенклатура" (Общие))', 'Наименование для печати',
#        'Единица измерения веса',
#        'Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))',
#        'Кол-во ДК (Справочник "Номенклатура" (Общие))',
#        'Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))', 'Группы',
#        'родитель1_1c', 'родитель2_1c', 'родитель3_1c', 'родитель4_1c',
#        'родитель5_1c', 'Количество конечный остаток', 'Конечный остаток вес',
#        'розничная стоимость', 'закупочная стоимость', 'Штрихкод',
#        'Вставки корректировка', 'корректировка вставки была', 'Родитель1корр',
#        'Родитель2корр', 'Родитель3корр', 'Родитель4корр', 'Родитель5корр'],
#       dtype='object')

# %%
#По каким договорам 223 с не подключенным полем Вставки
df_1c_res[df_1c_res['Вставки010123'].isna()].value_counts(['родитель2_1c','родитель3_1c','родитель4_1c'])
# Out:
# родитель2_1c              родитель3_1c                родитель4_1c
# Драгоценности Якутии ООО  №10-171 от 13.10.2022       РТ-5 от 24.10.2022     113
#                           №103/03-2022 от 27.12.2022  Рт-25 от 28.12.2022     66
# ОСОО "Валив"              №V22-01 от 07.07.2022       эксклюзив               33
# dtype: int64

# %%
#По каким договорам 223 с не подключенным полем штрихкод
df_1c_res[df_1c_res['Штрихкод'].isna()].value_counts(['родитель2_1c','родитель3_1c','родитель4_1c'])
# Out:
# родитель2_1c              родитель3_1c                родитель4_1c
# Драгоценности Якутии ООО  №10-171 от 13.10.2022       РТ-5 от 24.10.2022      113
#                           №103/03-2022 от 27.12.2022  Рт-25 от 28.12.2022      66
# ОСОО "Валив"              №V22-01 от 07.07.2022       эксклюзив                33
# Ювелирные изделия         ИП "Алексеев В.М."          10-064 от 07.04.2021     10
# dtype: int64

# %%
df_1c_res[df_1c_res['Вставки010123'].isna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212 entries, 5325 to 34241
# Data columns (total 41 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Код                                                                      212 non-null    object
#  1   Старый код (Справочник "Номенклатура" (Общие))                           0 non-null      object
#  2   Склад                                                                    212 non-null    object
#  3   Склад.Склад / Магазин                                                    212 non-null    object
#  4   Вставки (Справочник "Номенклатура" (Общие))                              212 non-null    object
#  5   Вид номенклатуры                                                         212 non-null    object
#  6   Тип номенклатуры                                                         212 non-null    object
#  7   Номенклатура                                                             212 non-null    object
#  8   Группа                                                                   212 non-null    object
#  9   Заводской номер (Справочник "Номенклатура" (Общие))                      212 non-null    object
#  10  Проба (Справочник "Номенклатура" (Общие))                                212 non-null    float64
#  11  Цвет металла (Справочник "Номенклатура" (Общие))                         212 non-null    object
#  12  Дизайн (Справочник "Номенклатура" (Общие))                               212 non-null    object
#  13  Артикул                                                                  212 non-null    object
#  14  Размерная группа Центрального камня (Справочник "Номенклатура" (Общие))  212 non-null    object
#  15  Цвет Центрального Камня (Справочник "Номенклатура" (Общие))              212 non-null    object
#  16  Чистота Центрального Камня (Справочник "Номенклатура" (Общие))           212 non-null    object
#  17  Размер (Справочник "Номенклатура" (Общие))                               212 non-null    object
#  18  Наименование для печати                                                  212 non-null    object
#  19  Единица измерения веса                                                   212 non-null    object
#  20  Вес Вставок ПДК (Карат) (Справочник "Номенклатура" (Общие))              0 non-null      float64
#  21  Кол-во ДК (Справочник "Номенклатура" (Общие))                            0 non-null      float64
#  22  Вес Вставок ДК (Карат) (Справочник "Номенклатура" (Общие))               0 non-null      float64
#  23  Группы                                                                   0 non-null      object
#  24  родитель1_1c                                                             212 non-null    object
#  25  родитель2_1c                                                             212 non-null    object
#  26  родитель3_1c                                                             212 non-null    object
#  27  родитель4_1c                                                             212 non-null    object
#  28  родитель5_1c                                                             0 non-null      object
#  29  Количество конечный остаток                                              212 non-null    float64
#  30  Конечный остаток вес                                                     212 non-null    float64
#  31  розничная стоимость                                                      212 non-null    float64
#  32  закупочная стоимость                                                     212 non-null    float64
#  33  Вставки010123                                                            0 non-null      object
#  34  Штрихкод                                                                 0 non-null      float64
#  35  Старый код                                                               0 non-null      object
#  36  Родитель1                                                                0 non-null      object
#  37  Родитель2                                                                0 non-null      object
#  38  Родитель3                                                                0 non-null      object
#  39  Родитель4                                                                0 non-null      object
#  40  Родитель5                                                                0 non-null      object
# dtypes: float64(9), object(32)
# memory usage: 69.6+ KB

# %%
#df_1c_res[df_1c_res['Сводка Вставки'].isna()]

# %%
#Проверка на срезанность вставок по 100 символов
df_1c_res.loc[df_1c_res['Вставки010123'].isna(),'Вставки (Справочник "Номенклатура" (Общие))'].map(len).unique()
# Out:
# array([ 16,  33,  35, 103, 127, 105,  37,  34,  87,  70,  52,  73,  51,
#         69, 107, 122,  85, 104,  71, 120, 137,  36,  55,  17,  31, 119,
#         24], dtype=int64)

# %% [markdown]
# # Подтянуть недостающие вставки из вставок 1С

# %%
df_1c_res.loc[df_1c_res['Вставки010123'].isna(),'Вставки010123'] = df_1c_res['Вставки (Справочник "Номенклатура" (Общие))']

# %%
df_1c_res.loc[df_1c_res['Вставки010123'].isna(),'Вставки010123']
# Out:
# Series([], Name: Вставки010123, dtype: object)

# %%
df_1c_res[['Вставки010123']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34311 entries, 0 to 34310
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Вставки010123  34311 non-null  object
# dtypes: object(1)
# memory usage: 1.5+ MB

# %%
  ['Т ДМ Юи с ДК', 'Т ДМ Юи сер. с ДК','П ДМ Юи с ДК','Т ДМ Юи Каст ДК','П ДМ Юи Каст ДК']

# %%
(len(df_vst2.loc[(df_vst2['Вид ном'].isin( ['Т ДМ Юи с ДК', 'Т ДМ Юи сер. с ДК','П ДМ Юи с ДК',
                                                   'Т ДМ Юи Каст ДК','П ДМ Юи Каст ДК'])),'Код'].unique()),
                 len(df_vst2.loc[(df_vst2['Вид ном'].isin(  ['Т ДМ Юи с ДК', 'Т ДМ Юи сер. с ДК','П ДМ Юи с ДК',
                                                             'Т ДМ Юи Каст ДК','П ДМ Юи Каст ДК'])),'Код']))
# Out:
# (36398, 36398)

# %%
df_vst2_DK = df_vst2.loc[(df_vst2['Вид ном'].isin(['Т ДМ Юи с ДК', 'Т ДМ Юи сер. с ДК','П ДМ Юи с ДК',
                                                             'Т ДМ Юи Каст ДК','П ДМ Юи Каст ДК']))]

# %%
df_vst2_DK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36398 entries, 1758 to 153277
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Склад                      36398 non-null  object
#  1   Штрихкод                   36388 non-null  float64
#  2   Старый код                 30683 non-null  object
#  3   Код                        36398 non-null  object
#  4   Наименование               36398 non-null  object
#  5   Артикул                    36397 non-null  object
#  6   Зав Ном                    35861 non-null  object
#  7   Вид ном                    36398 non-null  object
#  8   Проба                      36398 non-null  float64
#  9   Цвет металла               36304 non-null  object
#  10  Кол                        36398 non-null  float64
#  11  Вес                        36398 non-null  float64
#  12  Закуп                      36398 non-null  float64
#  13  Розн                       21664 non-null  float64
#  14  Размер                     36303 non-null  object
#  15  РазмернаяГруппаЦК          36398 non-null  object
#  16  ЦветЦК                     36398 non-null  object
#  17  ЧистотаЦК                  36398 non-null  object
#  18  Дизайн                     36398 non-null  object
#  19  Родитель1                  36398 non-null  object
#  20  Родитель2                  36398 non-null  object
#  21  Родитель3                  36391 non-null  object
#  22  Родитель4                  32206 non-null  object
#  23  Родитель5                  9946 non-null   object
#  24  Код классификатора Гохран  0 non-null      float64
#  25  Масса, гр. В хим чистоте   31174 non-null  float64
#  26  Кол-во ДК                  31174 non-null  float64
#  27  Вес вставок ДК(карат)      31174 non-null  float64
#  28  Вес вставок ПДК (Карат)    9658 non-null   float64
#  29  Сводка Вставки             36398 non-null  object
#  30  Unnamed: 30                0 non-null      float64
#  31  Unnamed: 31                0 non-null      float64
#  32  Unnamed: 32                0 non-null      float64
# dtypes: float64(14), object(19)
# memory usage: 9.4+ MB

# %%
len(df_1c_res['Код'].unique()), len(df_1c_res)
# Out:
# (34528, 34528)

# %%
len(set(df_1c_res['Код']) - set(df_vst2_DK['Код']))
# Out:
# 214

# %%
36398-34528
# Out:
# 1870

# %%
'Родитель1', 'Родитель2', 'Родитель3', 'Родитель4', 'Родитель5'

# %% [markdown]
# o	Данные по вставкам надежнее чем с 1с (на 1 янв 2023г) 1. Вводные\Данные по вставкам\23-01-01 Сводка ЮИ.xlsx

# %%
files = os.listdir(folder+'1. Вводные/Данные по вставкам/')
files

[x for x in enumerate(files)]

df_vst = pd.read_excel(folder+'1. Вводные/Данные по вставкам/'+files[0])#,header=9)#, dtype={5: str}

df_vst.columns

len(df_vst['Код'].unique()), len(df_vst)

len(df_1c_res['Код'].unique()), len(df_1c_res)

#Присоединяем к df_1c
df_1c_res = pd.merge(df_1c_res,
         df_vst[['Код','Вставки', 'Штрихкод', 'Старый код',
                 'Родитель1', 'Родитель2', 'Родитель3',
                 'Родитель4', 'Родитель5' ]],
         how='left',
         right_on=['Код'],
         left_on=['Код']
         )

df_1c_res['Штрихкод'].isna().sum()
